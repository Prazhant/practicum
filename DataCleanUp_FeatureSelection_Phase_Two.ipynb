# %%
import pandas as pd
from pathlib import Path  
import sys
import sqlite3

CUT_OF_UNIQUE_VALUES=40

# %%
data_filtered_cedd=pd.read_csv("cleaned_data_with_binary_dead.csv")
df_counts  = pd.DataFrame(columns = ['col', 'count'])
for col in data_filtered_cedd:
    no_of_unique_values=data_filtered_cedd[col].nunique()
    df_counts.loc[len(df_counts)]=[col,no_of_unique_values]
#     if( not col.startswith( 'Unnamed' ) && no_of_unique_values<20):
#         print("%s--->%s"%(col,))
df_counts = df_counts.sort_values(by=['count'], ascending=False)
display(df_counts.head(30))

count=0

for col in data_filtered_cedd:
    no_of_unique_values=data_filtered_cedd[col].nunique()
    if( not col.startswith( 'Unnamed' ) and no_of_unique_values<40):
        count =count+1
        #data_filtered_cedd[col].fillna("imputed",inplace=True)
        data_filtered_cedd[col]=pd.Categorical(data_filtered_cedd[col])
                
data_filtered_cedd.dtypes.value_counts()



count
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (74,82,87,135) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                           col  count
# 0                  Unnamed: 0  28122
# 1                Unnamed: 0.1  28122
# 28                     ceo_id  15744
# 27                     epi_id   7432
# 3                       pa_id   5930
# 12                epi_SocDate   1056
# 21                   icd_code    967
# 22       icd_code_description    965
# 13         epi_StartOfEpisode    833
# 24           cedd_dateofdeath    772
# 30    M0090_INFO_COMPLETED_DT    660
# 39       M0906_DC_TRAN_DTH_DT    619
# 14           epi_EndOfEpisode    616
# 15          epi_DischargeDate    613
# 25                DaysToDeath    334
# 69             M1060_WEIGHT_B    303
# 18                  ceo_HIPPS    226
# 17                 epi_weight    181
# 135       M2200_THER_NEED_NBR    108
# 4                   year_born     90
# 16                 epi_height     72
# 26                   RoughAge     67
# 19                   ceo_HHRG     39
# 68             M1060_HEIGHT_A     31
# 11                   dcr_desc     21
# 10                  epi_dcrid     21
# 75   M1311_NBR_PRSULC_STG2_A1     12
# 87      M1322_NBR_PRSULC_STG1     12
# 23          DiagnosisCategory     11
# 83    M1311_NSTG_DEEP_TSUE_F1     11
# 132

# %% [markdown]
# ### New Binary Column for label and drop alive patients with less than 365 days of history

# %%
from datetime import timedelta
import numpy as np

##### adding our binary column to denote if patient is dead
df = data_filtered_cedd
df['patient_deceased'] = np.where((df['DaysToDeath'] <= 365) | (df['dcc_desc'] == 'PATIENT EXPIRED'), 1, 0)
# Out:
# C:\Users\sjyhl\AppData\Local\Temp/ipykernel_11680/1752841957.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['patient_deceased'] = np.where((df['DaysToDeath'] <= 365) | (df['dcc_desc'] == 'PATIENT EXPIRED'), 1, 0)

# %%
##### defining our year threshold, and converting neccesary col's to datetimes

threesixtyfive = timedelta(days = 365)

df['epi_SocDate'] = pd.to_datetime(df['epi_SocDate'])
df['epi_EndOfEpisode'] = pd.to_datetime(df['epi_EndOfEpisode'])
df['M0906_DC_TRAN_DTH_DT'] = pd.to_datetime(df['M0906_DC_TRAN_DTH_DT'].fillna(df['epi_SocDate']))

# %%
##### dropping all 'alive' patients with LESS than a year of history

for index, row in df.iterrows():
    if row['patient_deceased'] == 0 and row['epi_EndOfEpisode'] - row['epi_SocDate'] > threesixtyfive:
        df.drop(index, axis = 0, inplace = True)

# %%
##### dropping all 'dead' patients with MORE than a year of history

for index, row in df.iterrows():
    if row['patient_deceased'] == 1 and row['epi_EndOfEpisode'] - row['epi_SocDate'] > threesixtyfive:
        row['patient_deceased'] == 0

# %%
len(df)
# Out:
# 27648

# %%
df["M1056_PVX_RSN_NOT_RCVD_AGNCY"].cat.categories
df.groupby(['M1056_PVX_RSN_NOT_RCVD_AGNCY']).size()

df["M1200_VISION"].cat.categories
df.groupby(['M1200_VISION']).size()
# Out:
# M1200_VISION
# 0 - NORMAL VISION: SEES ADEQUATELY IN MOST SITUATIONS; CAN SEE MEDICATION LABELS, NEWSPRINT                                                                        10917
# 1 - PARTIALLY IMPAIRED: CANNOT SEE MEDICATION LABELS OR NEWSPRINT, BUT CAN SEE OBSTACLES IN PATH, AND THE SURROUNDING LAYOUT; CAN COUNT FINGERS AT ARM'S LENGTH     3496
# 2 - SEVERELY IMPAIRED: CANNOT LOCATE OBJECTS WITHOUT HEARING OR TOUCHING THEM OR PATIENT NONRESPONSIVE                                                               195
# dtype: int64

# %% [markdown]
# ### Drop columns with no meaning

# %%
df = df.drop(columns=['CreatedDate', 'CreatedBy', 'UpdateDate', 'UpdateBy', 'ActiveFlag'])

# %%
df['DaysToDeath']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 28117    2.0
# 28118    2.0
# 28119    2.0
# 28120    2.0
# 28121    2.0
# Name: DaysToDeath, Length: 27648, dtype: float64

# %% [markdown]
# ### Find columns with name ID

# %%
[col for col in df.columns if 'id' in col]
# Out:
# ['pa_id', 'epi_dcrid', 'epi_id', 'ceo_id']

# %%
[col for col in df.columns if 'Id' in col]
# Out:
# ['DispositionId']

# %% [markdown]
# ### Drop ID columns... this could give model too much hint

# %%
df = df.drop(columns=['DispositionId', 'pa_id', 'epi_dcrid', 'epi_id', 'ceo_id'])

# %% [markdown]
# ### Drop records with DaysToDeath = 0

# %%
df.dropna(subset=['DaysToDeath'])
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  year_born pa_race pa_gender  \
# 40             40            40              40       1930     NaN    MALE
# 41             41            41              41       1930     NaN    MALE
# 42             42            42              42       1930     NaN    MALE
# 43             43            43              43       1930     NaN    MALE
# 76             76            76              76       1966     NaN    FEMALE
# ...           ...           ...             ...        ...     ...       ...
# 28117       28117         28117           28117       1940     NaN    FEMALE
# 28118       28118         28118           28118       1940     NaN    FEMALE
# 28119       28119         28119           28119       1940     NaN    FEMALE
# 28120       28120         28120           28120       1940     NaN    FEMALE
# 28121       28121         28121           28121       1940     NaN    FEMALE
#
#       pa_maritalstatus    epi_AdmitType         dcc_desc         dcr_desc  \
# 40                 NaN  RECERTIFICATION  PATIENT EXPIRED  PATIENT EXPIRED
# 41                 NaN  RECERTIFICATION  PATIENT EXPIRED  PATIENT EXPIRED
# 42                 NaN  RECERTIFICATION  PATIENT EXPIRED  PATIENT EXPIRED
# 43                 NaN  RECERTIFICATION  PATIENT EXPIRED  PATIENT EXPIRED
# 76                 NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# ...                ...              ...              ...              ...
# 28117              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# 28118              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# 28119              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# 28120              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# 28121              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
#
#        ... M2310_ECR_UNKNOWN  \
# 40     ...               NaN
# 41     ...               NaN
# 42     ...               NaN
# 43     ...               NaN
# 76     ...               NaN
# ...    ...               ...
# 28117  ...               NaN
# 28118  ...               NaN
# 28119  ...                NO
# 28120  ...               NaN
# 28121  ...               NaN
#
#                               M2401_INTRVTN_SMRY_DBTS_FT  \
# 40                                                   NaN
# 41                                                   NaN
# 42                                                   NaN
# 43                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 28117                                                NaN
# 28118                                                NaN
# 28119  NA - PATIENT IS NOT DIABETIC OR IS MISSING LOW...
# 28120                                                NaN
# 28121                                                NaN
#
#                                 M2401_INTRVTN_SMRY_DPRSN  \
# 40                                                   NaN
# 41                                                   NaN
# 42                                                   NaN
# 43                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 28117                                                NaN
# 28118                                                NaN
# 28119  NA - (C2) PATIENT HAS NO DIAGNOSIS OF DEPRESSI...
# 28120                                                NaN
# 28121                                                NaN
#
#       M2401_INTRVTN_SMRY_FALL_PRVNT  M2401_INTRVTN_SMRY_PAIN_MNTR  \
# 40                              NaN                           NaN
# 41                              NaN                           NaN
# 42                              NaN                           NaN
# 43                              NaN                           NaN
# 76                              NaN                           NaN
# ...                             ...                           ...
# 28117                           NaN                           NaN
# 28118                           NaN                           NaN
# 28119                       1 - YES                       1 - YES
# 28120                           NaN                           NaN
# 28121                           NaN                           NaN
#
#        M2401_INTRVTN_SMRY_PRSULC_PRVN  \
# 40                                NaN
# 41                                NaN
# 42                                NaN
# 43                                NaN
# 76                                NaN
# ...                               ...
# 28117                             NaN
# 28118                             NaN
# 28119                         1 - YES
# 28120                             NaN
# 28121                             NaN
#
#                            M2401_INTRVTN_SMRY_PRSULC_WET M2410_INPAT_FACILITY  \
# 40                                                   NaN                  NaN
# 41                                                   NaN                  NaN
# 42                                                   NaN                  NaN
# 43                                                   NaN                  NaN
# 76                                                   NaN                  NaN
# ...                                                  ...                  ...
# 28117                                                NaN                  NaN
# 28118                                                NaN                  NaN
# 28119  NA - PATIENT HAS NO PRESSURE ULCERS OR HAS NO ...         1 - HOSPITAL
# 28120                                                NaN                  NaN
# 28121                                                NaN                  NaN
#
#       M2420_DSCHRG_DISP patient_deceased
# 40                  NaN                1
# 41                  NaN                1
# 42                  NaN                1
# 43                  NaN                1
# 76                  NaN                1
# ...                 ...              ...
# 28117               NaN                1
# 28118               NaN                1
# 28119               NaN                1
# 28120               NaN                1
# 28121               NaN                1
#
# [11611 rows x 146 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df.select_dtypes(include=numerics)
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  year_born  epi_height  \
# 0               0             0               0       1940         NaN
# 1               1             1               1       1940         NaN
# 2               2             2               2       1940         NaN
# 3               3             3               3       1940         NaN
# 4               4             4               4       1961         NaN
# ...           ...           ...             ...        ...         ...
# 28117       28117         28117           28117       1940         NaN
# 28118       28118         28118           28118       1940         NaN
# 28119       28119         28119           28119       1940         NaN
# 28120       28120         28120           28120       1940         NaN
# 28121       28121         28121           28121       1940         NaN
#
#        epi_weight  DaysToDeath  RoughAge  patient_deceased
# 0             NaN          NaN       NaN                 0
# 1             NaN          NaN       NaN                 0
# 2             NaN          NaN       NaN                 0
# 3             NaN          NaN       NaN                 0
# 4             NaN          NaN       NaN                 0
# ...           ...          ...       ...               ...
# 28117         NaN          2.0      82.0                 1
# 28118         NaN          2.0      82.0                 1
# 28119         NaN          2.0      82.0                 1
# 28120         NaN          2.0      82.0                 1
# 28121         NaN          2.0      82.0                 1
#
# [27648 rows x 9 columns]

# %% [markdown]
# ### Drop columns that are giving hints as response variables (like cedd_dateofdeath).

# %%
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'])

# %%
### Also drop dcc_desc and dcr_desc

# %%
df.drop(['M2200_THER_NEED_NBR', 'M1322_NBR_PRSULC_STG1', 'M0090_INFO_COMPLETED_DT', 'ceo_OASIScorrectionnum', 'DaysToDeath', 'cedd_dateofdeath', 'ceas_ascode', 'epi_DischargeDate', 'epi_EndOfEpisode', 'epi_StartOfEpisode', 'epi_SocDate', 'dcr_desc', 'dcc_desc', 'icd_code_description'], inplace = True, axis = 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import numpy as np

imputer = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='imputed')
idf = pd.DataFrame(imputer.fit_transform(df))
idf.columns=df.columns
# idf.index=df.index

#
df = idf
for col in df:
    no_of_unique_values=df[col].nunique()
    if( not col.startswith( 'Unnamed' ) and no_of_unique_values<40):        
        df[col]=pd.Categorical(df[col])

# %%
df.dtypes
# Out:
# year_born                           object
# pa_race                           category
# pa_gender                         category
# pa_maritalstatus                  category
# epi_AdmitType                     category
#                                     ...
# M2401_INTRVTN_SMRY_PRSULC_PRVN    category
# M2401_INTRVTN_SMRY_PRSULC_WET     category
# M2410_INPAT_FACILITY              category
# M2420_DSCHRG_DISP                 category
# patient_deceased                  category
# Length: 129, dtype: object

# %% [markdown]
# #### detect columns that contain numeric value when it shouldn't be. (This runs quite a long time)

# %%
for column_name in df.columns:
    if column_name != 'year_born':
        for index, row in df.iterrows():
            if isinstance(row[column_name], (int, float)):
                print(column_name)
                df[column_name] = df[column_name].astype(str)
                break
# Out:
# pa_race
# pa_maritalstatus
# epi_height
# epi_weight
# RoughAge
# M1311_NBR_ULC_SOCROC_STG2_A2
# M1311_NBR_ULC_SOCROC_STG3_B2
# M1311_NBR_ULC_SOCROC_STG4_C2
# M1311_NSTG_CVRG_SOCROC_E2
# M1311_NSTG_DEEP_TSUE_SOCROC_F2
# M1311_NSTG_DRSG_SOCROC_D2
# patient_deceased

# %%
# Use Ordinal Encoder for all numeric type category

from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
enc.fit(df)
enc.categories_
# Out:
# [array([1909, 1913, 1914, 1915, 1917, 1918, 1919, 1920, 1921, 1922, 1923,
#         1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934,
#         1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945,
#         1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#         1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#         1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#         1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#         1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2001,
#         2011, 2019], dtype=object),
#  array(['1.0', '2.0', '3.0', '5.0', '6.0', '7.0', '8.0', 'imputed'],
#        dtype=object),
#  array(['FEMALE', 'MALE  '], dtype=object),
#  array(['1.0', '2.0', '25000.0', '3.0', '4.0', '5.0', '6.0', '7.0', '8.0',
#         'imputed'], dtype=object),
#  array(['NEW ADMISSION', 'READMISSION', 'RECERTIFICATION'], dtype=object),
#  array(['150.0', '164.0', '5.0', '5.3', '5.6', '55.0', '56.25', '57.0',
#         '58.0', '58.98', '59.0', '59.45', '59.8', '60.0', '60.5', '60.98',
#         '61.0', '61.2', '61.96', '61.97', '62.0', '62.9', '62.99', '63.0',
#         '63.35', '63.5', '63.6', '63.78', '63.9', '64.0', '64.57', '64.8',
#         '64.9', '64.96', '65.0', '65.25', '65.35', '65.98', '66.0',
#         '66.54', '66.75', '66.96', '67.0', '67.48', '67.5', '67.8', '67.9',
#         '67.99', '68.0', '68.11', '68.25', '68.5', '68.9', '68.97', '69.0',
#         '70.0', '70.08', '70.5', '70.8', '70.87', '70.9', '70.98', '71.0',
#         '71.25', '71.65', '71.96', '72.0', '72.5', '73.0', '73.97', '74.0',
#         '75.0', 'imputed'], dtype=object),
#  array(['100.0', '100.1', '101.0', '103.0', '104.94', '106.0', '108.0',
#         '108.9', '109.0', '110.0', '111.1', '112.0', '112.42', '114.0',
#         '116.0', '118.0', '119.0', '119.4', '120.0', '121.0', '121.11',
#         '122.0', '122.54', '123.0', '123.65', '125.0', '126.2', '127.0',
#         '127.6', '128.0', '129.0', '130.0', '134.0', '134.6', '135.0',
#         '137.0', '137.4', '139.0', '140.0', '143.0', '144.0', '144.32',
#         '144.4', '146.4', '147.0', '147.4', '148.0', '149.0', '150.0',
#         '151.0', '151.8', '151.9', '152.0', '152.46', '152.9', '154.0',
#         '155.0', '155.4', '156.64', '157.0', '158.0', '158.11', '159.0',
#         '159.37', '160.0', '161.0', '161.8', '163.0', '164.0', '164.12',
#         '164.9', '165.0', '166.01', '168.9', '169.0', '169.4', '169.62',
#         '170.0', '170.06', '171.0', '171.1', '173.0', '174.0', '174.7',
#         '175.0', '176.0', '177.0', '178.0', '178.2', '179.0', '179.3',
#         '179.52', '180.0', '181.0', '182.0', '183.0', '184.0', '184.6',
#         '185.0', '186.0', '188.0', '189.4', '189.86', '189.99', '192.0',
#         '193.0', '194.0', '195.0', '195.8', '197.0', '198.0', '198.9',
#         '199.6', '200.0', '200.42', '201.0', '202.4', '202.8', '204.6',
#         '205.0', '206.58', '207.0', '208.0', '209.0', '211.0', '212.74',
#         '212.96', '215.0', '215.6', '216.0', '216.7', '219.0', '220.0',
#         '222.0', '224.84', '225.0', '227.7', '233.64', '233.86', '235.0',
#         '235.84', '237.2', '238.0', '239.8', '243.0', '247.0', '250.0',
#         '251.0', '251.9', '253.0', '258.0', '263.0', '264.0', '266.0',
#         '268.0', '269.72', '271.0', '272.0', '288.0', '297.0', '297.66',
#         '311.0', '321.0', '333.3', '338.0', '412.72', '58.52', '80.0',
#         '84.0', '84.2', '86.0', '89.0', '90.0', '91.3', '92.62', '95.0',
#         '96.0', '99.0', '99.2', '99.4', 'imputed'], dtype=object),
#  array(['1AFKS', '1AFKT', '1AFKU', '1AFMS', '1AGKS', '1AGKT', '1AGKU',
#         '1AGMS', '1AGMT', '1AGNS', '1AGPS', '1AHKS', '1AHKT', '1AHKV',
#         '1AHLS', '1AHLT', '1AHMS', '1AHNS', '1AHPS', '1BFKS', '1BFKT',
#         '1BFKU', '1BFKV', '1BFLS', '1BFMS', '1BFMT', '1BGKS', '1BGKT',
#         '1BGKU', '1BGKV', '1BGLS', '1BGLT', '1BGMS', '1BGMT', '1BGNS',
#         '1BGPS', '1BGPT', '1BHKS', '1BHKT', '1BHKU', '1BHKV', '1BHLS',
#         '1BHLT', '1BHLV', '1BHMS', '1BHMT', '1BHNS', '1BHNT', '1BHNU',
#         '1BHPS', '1BHPT', '1BHPV', '1CFKS', '1CFKT', '1CFKU', '1CFKV',
#         '1CFKW', '1CFLS', '1CFLU', '1CFMS', '1CFPS', '1CFPT', '1CFPU',
#         '1CGKS', '1CGKT', '1CGKU', '1CGKV', '1CGKW', '1CGLS', '1CGLT',
#         '1CGMS', '1CGMT', '1CGMU', '1CGMV', '1CGNS', '1CGPS', '1CGPT',
#         '1CGPU', '1CGPV', '1CGPW', '1CHKS', '1CHKT', '1CHKU', '1CHKV',
#         '1CHKW', '1CHKX', '1CHLS', '1CHLT', '1CHLU', '1CHLV', '1CHLW',
#         '1CHLX', '1CHMS', '1CHMT', '1CHMU', '1CHMV', '1CHMW', '1CHNS',
#         '1CHNT', '1CHNU', '1CHNV', '1CHNW', '1CHPS', '1CHPT', '1CHPU',
#         '1CHPV', '1CHPW', '2AFKS', '2AFLS', '2AFLT', '2AFMS', '2AHKS',
#         '2AHLS', '2AHMS', '2BFKS', '2BFKT', '2BFLS', '2BFLT', '2BFLU',
#         '2BFMS', '2BHKS', '2BHLS', '2BHLT', '2BHMS', '2CFKS', '2CFKT',
#         '2CFKU', '2CFLS', '2CFLT', '2CFLU', '2CFMS', '2CFMT', '2CFMU',
#         '2CFMV', '2CHKS', '2CHKT', '2CHKW', '2CHLS', '2CHLT', '2CHLU',
#         '2CHLV', '2CHLW', '2CHMS', '2CHMT', '2CHMW', '3AFKS', '3AFMS',
#         '3AGKS', '3AGKT', '3AGKU', '3AGMS', '3AHKS', '3AHKT', '3AHKU',
#         '3AHLS', '3AHMS', '3AHMT', '3AHMU', '3AHNU', '3AHPS', '3BFKS',
#         '3BGKS', '3BGKT', '3BGLS', '3BGPS', '3BHKS', '3BHKT', '3BHKU',
#         '3BHKV', '3BHKW', '3BHLS', '3BHMS', '3BHMT', '3BHNS', '3BHPS',
#         '3BHPT', '3BHPU', '3CFKT', '3CFKU', '3CFKW', '3CGKS', '3CGKT',
#         '3CGKU', '3CGKV', '3CGKW', '3CGLS', '3CGLU', '3CGMU', '3CGNW',
#         '3CHKS', '3CHKT', '3CHKU', '3CHKV', '3CHKW', '3CHKX', '3CHMS',
#         '3CHMT', '3CHMU', '3CHMW', '3CHPS', '3CHPU', '3CHPV', '4BFLS',
#         '4BFMS', '4CFKT', '4CGMX', '5AFKS', '5AGKS', '5AHKS', '5AHKT',
#         '5BFKS', '5BGKS', '5BGKT', '5BHKS', '5BHKT', '5BHKU', '5CFKT',
#         '5CGKU', '5CHKS', '5CHKT', '5CHKU', '5CHKV', '5CHKW', 'imputed'],
#        dtype=object),
#  array(['C1F1S1', 'C1F1S2', 'C1F1S3', 'C1F2S1', 'C1F2S3', 'C1F2S4',
#         'C1F2S5', 'C1F3S1', 'C1F3S2', 'C1F3S3', 'C1F3S4', 'C1F3S5',
#         'C2F1S1', 'C2F1S2', 'C2F1S3', 'C2F2S1', 'C2F2S2', 'C2F2S3',
#         'C2F2S4', 'C2F2S5', 'C2F3S1', 'C2F3S2', 'C2F3S3', 'C2F3S4',
#         'C2F3S5', 'C3F1S1', 'C3F1S2', 'C3F1S3', 'C3F1S5', 'C3F2S1',
#         'C3F2S2', 'C3F2S3', 'C3F2S4', 'C3F2S5', 'C3F3S1', 'C3F3S2',
#         'C3F3S3', 'C3F3S4', 'C3F3S5', 'imputed'], dtype=object),
#  array(['348.31', '787.20', 'A04.71', 'A04.72', 'A09', 'A40.3', 'A40.8',
#         'A40.9', 'A41.01', 'A41.02', 'A41.1', 'A41.4', 'A41.50', 'A41.51',
#         'A41.52', 'A41.59', 'A41.81', 'A41.89', 'A41.9', 'B00.4', 'B02.29',
#         'B02.39', 'B02.8', 'B02.9', 'B18.2', 'B37.2', 'B37.7', 'C01',
#         'C02.9', 'C09.9', 'C10.9', 'C15.3', 'C15.5', 'C15.9', 'C16.0',
#         'C16.9', 'C17.0', 'C17.9', 'C18.0', 'C18.1', 'C18.2', 'C18.7',
#         'C18.9', 'C19', 'C20', 'C22.0', 'C22.9', 'C25.0', 'C25.1', 'C25.2',
#         'C25.3', 'C25.9', 'C26.9', 'C32.1', 'C32.9', 'C34.11', 'C34.12',
#         'C34.2', 'C34.31', 'C34.32', 'C34.81', 'C34.90', 'C34.91',
#         'C34.92', 'C44.329', 'C44.722', 'C45.0', 'C50.112', 'C50.212',
#         'C50.411', 'C50.412', 'C50.811', 'C50.911', 'C50.912', 'C53.0',
#         'C53.9', 'C54.1', 'C56.1', 'C61', 'C64.1', 'C64.2', 'C67.9',
#         'C71.0', 'C71.1', 'C71.3', 'C71.6', 'C71.7', 'C71.9', 'C73',
#         'C76.0', 'C76.2', 'C76.3', 'C78.01', 'C78.6', 'C78.7', 'C78.89',
#         'C79.31', 'C79.51', 'C79.81', 'C7A.1', 'C83.30', 'C83.33',
#         'C83.38', 'C83.39', 'C85.90', 'C88.4', 'C90.00', 'C91.10',
#         'C92.00', 'C92.01', 'C92.10', 'C92.50', 'C95.90', 'D12.6', 'D46.9',
#         'D49.6', 'D50.0', 'D50.9', 'D51.0', 'D59.1', 'D61.818', 'D62',
#         'D64.9', 'D66', 'D68.0', 'D69.6', 'E03.9', 'E05.90', 'E10.22',
#         'E10.40', 'E10.621', 'E10.622', 'E10.65', 'E10.69', 'E11.21',
#         'E11.22', 'E11.29', 'E11.36', 'E11.40', 'E11.41', 'E11.42',
#         'E11.51', 'E11.52', 'E11.59', 'E11.610', 'E11.621', 'E11.622',
#         'E11.649', 'E11.65', 'E11.69', 'E11.9', 'E43', 'E46', 'E53.8',
#         'E66.01', 'E83.52', 'E86.0', 'E87.0', 'E87.1', 'E87.6', 'F03.90',
#         'F03.91', 'F10.20', 'F10.239', 'F20.0', 'F20.9', 'F22', 'F29',
#         'F31.32', 'F31.9', 'F32.9', 'F33.1', 'F33.9', 'F41.1', 'F41.9',
#         'F44.4', 'G06.0', 'G06.2', 'G11.4', 'G12.21', 'G12.9', 'G14',
#         'G20', 'G21.11', 'G23.1', 'G25.0', 'G25.81', 'G30.0', 'G30.1',
#         'G30.8', 'G30.9', 'G31.01', 'G31.09', 'G31.2', 'G31.83', 'G31.84',
#         'G31.85', 'G35', 'G36.0', 'G37.3', 'G37.9', 'G40.109', 'G40.209',
#         'G40.309', 'G40.409', 'G40.89', 'G40.909', 'G40.919', 'G43.909',
#         'G50.0', 'G60.0', 'G60.8', 'G60.9', 'G61.0', 'G61.81', 'G62.1',
#         'G62.89', 'G70.00', 'G70.01', 'G71.00', 'G71.11', 'G72.0',
#         'G72.81', 'G72.9', 'G80.0', 'G80.1', 'G80.8', 'G80.9', 'G81.14',
#         'G81.91', 'G81.94', 'G82.20', 'G82.21', 'G82.50', 'G82.54',
#         'G83.4', 'G89.21', 'G89.29', 'G89.3', 'G89.4', 'G90.09', 'G90.3',
#         'G91.0', 'G91.2', 'G92', 'G93.1', 'G93.40', 'G93.41', 'H53.2',
#         'H81.13', 'I05.9', 'I10', 'I11.0', 'I11.9', 'I12.0', 'I12.9',
#         'I13.0', 'I13.10', 'I13.11', 'I13.2', 'I16.0', 'I16.1', 'I21.09',
#         'I21.19', 'I21.3', 'I21.4', 'I21.A1', 'I25.10', 'I25.110',
#         'I25.119', 'I25.5', 'I26.09', 'I26.93', 'I26.99', 'I27.20',
#         'I27.82', 'I30.9', 'I31.3', 'I33.0', 'I35.0', 'I38', 'I42.8',
#         'I44.1', 'I44.2', 'I47.1', 'I47.2', 'I48.0', 'I48.19', 'I48.20',
#         'I48.21', 'I48.3', 'I48.91', 'I48.92', 'I49.8', 'I50.1', 'I50.22',
#         'I50.23', 'I50.30', 'I50.32', 'I50.33', 'I50.40', 'I50.42',
#         'I50.43', 'I50.810', 'I50.82', 'I50.9', 'I63.512', 'I63.9',
#         'I65.22', 'I65.23', 'I67.89', 'I69.054', 'I69.120', 'I69.154',
#         'I69.198', 'I69.254', 'I69.298', 'I69.311', 'I69.314', 'I69.318',
#         'I69.320', 'I69.321', 'I69.322', 'I69.328', 'I69.334', 'I69.341',
#         'I69.344', 'I69.351', 'I69.353', 'I69.354', 'I69.365', 'I69.391',
#         'I69.393', 'I69.398', 'I70.235', 'I70.245', 'I70.248', 'I70.261',
#         'I70.262', 'I70.91', 'I73.9', 'I74.3', 'I82.401', 'I82.402',
#         'I82.411', 'I82.413', 'I82.431', 'I82.432', 'I82.621', 'I83.012',
#         'I83.018', 'I83.028', 'I87.2', 'I87.311', 'I87.312', 'I87.313',
#         'I87.331', 'I87.332', 'I87.333', 'I89.0', 'I95.1', 'I95.89', 'I96',
#         'J02.9', 'J06.9', 'J09.X1', 'J10.00', 'J10.1', 'J11.1', 'J12.2',
#         'J12.3', 'J13', 'J15.0', 'J15.1', 'J15.211', 'J15.212', 'J15.6',
#         'J15.9', 'J16.8', 'J18.0', 'J18.1', 'J18.8', 'J18.9', 'J20.8',
#         'J20.9', 'J32.0', 'J40', 'J43.1', 'J43.2', 'J43.8', 'J43.9',
#         'J44.0', 'J44.1', 'J44.9', 'J45.20', 'J45.21', 'J45.40', 'J45.41',
#         'J45.51', 'J45.901', 'J45.909', 'J47.1', 'J47.9', 'J69.0', 'J81.0',
#         'J84.10', 'J84.112', 'J84.9', 'J85.1', 'J86.9', 'J90', 'J96.01',
#         'J96.02', 'J96.10', 'J96.11', 'J96.12', 'J96.21', 'J96.91',
#         'J98.01', 'J98.2', 'J98.4', 'K21.9', 'K22.10', 'K22.2', 'K22.70',
#         'K26.9', 'K27.9', 'K28.9', 'K29.70', 'K29.80', 'K31.1', 'K31.819',
#         'K46.9', 'K50.90', 'K51.00', 'K51.90', 'K52.1', 'K52.89', 'K52.9',
#         'K55.1', 'K56.690', 'K56.699', 'K57.20', 'K57.21', 'K57.30',
#         'K57.31', 'K57.80', 'K57.90', 'K57.92', 'K58.9', 'K59.00',
#         'K59.09', 'K61.0', 'K61.1', 'K61.2', 'K61.39', 'K62.5', 'K62.89',
#         'K63.0', 'K63.1', 'K63.2', 'K65.1', 'K65.9', 'K70.10', 'K70.30',
#         'K70.31', 'K72.00', 'K72.10', 'K72.90', 'K74.3', 'K74.60',
#         'K74.69', 'K75.0', 'K75.81', 'K75.9', 'K80.20', 'K81.0', 'K81.9',
#         'K83.1', 'K85.10', 'K85.90', 'K86.1', 'K91.2', 'K91.870', 'K91.89',
#         'K92.0', 'K92.1', 'K92.2', 'K94.01', 'K94.02', 'K94.09', 'K94.22',
#         'K94.23', 'L02.211', 'L02.212', 'L02.213', 'L02.214', 'L02.31',
#         'L02.412', 'L02.413', 'L02.415', 'L02.512', 'L02.611', 'L02.612',
#         'L02.811', 'L03.031', 'L03.032', 'L03.113', 'L03.114', 'L03.115',
#         'L03.116', 'L03.213', 'L03.311', 'L03.312', 'L03.317', 'L12.0',
#         'L29.8', 'L30.9', 'L76.32', 'L76.34', 'L88', 'L89.012', 'L89.132',
#         'L89.150', 'L89.151', 'L89.152', 'L89.153', 'L89.154', 'L89.210',
#         'L89.212', 'L89.220', 'L89.222', 'L89.223', 'L89.224', 'L89.310',
#         'L89.311', 'L89.312', 'L89.313', 'L89.314', 'L89.320', 'L89.321',
#         'L89.322', 'L89.323', 'L89.324', 'L89.512', 'L89.513', 'L89.522',
#         'L89.523', 'L89.610', 'L89.611', 'L89.612', 'L89.613', 'L89.614',
#         'L89.620', 'L89.621', 'L89.622', 'L89.623', 'L89.890', 'L89.892',
#         'L89.893', 'L89.894', 'L89.896', 'L97.111', 'L97.311', 'L97.412',
#         'L97.422', 'L97.512', 'L97.521', 'L97.811', 'L97.812', 'L97.821',
#         'L97.822', 'L98.421', 'L98.492', 'L98.8', 'M00.011', 'M00.061',
#         'M00.852', 'M00.861', 'M00.862', 'M00.9', 'M06.89', 'M10.9',
#         'M12.811', 'M13.0', 'M14.671', 'M15.0', 'M15.9', 'M16.0', 'M16.11',
#         'M16.12', 'M17.0', 'M17.11', 'M17.12', 'M19.011', 'M19.012',
#         'M19.041', 'M19.042', 'M19.072', 'M21.371', 'M24.561', 'M25.062',
#         'M25.511', 'M25.521', 'M25.562', 'M27.2', 'M32.9', 'M35.2',
#         'M35.3', 'M41.9', 'M43.16', 'M43.17', 'M43.6', 'M46.26', 'M47.12',
#         'M47.26', 'M47.27', 'M47.812', 'M47.816', 'M47.9', 'M48.02',
#         'M48.061', 'M48.062', 'M48.07', 'M48.54XD', 'M48.56XD', 'M50.00',
#         'M51.16', 'M51.17', 'M51.26', 'M51.36', 'M51.37', 'M51.86',
#         'M53.3', 'M54.12', 'M54.16', 'M54.2', 'M54.31', 'M54.41', 'M54.42',
#         'M54.5', 'M54.89', 'M62.81', 'M62.82', 'M70.61', 'M72.2', 'M72.6',
#         'M75.01', 'M75.102', 'M75.41', 'M75.52', 'M75.81', 'M79.7',
#         'M79.81', 'M80.021D', 'M80.022D', 'M80.031D', 'M80.051D',
#         'M80.052D', 'M80.072D', 'M80.08XA', 'M80.08XD', 'M80.852D',
#         'M80.88XD', 'M81.0', 'M84.350D', 'M84.351D', 'M84.452D',
#         'M84.48XD', 'M84.58XD', 'M86.171', 'M86.672', 'M97.12XD', 'N10',
#         'N12', 'N13.2', 'N13.30', 'N13.6', 'N13.9', 'N15.1', 'N17.9',
#         'N18.3', 'N18.4', 'N20.0', 'N28.89', 'N30.00', 'N30.90', 'N31.2',
#         'N31.9', 'N39.0', 'N40.1', 'N45.1', 'N48.29', 'N49.3', 'N61.1',
#         'R13.10', 'R13.13', 'R19.7', 'R26.89', 'R60.0', 'S01.01XD',
#         'S01.81XA', 'S01.81XD', 'S02.2XXD', 'S02.32XD', 'S02.91XD',
#         'S06.0X0D', 'S06.360D', 'S06.5X0D', 'S06.5X9D', 'S06.6X0D',
#         'S12.100D', 'S12.112D', 'S12.600D', 'S12.9XXD', 'S16.1XXD',
#         'S22.060D', 'S22.068D', 'S22.069D', 'S22.070D', 'S22.080D',
#         'S22.088D', 'S22.089A', 'S22.089D', 'S22.20XD', 'S22.31XD',
#         'S22.32XD', 'S22.41XD', 'S22.42XD', 'S22.43XD', 'S30.0XXD',
#         'S31.105D', 'S31.829D', 'S32.000D', 'S32.010D', 'S32.011D',
#         'S32.018D', 'S32.019D', 'S32.020D', 'S32.028D', 'S32.029D',
#         'S32.030A', 'S32.030D', 'S32.038D', 'S32.040D', 'S32.048D',
#         'S32.059D', 'S32.10XD', 'S32.401D', 'S32.412D', 'S32.501D',
#         'S32.502D', 'S32.511D', 'S32.512D', 'S32.591D', 'S32.592D',
#         'S32.810D', 'S39.012A', 'S39.012D', 'S41.111D', 'S41.112D',
#         'S42.201D', 'S42.202D', 'S42.211D', 'S42.212D', 'S42.214D',
#         'S42.215D', 'S42.251D', 'S42.302D', 'S42.342D', 'S42.351D',
#         'S42.352D', 'S42.411D', 'S42.412D', 'S43.004D', 'S43.005D',
#         'S46.011D', 'S51.012D', 'S51.811D', 'S51.812D', 'S52.501D',
#         'S52.502D', 'S52.502E', 'S52.532D', 'S52.571D', 'S61.011D',
#         'S61.401D', 'S61.412D', 'S62.102D', 'S62.112D', 'S62.92XD',
#         'S71.002D', 'S71.101D', 'S71.102D', 'S71.112D', 'S72.001D',
#         'S72.002A', 'S72.002D', 'S72.011D', 'S72.012D', 'S72.022D',
#         'S72.041D', 'S72.042D', 'S72.102D', 'S72.111D', 'S72.112D',
#         'S72.114D', 'S72.141A', 'S72.141D', 'S72.142D', 'S72.145D',
#         'S72.21XD', 'S72.22XD', 'S72.302D', 'S72.401D', 'S72.402D',
#         'S72.421D', 'S72.8X1D', 'S72.91XD', 'S72.92XD', 'S76.011D',
#         'S76.012D', 'S80.812D', 'S81.001A', 'S81.002D', 'S81.011D',
#         'S81.801D', 'S81.802A', 'S81.802D', 'S81.811A', 'S81.811D',
#         'S81.812D', 'S81.832D', 'S82.001D', 'S82.002D', 'S82.041D',
#         'S82.101D', 'S82.142D', 'S82.202D', 'S82.241D', 'S82.301D',
#         'S82.401D', 'S82.51XD', 'S82.52XD', 'S82.54XD', 'S82.61XD',
#         'S82.62XD', 'S82.841D', 'S82.842D', 'S82.842E', 'S82.851D',
#         'S82.852D', 'S82.891D', 'S82.892D', 'S83.242D', 'S83.91XD',
#         'S91.001D', 'S91.002D', 'S91.101D', 'S91.104D', 'S91.105D',
#         'S91.111D', 'S91.112D', 'S91.202D', 'S91.205D', 'S91.301D',
#         'S91.302D', 'S93.401D', 'T21.24XD', 'T22.212D', 'T24.212D',
#         'T24.311D', 'T24.331D', 'T25.222D', 'T79.6XXD', 'T79.8XXD',
#         'T80.211A', 'T81.31XA', 'T81.31XD', 'T81.32XA', 'T81.32XD',
#         'T81.40XD', 'T81.41XA', 'T81.41XD', 'T81.42XA', 'T81.43XA',
#         'T81.43XD', 'T81.49XA', 'T81.83XD', 'T81.89XD', 'T82.6XXA',
#         'T82.7XXA', 'T82.7XXD', 'T82.868D', 'T82.897D', 'T83.510A',
#         'T83.510D', 'T83.511A', 'T83.518A', 'T83.518D', 'T84.020D',
#         'T84.021D', 'T84.022D', 'T84.023D', 'T84.030D', 'T84.033D',
#         'T84.090D', 'T84.498D', 'T84.51XA', 'T84.52XA', 'T84.52XD',
#         'T84.53XA', 'T84.53XD', 'T84.54XA', 'T84.54XD', 'T84.59XA',
#         'T84.59XD', 'T84.624A', 'T84.63XA', 'T84.69XA', 'T84.7XXA',
#         'T84.84XD', 'T84.89XA', 'T85.71XD', 'T85.730D', 'T85.733A',
#         'T85.79XA', 'T85.79XD', 'T86.11', 'T86.43', 'T87.41', 'T87.43',
#         'T87.44', 'T87.54', 'T87.81', 'T87.89', 'U07.1', 'Z43.0', 'Z43.1',
#         'Z43.2', 'Z43.3', 'Z43.4', 'Z43.5', 'Z43.6', 'Z45.2', 'Z46.6',
#         'Z47.1', 'Z47.33', 'Z47.81', 'Z47.89', 'Z48.00', 'Z48.01',
#         'Z48.03', 'Z48.22', 'Z48.3', 'Z48.811', 'Z48.812', 'Z48.813',
#         'Z48.815', 'Z48.816', 'Z48.817', 'Z48.89', 'imputed'], dtype=object),
#  array(['Cancer', 'Dementia, Cerebral Degeneration', 'Heart',
#         'Kidney, excluding cancer', 'Liver, excluding cancer',
#         'Lung, excluding cancer', 'Neurological', 'Other', 'Stroke/Coma',
#         'Unspecified/AFTT', 'heart', 'imputed'], dtype=object),
#  array(['10.0', '100.0', '101.0', '102.0', '103.0', '104.0', '106.0',
#         '108.0', '112.0', '28.0', '33.0', '36.0', '42.0', '43.0', '45.0',
#         '48.0', '49.0', '50.0', '51.0', '52.0', '53.0', '54.0', '55.0',
#         '56.0', '57.0', '58.0', '59.0', '60.0', '61.0', '62.0', '63.0',
#         '64.0', '65.0', '66.0', '67.0', '68.0', '69.0', '70.0', '71.0',
#         '72.0', '73.0', '74.0', '75.0', '76.0', '77.0', '78.0', '79.0',
#         '80.0', '81.0', '82.0', '83.0', '84.0', '85.0', '86.0', '87.0',
#         '88.0', '89.0', '90.0', '91.0', '92.0', '93.0', '94.0', '95.0',
#         '96.0', '97.0', '98.0', '99.0', 'imputed'], dtype=object),
#  array(['1 - START OF CARE - FURTHER VISITS PLANNED',
#         '3 - RESUMPTION OF CARE (AFTER INPATIENT STAY)',
#         '4 - RECERTIFICATION (FOLLOW-UP) REASSESSMENT',
#         '5 - OTHER FOLLOW-UP',
#         '6 - TRANSFERRED TO AN INPATIENT FACILITY - PATIENT NOT DISCHARGED FROM AGENCY',
#         '7 - TRANSFERRED TO AN INPATIENT FACILITY - PATIENT DISCHARGED FROM AGENCY',
#         '8 - DEATH AT HOME', '9 - DISCHARGE FROM AGENCY', 'imputed'],
#        dtype=object),
#  array(['EARLY', 'LATER', 'NOT APPLICABLE', 'UNKNOWN', 'imputed'],
#        dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['2014-10-25T00:00:00.000000000', '2015-09-22T00:00:00.000000000',
#         '2015-09-30T00:00:00.000000000', '2016-09-16T00:00:00.000000000',
#         '2017-01-20T00:00:00.000000000', '2017-02-28T00:00:00.000000000',
#         '2017-04-07T00:00:00.000000000', '2017-05-16T00:00:00.000000000',
#         '2017-06-02T00:00:00.000000000', '2017-06-18T00:00:00.000000000',
#         '2017-06-24T00:00:00.000000000', '2017-12-06T00:00:00.000000000',
#         '2018-01-02T00:00:00.000000000', '2018-01-03T00:00:00.000000000',
#         '2018-01-09T00:00:00.000000000', '2018-02-03T00:00:00.000000000',
#         '2018-02-17T00:00:00.000000000', '2018-03-30T00:00:00.000000000',
#         '2018-05-02T00:00:00.000000000', '2018-05-20T00:00:00.000000000',
#         '2018-06-06T00:00:00.000000000', '2018-06-09T00:00:00.000000000',
#         '2018-06-17T00:00:00.000000000', '2018-06-20T00:00:00.000000000',
#         '2018-07-03T00:00:00.000000000', '2018-07-20T00:00:00.000000000',
#         '2018-08-30T00:00:00.000000000', '2018-09-08T00:00:00.000000000',
#         '2018-09-18T00:00:00.000000000', '2018-10-27T00:00:00.000000000',
#         '2018-11-13T00:00:00.000000000', '2018-12-19T00:00:00.000000000',
#         '2018-12-26T00:00:00.000000000', '2019-01-07T00:00:00.000000000',
#         '2019-01-18T00:00:00.000000000', '2019-01-21T00:00:00.000000000',
#         '2019-01-23T00:00:00.000000000', '2019-01-24T00:00:00.000000000',
#         '2019-01-31T00:00:00.000000000', '2019-02-02T00:00:00.000000000',
#         '2019-02-09T00:00:00.000000000', '2019-02-10T00:00:00.000000000',
#         '2019-02-21T00:00:00.000000000', '2019-02-23T00:00:00.000000000',
#         '2019-02-25T00:00:00.000000000', '2019-02-27T00:00:00.000000000',
#         '2019-03-01T00:00:00.000000000', '2019-03-06T00:00:00.000000000',
#         '2019-03-10T00:00:00.000000000', '2019-03-13T00:00:00.000000000',
#         '2019-03-15T00:00:00.000000000', '2019-03-26T00:00:00.000000000',
#         '2019-03-28T00:00:00.000000000', '2019-03-29T00:00:00.000000000',
#         '2019-04-03T00:00:00.000000000', '2019-04-06T00:00:00.000000000',
#         '2019-04-09T00:00:00.000000000', '2019-04-10T00:00:00.000000000',
#         '2019-04-11T00:00:00.000000000', '2019-04-13T00:00:00.000000000',
#         '2019-04-19T00:00:00.000000000', '2019-04-22T00:00:00.000000000',
#         '2019-04-23T00:00:00.000000000', '2019-04-24T00:00:00.000000000',
#         '2019-04-26T00:00:00.000000000', '2019-04-30T00:00:00.000000000',
#         '2019-05-01T00:00:00.000000000', '2019-05-02T00:00:00.000000000',
#         '2019-05-04T00:00:00.000000000', '2019-05-05T00:00:00.000000000',
#         '2019-05-06T00:00:00.000000000', '2019-05-08T00:00:00.000000000',
#         '2019-05-09T00:00:00.000000000', '2019-05-11T00:00:00.000000000',
#         '2019-05-12T00:00:00.000000000', '2019-05-18T00:00:00.000000000',
#         '2019-05-20T00:00:00.000000000', '2019-05-22T00:00:00.000000000',
#         '2019-05-23T00:00:00.000000000', '2019-05-31T00:00:00.000000000',
#         '2019-06-02T00:00:00.000000000', '2019-06-07T00:00:00.000000000',
#         '2019-06-09T00:00:00.000000000', '2019-06-13T00:00:00.000000000',
#         '2019-06-14T00:00:00.000000000', '2019-06-18T00:00:00.000000000',
#         '2019-06-19T00:00:00.000000000', '2019-06-20T00:00:00.000000000',
#         '2019-06-21T00:00:00.000000000', '2019-06-23T00:00:00.000000000',
#         '2019-06-25T00:00:00.000000000', '2019-06-26T00:00:00.000000000',
#         '2019-06-27T00:00:00.000000000', '2019-06-29T00:00:00.000000000',
#         '2019-07-01T00:00:00.000000000', '2019-07-02T00:00:00.000000000',
#         '2019-07-03T00:00:00.000000000', '2019-07-05T00:00:00.000000000',
#         '2019-07-11T00:00:00.000000000', '2019-07-16T00:00:00.000000000',
#         '2019-07-19T00:00:00.000000000', '2019-07-20T00:00:00.000000000',
#         '2019-07-22T00:00:00.000000000', '2019-07-23T00:00:00.000000000',
#         '2019-07-24T00:00:00.000000000', '2019-07-25T00:00:00.000000000',
#         '2019-07-26T00:00:00.000000000', '2019-07-27T00:00:00.000000000',
#         '2019-07-30T00:00:00.000000000', '2019-07-31T00:00:00.000000000',
#         '2019-08-01T00:00:00.000000000', '2019-08-02T00:00:00.000000000',
#         '2019-08-03T00:00:00.000000000', '2019-08-04T00:00:00.000000000',
#         '2019-08-05T00:00:00.000000000', '2019-08-07T00:00:00.000000000',
#         '2019-08-09T00:00:00.000000000', '2019-08-10T00:00:00.000000000',
#         '2019-08-11T00:00:00.000000000', '2019-08-12T00:00:00.000000000',
#         '2019-08-13T00:00:00.000000000', '2019-08-14T00:00:00.000000000',
#         '2019-08-15T00:00:00.000000000', '2019-08-17T00:00:00.000000000',
#         '2019-08-18T00:00:00.000000000', '2019-08-20T00:00:00.000000000',
#         '2019-08-21T00:00:00.000000000', '2019-08-22T00:00:00.000000000',
#         '2019-08-23T00:00:00.000000000', '2019-08-24T00:00:00.000000000',
#         '2019-08-25T00:00:00.000000000', '2019-08-26T00:00:00.000000000',
#         '2019-08-27T00:00:00.000000000', '2019-08-28T00:00:00.000000000',
#         '2019-08-29T00:00:00.000000000', '2019-08-30T00:00:00.000000000',
#         '2019-08-31T00:00:00.000000000', '2019-09-01T00:00:00.000000000',
#         '2019-09-03T00:00:00.000000000', '2019-09-04T00:00:00.000000000',
#         '2019-09-05T00:00:00.000000000', '2019-09-06T00:00:00.000000000',
#         '2019-09-07T00:00:00.000000000', '2019-09-08T00:00:00.000000000',
#         '2019-09-09T00:00:00.000000000', '2019-09-10T00:00:00.000000000',
#         '2019-09-11T00:00:00.000000000', '2019-09-12T00:00:00.000000000',
#         '2019-09-13T00:00:00.000000000', '2019-09-16T00:00:00.000000000',
#         '2019-09-17T00:00:00.000000000', '2019-09-18T00:00:00.000000000',
#         '2019-09-19T00:00:00.000000000', '2019-09-20T00:00:00.000000000',
#         '2019-09-21T00:00:00.000000000', '2019-09-22T00:00:00.000000000',
#         '2019-09-23T00:00:00.000000000', '2019-09-24T00:00:00.000000000',
#         '2019-09-25T00:00:00.000000000', '2019-09-26T00:00:00.000000000',
#         '2019-09-27T00:00:00.000000000', '2019-09-28T00:00:00.000000000',
#         '2019-09-29T00:00:00.000000000', '2019-10-01T00:00:00.000000000',
#         '2019-10-02T00:00:00.000000000', '2019-10-03T00:00:00.000000000',
#         '2019-10-04T00:00:00.000000000', '2019-10-05T00:00:00.000000000',
#         '2019-10-06T00:00:00.000000000', '2019-10-07T00:00:00.000000000',
#         '2019-10-08T00:00:00.000000000', '2019-10-09T00:00:00.000000000',
#         '2019-10-10T00:00:00.000000000', '2019-10-11T00:00:00.000000000',
#         '2019-10-12T00:00:00.000000000', '2019-10-13T00:00:00.000000000',
#         '2019-10-14T00:00:00.000000000', '2019-10-15T00:00:00.000000000',
#         '2019-10-16T00:00:00.000000000', '2019-10-17T00:00:00.000000000',
#         '2019-10-18T00:00:00.000000000', '2019-10-19T00:00:00.000000000',
#         '2019-10-20T00:00:00.000000000', '2019-10-21T00:00:00.000000000',
#         '2019-10-22T00:00:00.000000000', '2019-10-23T00:00:00.000000000',
#         '2019-10-24T00:00:00.000000000', '2019-10-25T00:00:00.000000000',
#         '2019-10-26T00:00:00.000000000', '2019-10-27T00:00:00.000000000',
#         '2019-10-28T00:00:00.000000000', '2019-10-29T00:00:00.000000000',
#         '2019-10-30T00:00:00.000000000', '2019-10-31T00:00:00.000000000',
#         '2019-11-01T00:00:00.000000000', '2019-11-02T00:00:00.000000000',
#         '2019-11-03T00:00:00.000000000', '2019-11-04T00:00:00.000000000',
#         '2019-11-05T00:00:00.000000000', '2019-11-06T00:00:00.000000000',
#         '2019-11-07T00:00:00.000000000', '2019-11-08T00:00:00.000000000',
#         '2019-11-09T00:00:00.000000000', '2019-11-10T00:00:00.000000000',
#         '2019-11-11T00:00:00.000000000', '2019-11-12T00:00:00.000000000',
#         '2019-11-13T00:00:00.000000000', '2019-11-14T00:00:00.000000000',
#         '2019-11-15T00:00:00.000000000', '2019-11-16T00:00:00.000000000',
#         '2019-11-17T00:00:00.000000000', '2019-11-18T00:00:00.000000000',
#         '2019-11-19T00:00:00.000000000', '2019-11-20T00:00:00.000000000',
#         '2019-11-21T00:00:00.000000000', '2019-11-22T00:00:00.000000000',
#         '2019-11-23T00:00:00.000000000', '2019-11-24T00:00:00.000000000',
#         '2019-11-25T00:00:00.000000000', '2019-11-26T00:00:00.000000000',
#         '2019-11-27T00:00:00.000000000', '2019-11-28T00:00:00.000000000',
#         '2019-11-29T00:00:00.000000000', '2019-11-30T00:00:00.000000000',
#         '2019-12-01T00:00:00.000000000', '2019-12-02T00:00:00.000000000',
#         '2019-12-03T00:00:00.000000000', '2019-12-04T00:00:00.000000000',
#         '2019-12-05T00:00:00.000000000', '2019-12-06T00:00:00.000000000',
#         '2019-12-07T00:00:00.000000000', '2019-12-08T00:00:00.000000000',
#         '2019-12-09T00:00:00.000000000', '2019-12-10T00:00:00.000000000',
#         '2019-12-11T00:00:00.000000000', '2019-12-12T00:00:00.000000000',
#         '2019-12-13T00:00:00.000000000', '2019-12-14T00:00:00.000000000',
#         '2019-12-15T00:00:00.000000000', '2019-12-16T00:00:00.000000000',
#         '2019-12-17T00:00:00.000000000', '2019-12-18T00:00:00.000000000',
#         '2019-12-19T00:00:00.000000000', '2019-12-20T00:00:00.000000000',
#         '2019-12-21T00:00:00.000000000', '2019-12-22T00:00:00.000000000',
#         '2019-12-23T00:00:00.000000000', '2019-12-24T00:00:00.000000000',
#         '2019-12-25T00:00:00.000000000', '2019-12-26T00:00:00.000000000',
#         '2019-12-27T00:00:00.000000000', '2019-12-28T00:00:00.000000000',
#         '2019-12-29T00:00:00.000000000', '2019-12-30T00:00:00.000000000',
#         '2019-12-31T00:00:00.000000000', '2020-01-01T00:00:00.000000000',
#         '2020-01-02T00:00:00.000000000', '2020-01-03T00:00:00.000000000',
#         '2020-01-04T00:00:00.000000000', '2020-01-05T00:00:00.000000000',
#         '2020-01-06T00:00:00.000000000', '2020-01-07T00:00:00.000000000',
#         '2020-01-08T00:00:00.000000000', '2020-01-09T00:00:00.000000000',
#         '2020-01-10T00:00:00.000000000', '2020-01-11T00:00:00.000000000',
#         '2020-01-12T00:00:00.000000000', '2020-01-13T00:00:00.000000000',
#         '2020-01-14T00:00:00.000000000', '2020-01-15T00:00:00.000000000',
#         '2020-01-16T00:00:00.000000000', '2020-01-17T00:00:00.000000000',
#         '2020-01-18T00:00:00.000000000', '2020-01-19T00:00:00.000000000',
#         '2020-01-20T00:00:00.000000000', '2020-01-21T00:00:00.000000000',
#         '2020-01-22T00:00:00.000000000', '2020-01-23T00:00:00.000000000',
#         '2020-01-24T00:00:00.000000000', '2020-01-25T00:00:00.000000000',
#         '2020-01-26T00:00:00.000000000', '2020-01-27T00:00:00.000000000',
#         '2020-01-28T00:00:00.000000000', '2020-01-29T00:00:00.000000000',
#         '2020-01-30T00:00:00.000000000', '2020-01-31T00:00:00.000000000',
#         '2020-02-01T00:00:00.000000000', '2020-02-02T00:00:00.000000000',
#         '2020-02-03T00:00:00.000000000', '2020-02-04T00:00:00.000000000',
#         '2020-02-05T00:00:00.000000000', '2020-02-06T00:00:00.000000000',
#         '2020-02-07T00:00:00.000000000', '2020-02-08T00:00:00.000000000',
#         '2020-02-09T00:00:00.000000000', '2020-02-10T00:00:00.000000000',
#         '2020-02-11T00:00:00.000000000', '2020-02-12T00:00:00.000000000',
#         '2020-02-13T00:00:00.000000000', '2020-02-14T00:00:00.000000000',
#         '2020-02-15T00:00:00.000000000', '2020-02-16T00:00:00.000000000',
#         '2020-02-17T00:00:00.000000000', '2020-02-18T00:00:00.000000000',
#         '2020-02-19T00:00:00.000000000', '2020-02-20T00:00:00.000000000',
#         '2020-02-21T00:00:00.000000000', '2020-02-22T00:00:00.000000000',
#         '2020-02-23T00:00:00.000000000', '2020-02-24T00:00:00.000000000',
#         '2020-02-25T00:00:00.000000000', '2020-02-26T00:00:00.000000000',
#         '2020-02-27T00:00:00.000000000', '2020-02-28T00:00:00.000000000',
#         '2020-02-29T00:00:00.000000000', '2020-03-01T00:00:00.000000000',
#         '2020-03-02T00:00:00.000000000', '2020-03-03T00:00:00.000000000',
#         '2020-03-04T00:00:00.000000000', '2020-03-05T00:00:00.000000000',
#         '2020-03-06T00:00:00.000000000', '2020-03-07T00:00:00.000000000',
#         '2020-03-08T00:00:00.000000000', '2020-03-09T00:00:00.000000000',
#         '2020-03-10T00:00:00.000000000', '2020-03-11T00:00:00.000000000',
#         '2020-03-12T00:00:00.000000000', '2020-03-13T00:00:00.000000000',
#         '2020-03-14T00:00:00.000000000', '2020-03-15T00:00:00.000000000',
#         '2020-03-16T00:00:00.000000000', '2020-03-17T00:00:00.000000000',
#         '2020-03-18T00:00:00.000000000', '2020-03-19T00:00:00.000000000',
#         '2020-03-20T00:00:00.000000000', '2020-03-21T00:00:00.000000000',
#         '2020-03-22T00:00:00.000000000', '2020-03-23T00:00:00.000000000',
#         '2020-03-24T00:00:00.000000000', '2020-03-25T00:00:00.000000000',
#         '2020-03-26T00:00:00.000000000', '2020-03-27T00:00:00.000000000',
#         '2020-03-28T00:00:00.000000000', '2020-03-29T00:00:00.000000000',
#         '2020-03-30T00:00:00.000000000', '2020-03-31T00:00:00.000000000',
#         '2020-04-01T00:00:00.000000000', '2020-04-02T00:00:00.000000000',
#         '2020-04-03T00:00:00.000000000', '2020-04-04T00:00:00.000000000',
#         '2020-04-05T00:00:00.000000000', '2020-04-06T00:00:00.000000000',
#         '2020-04-07T00:00:00.000000000', '2020-04-08T00:00:00.000000000',
#         '2020-04-09T00:00:00.000000000', '2020-04-10T00:00:00.000000000',
#         '2020-04-11T00:00:00.000000000', '2020-04-12T00:00:00.000000000',
#         '2020-04-13T00:00:00.000000000', '2020-04-14T00:00:00.000000000',
#         '2020-04-15T00:00:00.000000000', '2020-04-16T00:00:00.000000000',
#         '2020-04-17T00:00:00.000000000', '2020-04-18T00:00:00.000000000',
#         '2020-04-19T00:00:00.000000000', '2020-04-20T00:00:00.000000000',
#         '2020-04-21T00:00:00.000000000', '2020-04-22T00:00:00.000000000',
#         '2020-04-23T00:00:00.000000000', '2020-04-24T00:00:00.000000000',
#         '2020-04-25T00:00:00.000000000', '2020-04-26T00:00:00.000000000',
#         '2020-04-27T00:00:00.000000000', '2020-04-28T00:00:00.000000000',
#         '2020-04-29T00:00:00.000000000', '2020-04-30T00:00:00.000000000',
#         '2020-05-01T00:00:00.000000000', '2020-05-02T00:00:00.000000000',
#         '2020-05-03T00:00:00.000000000', '2020-05-04T00:00:00.000000000',
#         '2020-05-05T00:00:00.000000000', '2020-05-06T00:00:00.000000000',
#         '2020-05-07T00:00:00.000000000', '2020-05-08T00:00:00.000000000',
#         '2020-05-09T00:00:00.000000000', '2020-05-10T00:00:00.000000000',
#         '2020-05-11T00:00:00.000000000', '2020-05-12T00:00:00.000000000',
#         '2020-05-13T00:00:00.000000000', '2020-05-14T00:00:00.000000000',
#         '2020-05-15T00:00:00.000000000', '2020-05-16T00:00:00.000000000',
#         '2020-05-17T00:00:00.000000000', '2020-05-18T00:00:00.000000000',
#         '2020-05-19T00:00:00.000000000', '2020-05-20T00:00:00.000000000',
#         '2020-05-21T00:00:00.000000000', '2020-05-22T00:00:00.000000000',
#         '2020-05-23T00:00:00.000000000', '2020-05-24T00:00:00.000000000',
#         '2020-05-25T00:00:00.000000000', '2020-05-26T00:00:00.000000000',
#         '2020-05-27T00:00:00.000000000', '2020-05-28T00:00:00.000000000',
#         '2020-05-29T00:00:00.000000000', '2020-05-30T00:00:00.000000000',
#         '2020-05-31T00:00:00.000000000', '2020-06-01T00:00:00.000000000',
#         '2020-06-02T00:00:00.000000000', '2020-06-03T00:00:00.000000000',
#         '2020-06-04T00:00:00.000000000', '2020-06-05T00:00:00.000000000',
#         '2020-06-06T00:00:00.000000000', '2020-06-07T00:00:00.000000000',
#         '2020-06-08T00:00:00.000000000', '2020-06-09T00:00:00.000000000',
#         '2020-06-10T00:00:00.000000000', '2020-06-11T00:00:00.000000000',
#         '2020-06-12T00:00:00.000000000', '2020-06-13T00:00:00.000000000',
#         '2020-06-14T00:00:00.000000000', '2020-06-15T00:00:00.000000000',
#         '2020-06-16T00:00:00.000000000', '2020-06-17T00:00:00.000000000',
#         '2020-06-18T00:00:00.000000000', '2020-06-19T00:00:00.000000000',
#         '2020-06-20T00:00:00.000000000', '2020-06-21T00:00:00.000000000',
#         '2020-06-22T00:00:00.000000000', '2020-06-23T00:00:00.000000000',
#         '2020-06-24T00:00:00.000000000', '2020-06-25T00:00:00.000000000',
#         '2020-06-26T00:00:00.000000000', '2020-06-27T00:00:00.000000000',
#         '2020-06-28T00:00:00.000000000', '2020-06-29T00:00:00.000000000',
#         '2020-06-30T00:00:00.000000000', '2020-07-01T00:00:00.000000000',
#         '2020-07-02T00:00:00.000000000', '2020-07-03T00:00:00.000000000',
#         '2020-07-04T00:00:00.000000000', '2020-07-05T00:00:00.000000000',
#         '2020-07-06T00:00:00.000000000', '2020-07-07T00:00:00.000000000',
#         '2020-07-08T00:00:00.000000000', '2020-07-09T00:00:00.000000000',
#         '2020-07-10T00:00:00.000000000', '2020-07-11T00:00:00.000000000',
#         '2020-07-12T00:00:00.000000000', '2020-07-13T00:00:00.000000000',
#         '2020-07-14T00:00:00.000000000', '2020-07-15T00:00:00.000000000',
#         '2020-07-16T00:00:00.000000000', '2020-07-17T00:00:00.000000000',
#         '2020-07-18T00:00:00.000000000', '2020-07-19T00:00:00.000000000',
#         '2020-07-20T00:00:00.000000000', '2020-07-21T00:00:00.000000000',
#         '2020-07-22T00:00:00.000000000', '2020-07-23T00:00:00.000000000',
#         '2020-07-24T00:00:00.000000000', '2020-07-25T00:00:00.000000000',
#         '2020-07-26T00:00:00.000000000', '2020-07-27T00:00:00.000000000',
#         '2020-07-28T00:00:00.000000000', '2020-07-29T00:00:00.000000000',
#         '2020-07-30T00:00:00.000000000', '2020-07-31T00:00:00.000000000',
#         '2020-08-01T00:00:00.000000000', '2020-08-02T00:00:00.000000000',
#         '2020-08-03T00:00:00.000000000', '2020-08-04T00:00:00.000000000',
#         '2020-08-05T00:00:00.000000000', '2020-08-06T00:00:00.000000000',
#         '2020-08-07T00:00:00.000000000', '2020-08-08T00:00:00.000000000',
#         '2020-08-09T00:00:00.000000000', '2020-08-10T00:00:00.000000000',
#         '2020-08-11T00:00:00.000000000', '2020-08-12T00:00:00.000000000',
#         '2020-08-13T00:00:00.000000000', '2020-08-14T00:00:00.000000000',
#         '2020-08-15T00:00:00.000000000', '2020-08-16T00:00:00.000000000',
#         '2020-08-17T00:00:00.000000000', '2020-08-18T00:00:00.000000000',
#         '2020-08-19T00:00:00.000000000', '2020-08-20T00:00:00.000000000',
#         '2020-08-21T00:00:00.000000000', '2020-08-22T00:00:00.000000000',
#         '2020-08-23T00:00:00.000000000', '2020-08-24T00:00:00.000000000',
#         '2020-08-25T00:00:00.000000000', '2020-08-26T00:00:00.000000000',
#         '2020-08-27T00:00:00.000000000', '2020-08-28T00:00:00.000000000',
#         '2020-08-29T00:00:00.000000000', '2020-08-30T00:00:00.000000000',
#         '2020-08-31T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
#         '2020-09-02T00:00:00.000000000', '2020-09-03T00:00:00.000000000',
#         '2020-09-04T00:00:00.000000000', '2020-09-05T00:00:00.000000000',
#         '2020-09-06T00:00:00.000000000', '2020-09-07T00:00:00.000000000',
#         '2020-09-08T00:00:00.000000000', '2020-09-09T00:00:00.000000000',
#         '2020-09-10T00:00:00.000000000', '2020-09-11T00:00:00.000000000',
#         '2020-09-12T00:00:00.000000000', '2020-09-13T00:00:00.000000000',
#         '2020-09-14T00:00:00.000000000', '2020-09-15T00:00:00.000000000',
#         '2020-09-16T00:00:00.000000000', '2020-09-17T00:00:00.000000000',
#         '2020-09-18T00:00:00.000000000', '2020-09-19T00:00:00.000000000',
#         '2020-09-20T00:00:00.000000000', '2020-09-21T00:00:00.000000000',
#         '2020-09-22T00:00:00.000000000', '2020-09-23T00:00:00.000000000',
#         '2020-09-24T00:00:00.000000000', '2020-09-25T00:00:00.000000000',
#         '2020-09-26T00:00:00.000000000', '2020-09-27T00:00:00.000000000',
#         '2020-09-28T00:00:00.000000000', '2020-09-29T00:00:00.000000000',
#         '2020-09-30T00:00:00.000000000', '2020-10-01T00:00:00.000000000',
#         '2020-10-02T00:00:00.000000000', '2020-10-03T00:00:00.000000000',
#         '2020-10-04T00:00:00.000000000', '2020-10-05T00:00:00.000000000',
#         '2020-10-06T00:00:00.000000000', '2020-10-07T00:00:00.000000000',
#         '2020-10-08T00:00:00.000000000', '2020-10-09T00:00:00.000000000',
#         '2020-10-10T00:00:00.000000000', '2020-10-11T00:00:00.000000000',
#         '2020-10-12T00:00:00.000000000', '2020-10-13T00:00:00.000000000',
#         '2020-10-14T00:00:00.000000000', '2020-10-15T00:00:00.000000000',
#         '2020-10-16T00:00:00.000000000', '2020-10-17T00:00:00.000000000',
#         '2020-10-18T00:00:00.000000000', '2020-10-19T00:00:00.000000000',
#         '2020-10-20T00:00:00.000000000', '2020-10-21T00:00:00.000000000',
#         '2020-10-22T00:00:00.000000000', '2020-10-23T00:00:00.000000000',
#         '2020-10-24T00:00:00.000000000', '2020-10-25T00:00:00.000000000',
#         '2020-10-26T00:00:00.000000000', '2020-10-27T00:00:00.000000000',
#         '2020-10-28T00:00:00.000000000', '2020-10-29T00:00:00.000000000',
#         '2020-10-30T00:00:00.000000000', '2020-10-31T00:00:00.000000000',
#         '2020-11-01T00:00:00.000000000', '2020-11-02T00:00:00.000000000',
#         '2020-11-03T00:00:00.000000000', '2020-11-04T00:00:00.000000000',
#         '2020-11-05T00:00:00.000000000', '2020-11-06T00:00:00.000000000',
#         '2020-11-07T00:00:00.000000000', '2020-11-08T00:00:00.000000000',
#         '2020-11-09T00:00:00.000000000', '2020-11-10T00:00:00.000000000',
#         '2020-11-11T00:00:00.000000000', '2020-11-12T00:00:00.000000000',
#         '2020-11-13T00:00:00.000000000', '2020-11-14T00:00:00.000000000',
#         '2020-11-15T00:00:00.000000000', '2020-11-16T00:00:00.000000000',
#         '2020-11-17T00:00:00.000000000', '2020-11-18T00:00:00.000000000',
#         '2020-11-19T00:00:00.000000000', '2020-11-20T00:00:00.000000000',
#         '2020-11-21T00:00:00.000000000', '2020-11-22T00:00:00.000000000',
#         '2020-11-23T00:00:00.000000000', '2020-11-24T00:00:00.000000000',
#         '2020-11-25T00:00:00.000000000', '2020-11-26T00:00:00.000000000',
#         '2020-11-27T00:00:00.000000000', '2020-11-28T00:00:00.000000000',
#         '2020-11-29T00:00:00.000000000', '2020-11-30T00:00:00.000000000',
#         '2020-12-01T00:00:00.000000000', '2020-12-02T00:00:00.000000000',
#         '2020-12-03T00:00:00.000000000', '2020-12-04T00:00:00.000000000',
#         '2020-12-05T00:00:00.000000000', '2020-12-06T00:00:00.000000000',
#         '2020-12-07T00:00:00.000000000', '2020-12-08T00:00:00.000000000',
#         '2020-12-09T00:00:00.000000000', '2020-12-10T00:00:00.000000000',
#         '2020-12-11T00:00:00.000000000', '2020-12-12T00:00:00.000000000',
#         '2020-12-13T00:00:00.000000000', '2020-12-14T00:00:00.000000000',
#         '2020-12-15T00:00:00.000000000', '2020-12-16T00:00:00.000000000',
#         '2020-12-17T00:00:00.000000000', '2020-12-18T00:00:00.000000000',
#         '2020-12-19T00:00:00.000000000', '2020-12-20T00:00:00.000000000',
#         '2020-12-21T00:00:00.000000000', '2020-12-22T00:00:00.000000000',
#         '2020-12-23T00:00:00.000000000', '2020-12-24T00:00:00.000000000',
#         '2020-12-25T00:00:00.000000000', '2020-12-26T00:00:00.000000000',
#         '2020-12-27T00:00:00.000000000', '2020-12-28T00:00:00.000000000',
#         '2020-12-29T00:00:00.000000000', '2020-12-30T00:00:00.000000000',
#         '2020-12-31T00:00:00.000000000', '2021-01-01T00:00:00.000000000',
#         '2021-01-02T00:00:00.000000000', '2021-01-03T00:00:00.000000000',
#         '2021-01-04T00:00:00.000000000', '2021-01-05T00:00:00.000000000',
#         '2021-01-06T00:00:00.000000000', '2021-01-07T00:00:00.000000000',
#         '2021-01-08T00:00:00.000000000', '2021-01-09T00:00:00.000000000',
#         '2021-01-10T00:00:00.000000000', '2021-01-11T00:00:00.000000000',
#         '2021-01-12T00:00:00.000000000', '2021-01-13T00:00:00.000000000',
#         '2021-01-14T00:00:00.000000000', '2021-01-15T00:00:00.000000000',
#         '2021-01-16T00:00:00.000000000', '2021-01-17T00:00:00.000000000',
#         '2021-01-18T00:00:00.000000000', '2021-01-19T00:00:00.000000000',
#         '2021-01-20T00:00:00.000000000', '2021-01-21T00:00:00.000000000',
#         '2021-01-22T00:00:00.000000000', '2021-01-23T00:00:00.000000000',
#         '2021-01-24T00:00:00.000000000', '2021-01-25T00:00:00.000000000',
#         '2021-01-26T00:00:00.000000000', '2021-01-27T00:00:00.000000000',
#         '2021-01-28T00:00:00.000000000', '2021-01-29T00:00:00.000000000',
#         '2021-01-30T00:00:00.000000000', '2021-01-31T00:00:00.000000000',
#         '2021-02-01T00:00:00.000000000', '2021-02-02T00:00:00.000000000',
#         '2021-02-03T00:00:00.000000000', '2021-02-04T00:00:00.000000000',
#         '2021-02-05T00:00:00.000000000', '2021-02-06T00:00:00.000000000',
#         '2021-02-07T00:00:00.000000000', '2021-02-08T00:00:00.000000000',
#         '2021-02-09T00:00:00.000000000', '2021-02-10T00:00:00.000000000',
#         '2021-02-11T00:00:00.000000000', '2021-02-12T00:00:00.000000000',
#         '2021-02-13T00:00:00.000000000', '2021-02-14T00:00:00.000000000',
#         '2021-02-15T00:00:00.000000000', '2021-02-16T00:00:00.000000000',
#         '2021-02-17T00:00:00.000000000', '2021-02-18T00:00:00.000000000',
#         '2021-02-19T00:00:00.000000000', '2021-02-20T00:00:00.000000000',
#         '2021-02-21T00:00:00.000000000', '2021-02-22T00:00:00.000000000',
#         '2021-02-23T00:00:00.000000000', '2021-02-24T00:00:00.000000000',
#         '2021-02-25T00:00:00.000000000', '2021-02-26T00:00:00.000000000',
#         '2021-02-27T00:00:00.000000000', '2021-02-28T00:00:00.000000000',
#         '2021-03-01T00:00:00.000000000', '2021-03-02T00:00:00.000000000',
#         '2021-03-03T00:00:00.000000000', '2021-03-04T00:00:00.000000000',
#         '2021-03-05T00:00:00.000000000', '2021-03-06T00:00:00.000000000',
#         '2021-03-07T00:00:00.000000000', '2021-03-08T00:00:00.000000000',
#         '2021-03-09T00:00:00.000000000', '2021-03-10T00:00:00.000000000',
#         '2021-03-11T00:00:00.000000000', '2021-03-12T00:00:00.000000000',
#         '2021-03-13T00:00:00.000000000', '2021-03-14T00:00:00.000000000',
#         '2021-03-15T00:00:00.000000000', '2021-03-16T00:00:00.000000000',
#         '2021-03-17T00:00:00.000000000', '2021-03-18T00:00:00.000000000',
#         '2021-03-19T00:00:00.000000000', '2021-03-20T00:00:00.000000000',
#         '2021-03-21T00:00:00.000000000', '2021-03-22T00:00:00.000000000',
#         '2021-03-23T00:00:00.000000000', '2021-03-24T00:00:00.000000000',
#         '2021-03-25T00:00:00.000000000', '2021-03-26T00:00:00.000000000',
#         '2021-03-27T00:00:00.000000000', '2021-03-28T00:00:00.000000000',
#         '2021-03-29T00:00:00.000000000', '2021-03-30T00:00:00.000000000',
#         '2021-03-31T00:00:00.000000000', '2021-04-01T00:00:00.000000000',
#         '2021-04-02T00:00:00.000000000', '2021-04-03T00:00:00.000000000',
#         '2021-04-04T00:00:00.000000000', '2021-04-05T00:00:00.000000000',
#         '2021-04-06T00:00:00.000000000', '2021-04-07T00:00:00.000000000',
#         '2021-04-08T00:00:00.000000000', '2021-04-09T00:00:00.000000000',
#         '2021-04-10T00:00:00.000000000', '2021-04-11T00:00:00.000000000',
#         '2021-04-12T00:00:00.000000000', '2021-04-13T00:00:00.000000000',
#         '2021-04-14T00:00:00.000000000', '2021-04-15T00:00:00.000000000',
#         '2021-04-16T00:00:00.000000000', '2021-04-17T00:00:00.000000000',
#         '2021-04-18T00:00:00.000000000', '2021-04-19T00:00:00.000000000',
#         '2021-04-20T00:00:00.000000000', '2021-04-21T00:00:00.000000000',
#         '2021-04-22T00:00:00.000000000', '2021-04-23T00:00:00.000000000',
#         '2021-04-24T00:00:00.000000000', '2021-04-25T00:00:00.000000000',
#         '2021-04-26T00:00:00.000000000', '2021-04-27T00:00:00.000000000',
#         '2021-04-28T00:00:00.000000000', '2021-04-29T00:00:00.000000000',
#         '2021-04-30T00:00:00.000000000', '2021-05-01T00:00:00.000000000',
#         '2021-05-02T00:00:00.000000000', '2021-05-03T00:00:00.000000000',
#         '2021-05-04T00:00:00.000000000', '2021-05-05T00:00:00.000000000',
#         '2021-05-06T00:00:00.000000000', '2021-05-07T00:00:00.000000000',
#         '2021-05-08T00:00:00.000000000', '2021-05-09T00:00:00.000000000',
#         '2021-05-10T00:00:00.000000000', '2021-05-11T00:00:00.000000000',
#         '2021-05-12T00:00:00.000000000', '2021-05-13T00:00:00.000000000',
#         '2021-05-14T00:00:00.000000000', '2021-05-15T00:00:00.000000000',
#         '2021-05-16T00:00:00.000000000', '2021-05-17T00:00:00.000000000',
#         '2021-05-18T00:00:00.000000000', '2021-05-19T00:00:00.000000000',
#         '2021-05-20T00:00:00.000000000', '2021-05-21T00:00:00.000000000',
#         '2021-05-22T00:00:00.000000000', '2021-05-23T00:00:00.000000000',
#         '2021-05-24T00:00:00.000000000', '2021-05-25T00:00:00.000000000',
#         '2021-05-26T00:00:00.000000000', '2021-05-27T00:00:00.000000000',
#         '2021-05-28T00:00:00.000000000', '2021-05-29T00:00:00.000000000',
#         '2021-05-30T00:00:00.000000000', '2021-05-31T00:00:00.000000000',
#         '2021-06-01T00:00:00.000000000', '2021-06-02T00:00:00.000000000',
# ...
#         'IGNORED', 'imputed'], dtype=object),
#  array(['0 - VERY RARELY OR NEVER HAS BOWEL INCONTINENCE ',
#         '1 - LESS THAN ONCE WEEKLY ', '2 - ONE TO THREE TIMES WEEKLY ',
#         '3 - FOUR TO SIX TIMES WEEKLY ', '4 - ON A DAILY BASIS ',
#         '5 - MORE OFTEN THAN ONCE DAILY ',
#         'NA - PATIENT HAS OSTOMY FOR BOWEL ELIMINATION', 'UK - UNKNOWN',
#         'imputed'], dtype=object),
#  array(['0 - PATIENT DOES NOT HAVE AN OSTOMY FOR BOWEL ELIMINATION. ',
#         "1 - PATIENT'S OSTOMY WAS NOT RELATED TO AN INPATIENT STAY AND DID NOT NECESSITATE CHANGE IN MEDICAL OR TREATMENT REGIMEN. ",
#         '2 - THE OSTOMY WAS RELATED TO AN INPATIENT STAY OR DID NECESSITATE CHANGE IN MEDICAL OR TREATMENT REGIMEN.',
#         'imputed'], dtype=object),
#  array(['0 - ALERT/ORIENTED, ABLE TO FOCUS AND SHIFT ATTENTION, COMPREHENDS AND RECALLS TASK DIRECTIONS INDEPENDENTLY. ',
#         '1 - REQUIRES PROMPTING (CUING, REPETITION, REMINDERS) ONLY UNDER STRESSFUL OR UNFAMILIAR CONDITIONS. ',
#         '2 - REQUIRES ASSISTANCE AND SOME DIRECTION IN SPECIFIC SITUATIONS (FOR EXAMPLE,  ON ALL TASKS INVOLVING SHIFTING OF ATTENTION), OR CONSISTENTLY REQUIRES LOW STIMULUS ENVIRONMENT DUE TO DISTRACTIBILITY. ',
#         '3 - REQUIRES CONSIDERABLE ASSISTANCE IN ROUTINE SITUATIONS. IS NOT ALERT AND ORIENTED OR IS UNABLE TO SHIFT ATTENTION AND RECALL DIRECTIONS MORE THAN HALF THE TIME.',
#         '4 - TOTALLY DEPENDENT DUE TO DISTURBANCES SUCH AS CONSTANT DISORIENTATION, COMA, PERSISTENT VEGETATIVE STATE, OR DELIRIUM.',
#         'imputed'], dtype=object),
#  array(['0 - NEVER ', '1 - IN NEW OR COMPLEX SITUATIONS ONLY ',
#         '2 - ON AWAKENING OR AT NIGHT ONLY ',
#         '3 - DURING THE DAY AND EVENING, BUT NOT CONSTANTLY ',
#         '4 - CONSTANTLY', 'NA - PATIENT NONRESPONSIVE', 'imputed'],
#        dtype=object),
#  array(['0 - NONE OF THE TIME', '1 - LESS OFTEN THAN DAILY ',
#         '2 - DAILY, BUT NOT CONSTANTLY', '3 - ALL OF THE TIME ',
#         'NA - PATIENT NONRESPONSIVE', 'imputed'], dtype=object),
#  array(['0 - NOT AT ALL (0 - 1 DAY) ', '1 - SEVERAL DAYS (2 - 6 DAYS) ',
#         '2 - MORE THAN HALF OF THE DAYS (7 - 11 DAYS) ',
#         '3 - NEARLY EVERY DAY (12 - 14 DAYS) ', 'N/A - UNABLE TO RESPOND',
#         'imputed'], dtype=object),
#  array(['0 - NOT AT ALL (0 - 1 DAY) ', '1 - SEVERAL DAYS (2 - 6 DAYS) ',
#         '2 - MORE THAN HALF OF THE DAYS (7 - 11 DAYS) ',
#         '3 - NEARLY EVERY DAY (12 - 14 DAYS) ', 'N/A - UNABLE TO RESPOND',
#         'imputed'], dtype=object),
#  array(['0 - NO',
#         '1 - YES, PATIENT WAS SCREENED USING THE PHQ-2(c) SCALE. (INSTRUCTIONS FOR THIS TWO-QUESTION TOOL: ASK PATIENT: "OVER THE LAST TWO WEEKS, HOW OFTEN HAVE YOU BEEN BOTHERED BY ANY OF THE FOLLOWING PROBLEMS")',
#         '2 - YES, PATIENT WAS SCREENED WITH A DIFFERENT STANDARDIZED, VALIDATED ASSESSMENT AND THE PATIENT MEETS CRITERIA FOR FURTHER EVALUATION FOR DEPRESSION.',
#         '3 - YES, PATIENT WAS SCREENED WITH A DIFFERENT STANDARDIZED, VALIDATED ASSESSMENT AND THE PATIENT DOES NOT MEET CRITERIA FOR FURTHER EVALUATION FOR DEPRESSION.',
#         'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['0 - NEVER', '1 - LESS THAN ONCE A MONTH', '2 - ONCE A MONTH',
#         '3 - SEVERAL TIMES EACH MONTH', '4 - SEVERAL TIMES A WEEK',
#         '5 - AT LEAST DAILY', 'imputed'], dtype=object),
#  array(['0 - ABLE TO GROOM SELF UNAIDED, WITH OR WITHOUT THE USE OF ASSISTIVE DEVICES OR ADAPTED METHODS',
#         '1 - GROOMING UTENSILS MUST BE PLACED WITHIN REACH BEFORE ABLE TO COMPLETE GROOMING ACTIVITIES',
#         '2 - SOMEONE MUST ASSIST THE PATIENT TO GROOM SELF',
#         '3 - PATIENT DEPENDS ENTIRELY UPON SOMEONE ELSE FOR GROOMING NEEDS',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO GET CLOTHES OUT OF CLOSETS AND DRAWERS, PUT THEM ON AND REMOVE THEM FROM THE UPPER BODY WITHOUT ASSISTANCE',
#         '1 - ABLE TO DRESS UPPER BODY WITHOUT ASSISTANCE IF CLOTHING IS LAID OUT OR HANDED TO THE PATIENT',
#         '2 - SOMEONE MUST HELP THE PATIENT PUT ON UPPER BODY CLOTHING',
#         '3 - PATIENT DEPENDS ENTIRELY UPON ANOTHER PERSON TO DRESS UPPER BODY',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO OBTAIN, PUT ON, AND REMOVE CLOTHING AND SHOES WITHOUT ASSISTANCE',
#         '1 - ABLE TO DRESS LOWER BODY WITHOUT ASSISTANCE IF CLOTHING AND SHOES ARE LAID OUT OR HANDED TO THE PATIENT',
#         '2 - SOMEONE MUST HELP PATIENT PUT ON UNDERGARMENTS, SLACKS, SOCKS OR NYLONS, AND SHOES',
#         '3 - PATIENT DEPENDS ENTIRELY UPON ANOTHER PERSON TO DRESS LOWER BODY',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO BATHE SELF IN SHOWER OR TUB INDEPENDENTLY, INCLUDING GETTING IN AND OUT OF TUB/SHOWER.',
#         '1 - WITH THE USE OF DEVICES, IS ABLE TO BATHE SELF IN SHOWER OR TUB INDEPENDENTLY, INCLUDING GETTING IN AND OUT OF THE TUB/SHOWER. ',
#         '2 - ABLE TO BATHE IN SHOWER OR TUB WITH THE INTERMITTENT ASSISTANCE OF ANOTHER PERSON: (A) FOR INTERMITTENT SUPERVISION OR ENCOURAGEMENT OR REMINDERS, OR (B) TO GET IN AND OUT OF THE SHOWER OR TUB, OR (C) FOR WASHING DIFFICULT TO REACH AREAS. ',
#         '3 - ABLE TO PARTICIPATE IN BATHING SELF IN SHOWER OR TUB, BUT REQUIRES PRESENCE OF ANOTHER PERSON THROUGHOUT THE BATH FOR ASSISTANCE OR SUPERVISION. ',
#         '4 - UNABLE TO USE THE SHOWER OR TUB, BUT ABLE TO BATHE SELF INDEPENDENTLY, WITH OR WITHOUT THE USE OF DEVICES, AT THE SINK, IN CHAIR, OR ON COMMODE. ',
#         '5 - UNABLE TO USE THE SHOWER OR TUB, BUT ABLE TO PARTICIPATE IN BATHING SELF IN BED, AT THE SINK, IN BEDSIDE CHAIR, OR ON COMMODE, WITH THE ASSISTANCE OR SUPERVISION OF ANOTHER PERSON.',
#         '6 - UNABLE TO PARTICIPATE EFFECTIVELY IN BATHING AND IS BATHED TOTALLY BY ANOTHER PERSON.',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO GET TO AND FROM THE TOILET AND TRANSFER INDEPENDENTLY WITH OR WITHOUT A DEVICE. ',
#         '1 - WHEN REMINDED, ASSISTED, OR SUPERVISED BY ANOTHER PERSON, ABLE TO GET TO AND FROM THE TOILET AND TRANSFER. ',
#         '2 - UNABLE TO GET TO AND FROM THE TOILET BUT IS ABLE TO USE A BEDSIDE COMMODE (WITH OR WITHOUT ASSISTANCE). ',
#         '3 - UNABLE TO GET TO AND FROM THE TOILET OR BEDSIDE COMMODE BUT IS ABLE TO USE A BEDPAN/URINAL INDEPENDENTLY. ',
#         '4 - IS TOTALLY DEPENDENT IN TOILETING.', 'imputed'], dtype=object),
#  array(['0 - ABLE TO MANAGE TOILETING HYGIENE AND CLOTHING MANAGEMENT WITHOUT ASSISTANCE.',
#         '1 - ABLE TO MANAGE TOILETING HYGIENE AND CLOTHING MANAGEMENT WITHOUT ASSISTANCE IF SUPPLIES/IMPLEMENTS ARE LAID OUT FOR THE PATIENT. ',
#         '2 -SOMEONE MUST HELP THE PATIENT TO MAINTAIN TOILETING HYGIENE AND/OR ADJUST CLOTHING. ',
#         '3 - PATIENT DEPENDS ENTIRELY UPON ANOTHER PERSON TO MAINTAIN TOILETING HYGIENE.',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY TRANSFER',
#         '1 - ABLE TO TRANSFER WITH MINIMAL HUMAN ASSISTANCE OR WITH USE OF AN ASSISTIVE DEVICE',
#         '2 - ABLE TO BEAR WEIGHT AND PIVOT DURING THE TRANSFER PROCESS BUT UNABLE TO TRANSFER SELF',
#         '3 - UNABLE TO TRANSFER SELF AND IS UNABLE TO BEAR WEIGHT OR PIVOT WHEN TRANSFERRED BY ANOTHER PERSON',
#         '4 - BEDFAST, UNABLE TO TRANSFER BUT IS ABLE TO TURN AND POSITION SELF IN BED',
#         '5 - BEDFAST, UNABLE TO TRANSFER AND IS UNABLE TO TURN AND POSITION SELF',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY WALK ON EVEN AND UNEVEN SURFACES AND NEGOTIATE STAIRS WITH OR WITHOUT RAILINGS (SPECIFICALLY: NEEDS NO HUMAN ASSISTANCE OR ASSISTIVE DEVICE).',
#         '1 - WITH THE USE OF A ONE-HANDED DEVICE (FOR EXAMPLE, CANE, SINGLE CRUTCH, HEMI-WALKER), ABLE TO INDEPENDENTLY WALK ON EVEN AND UNEVEN SURFACES AND NEGOTIATE STAIRS WITH OR WITHOUT RAILINGS.',
#         '2 - REQUIRES USE OF A TWO-HANDED DEVICE (FOR EXAMPLE, WALKER OR CRUTCHES) TO WALK ALONE ON A LEVEL SURFACE AND/OR REQUIRES HUMAN SUPERVISION OR ASSISTANCE TO NEGOTIATE STAIRS OR STEPS OR UNEVEN SURFACES.',
#         '3 - ABLE TO WALK ONLY WITH THE SUPERVISION OR ASSISTANCE OF ANOTHER PERSON AT ALL TIMES. ',
#         '4 - CHAIRFAST, UNABLE TO AMBULATE BUT IS ABLE TO WHEEL SELF INDEPENDENTLY. ',
#         '5 - CHAIRFAST, UNABLE TO AMBULATE AND IS UNABLE TO WHEEL SELF. ',
#         '6 - BEDFAST, UNABLE TO AMBULATE OR BE UP IN A CHAIR', 'imputed'],
#        dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY FEED SELF',
#         '1 - ABLE TO FEED SELF INDEPENDENTLY BUT REQUIRES: (A) MEAL SET-UP; OR (B) INTERMITTENT ASSISTANCE OR SUPERVISION FROM ANOTHER PERSON; OR (C) A LIQUID, PUREED OR GROUND MEAT DIET',
#         '2 - UNABLE TO FEED SELF AND MUST BE ASSISTED OR SUPERVISED THROUGHOUT THE MEAL/SNACK',
#         '3 - ABLE TO TAKE IN NUTRIENTS ORALLY AND RECEIVES SUPPLEMENTAL NUTRIENTS THROUGH A NASOGASTRIC TUBE OR GASTROSTOMY',
#         '4 - UNABLE TO TAKE IN NUTRIENTS ORALLY AND IS FED NUTRIENTS THROUGH NASOGASTRIC TUBE OR GASTROSTOMY',
#         '5 - UNABLE TO TAKE IN NUTRIENTS ORALLY OR BY TUBE FEEDING',
#         'imputed'], dtype=object),
#  array(['0 - NO.', '1 -YES, AND IT DOES NOT INDICATE A RISK FOR FALLS. ',
#         '2 - YES, AND IT DOES INDICATE A RISK FOR FALLS.', 'imputed'],
#        dtype=object),
#  array(['-', '0 - NO - NO ISSUES FOUND DURING REVIEW',
#         '1 - YES - ISSUES FOUND DURING REVIEW',
#         '9 - NA - PATIENT IS NOT TAKING ANY MEDICATIONS', 'imputed'],
#        dtype=object),
#  array(['-', '0 - NO', '1 - YES', 'imputed'], dtype=object),
#  array(['-', '0 - NO', '1 - YES',
#         '9 - NA - THERE WERE NO POTENTIALLY CLINICALLY SIGNIFICANT MEDICATION ISSUES IDENTIFIED SINCE SOC/ROC OR PATIENT IS NOT TAKING ANY MEDICATIONS',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - PATIENT NOT TAKING ANY HIGH RISK DRUGS OR PATIENT/CAREGIVER FULLY KNOWLEDGEABLE ABOUT SPECIAL PRECAUTIONS ASSOCIATED WITH ALL HIGH-RISK MEDICATIONS',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES', 'NA - PATIENT NOT TAKING ANY DRUGS',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY TAKE THE CORRECT ORAL MEDICATION(S) AND PROPER DOSAGE(S) AT THE CORRECT TIMES. ',
#         '1 - ABLE TO TAKE MEDICATION(S) AT THE CORRECT TIMES IF: (A) INDIVIDUAL DOSAGES ARE PREPARED IN ADVANCE BY ANOTHER PERSON; OR (B) ANOTHER PERSON DEVELOPS A DRUG DIARY OR CHART. ',
#         '2 - ABLE TO TAKE MEDICATION(S) AT THE CORRECT TIMES IF GIVEN REMINDERS BY ANOTHER PERSON AT THE APPROPRIATE TIMES ',
#         '3 - UNABLE TO TAKE MEDICATION UNLESS ADMINISTERED BY ANOTHER PERSON. ',
#         'NA - NO ORAL MEDICATIONS PRESCRIBED.', 'imputed'], dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY TAKE THE CORRECT MEDICATION(S) AND PROPER DOSAGE(S) AT THE CORRECT TIMES. ',
#         '1 - ABLE TO TAKE INJECTABLE MEDICATION(S) AT THE CORRECT TIMES IF: (A) INDIVIDUAL SYRINGES ARE PREPARED IN ADVANCE BY ANOTHER PERSON; OR (B) ANOTHER PERSON DEVELOPS A DRUG DIARY OR CHART. ',
#         '2 - ABLE TO TAKE MEDICATION(S) AT THE CORRECT TIMES IF GIVEN REMINDERS BY ANOTHER PERSON BASED ON THE FREQUENCY OF THE INJECTION ',
#         '3 - UNABLE TO TAKE INJECTABLE MEDICATION UNLESS ADMINISTERED BY ANOTHER PERSON. ',
#         'NA - NO INJECTABLE MEDICATIONS PRESCRIBED', 'imputed'],
#        dtype=object),
#  array(['0 - NO ASSISTANCE NEEDED –PATIENT IS INDEPENDENT OR DOES NOT HAVE NEEDS IN THIS AREA',
#         '1 - NON-AGENCY CAREGIVER(S) CURRENTLY PROVIDE ASSISTANCE',
#         '2 - NON-AGENCY CAREGIVER(S) NEED TRAINING/ SUPPORTIVE SERVICES TO PROVIDE ASSISTANCE',
#         '3 - NON-AGENCY CAREGIVER(S) ARE NOT LIKELY TO PROVIDE ASSISTANCE OR IT IS UNCLEAR IF THEY WILL PROVIDE ASSISTANCE',
#         '4 - ASSISTANCE NEEDED, BUT NO NON-AGENCY CAREGIVER(S) AVAILABLE',
#         'imputed'], dtype=object),
#  array(['0 - NO ASSISTANCE NEEDED –PATIENT IS INDEPENDENT OR DOES NOT HAVE NEEDS IN THIS AREA',
#         '1 - NON-AGENCY CAREGIVER(S) CURRENTLY PROVIDE ASSISTANCE',
#         '2 - NON-AGENCY CAREGIVER(S) NEED TRAINING/ SUPPORTIVE SERVICES TO PROVIDE ASSISTANCE',
#         '3 - NON-AGENCY CAREGIVER(S) ARE NOT LIKELY TO PROVIDE ASSISTANCE OR IT IS UNCLEAR IF THEY WILL PROVIDE ASSISTANCE',
#         '4 - ASSISTANCE NEEDED, BUT NO NON-AGENCY CAREGIVER(S) AVAILABLE',
#         'imputed'], dtype=object),
#  array(['0 - NO ASSISTANCE NEEDED –PATIENT IS INDEPENDENT OR DOES NOT HAVE NEEDS IN THIS AREA',
#         '1 - NON-AGENCY CAREGIVER(S) CURRENTLY PROVIDE ASSISTANCE',
#         '2 - NON-AGENCY CAREGIVER(S) NEED TRAINING/ SUPPORTIVE SERVICES TO PROVIDE ASSISTANCE',
#         '3 - NON-AGENCY CAREGIVER(S) ARE NOT LIKELY TO PROVIDE ASSISTANCE OR IT IS UNCLEAR IF THEY WILL PROVIDE ASSISTANCE',
#         '4 - ASSISTANCE NEEDED, BUT NO NON-AGENCY CAREGIVER(S) AVAILABLE',
#         'imputed'], dtype=object),
#  array(['0 - NO ASSISTANCE NEEDED –PATIENT IS INDEPENDENT OR DOES NOT HAVE NEEDS IN THIS AREA',
#         '1 - NON-AGENCY CAREGIVER(S) CURRENTLY PROVIDE ASSISTANCE',
#         '2 - NON-AGENCY CAREGIVER(S) NEED TRAINING/ SUPPORTIVE SERVICES TO PROVIDE ASSISTANCE',
#         '3 - NON-AGENCY CAREGIVER(S) ARE NOT LIKELY TO PROVIDE ASSISTANCE OR IT IS UNCLEAR IF THEY WILL PROVIDE ASSISTANCE',
#         '4 - ASSISTANCE NEEDED, BUT NO NON-AGENCY CAREGIVER(S) AVAILABLE',
#         'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['0 - NO',
#         '1 - YES, USED HOSPITAL EMERGENCY DEPARTMENT WITHOUT HOSPITAL ADMISSION ',
#         '2 - YES, USED HOSPITAL EMERGENCY DEPARTMENT WITH HOSPITAL ADMISSION',
#         'UK - UNKNOWN', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - PATIENT IS NOT DIABETIC OR IS MISSING LOWER LEGS DUE TO CONGENITAL OR ACQUIRED CONDITION (BILATERAL AMPUTEE).',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - (C2) PATIENT HAS NO DIAGNOSIS OF DEPRESSION AND EVERY STANDARDIZED, VALIDATED DEPRESSION SCREENING CONDUCTED AT OR SINCE THE MOST RECENT SOC/ROC ASSESSMENT INDICATES THE PATIENT HAS: 1) NO SYMPTOMS OF DEPRESSION; OR 2) HAS SOME SYMPTOMS OF DEPRESSION BUT DOES NOT MEET CRITERIA FOR FURTHER EVALUATION OF DEPRESSION BASED ON SCREENING TOOL USED.',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - (C2) EVERY STANDARDIZED, VALIDATED MULTI-FACTOR FALL RISK ASSESSMENT CONDUCTED AT OR SINCE THE MOST RECENT SOC/ROC ASSESSMENT INDICATES THE PATIENT HAS NO RISK FOR FALLS.',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - (C2) EVERY STANDARDIZED, VALIDATED PAIN ASSESSMENT CONDUCTED AT OR SINCE THE MOST RECENT SOC/ROC ASSESSMENT INDICATES THE PATIENT HAS NO PAIN.',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - (C2) EVERY STANDARDIZED, VALIDATED PRESSURE ULCER RISK ASSESSMENT CONDUCTED AT OR SINCE THE RECENT SOC/ROC  ASSESSMENT INDICATES THE PATIENT IS NOT AT RISK OF DEVELOPING PRESSURE ULCERS.',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - PATIENT HAS NO PRESSURE ULCERS OR HAS NO PRESSURE ULCERS FOR WHICH MOIST WOUND HEALING IS INDICATED.',
#         'imputed'], dtype=object),
#  array(['1 - HOSPITAL', '2 - REHABILITATION FACILITY', '3 - NURSING HOME',
#         '4 - HOSPICE', 'NA - NO INPATIENT FACILITY ADMISSION', 'imputed'],
#        dtype=object),
#  array(['1 - PATIENT REMAINED IN THE COMMUNITY (WITHOUT FORMAL ASSISTIVE SERVICES) ',
#         '2 - PATIENT REMAINED IN THE COMMUNITY (WITH FORMAL ASSISTIVE SERVICES) ',
#         '3 - PATIENT TRANSFERRED TO A NON-INSTITUTIONAL HOSPICE ',
#         '4 - UNKNOWN BECAUSE PATIENT MOVED TO A GEOGRAPHIC LOCATION NOT SERVED BY THIS AGENCY ',
#         'UK - OTHER UNKNOWN', 'imputed'], dtype=object),
#  array(['0', '1'], dtype=object)]

# %%
xdf = enc.transform(df) # transform using encoder

# %%
df2 = pd.DataFrame(xdf, columns=df.columns) # numpy to dataframe

# %%
X = df2.iloc[:,:-1]

# %%
y = df2.iloc[:,-1:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)

# %% [markdown]
# ### Quick Evaluation using RFE Feature Selection: LogisticRegression

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
rfe = RFE(estimator=LogisticRegression(), n_features_to_select=10, verbose=1)

rfe.fit(X_train, y_train)

print(dict(zip(X.columns, rfe.ranking_)))
# Out:
# Fitting estimator with 128 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 127 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 126 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 125 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 124 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 123 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 122 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 121 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 120 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 119 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 118 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 117 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 116 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 115 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 114 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 113 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 112 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 111 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 110 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 109 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 108 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 107 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 106 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 105 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 104 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 103 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 102 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 101 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 100 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 99 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 98 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 97 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 96 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 95 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 94 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 93 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 92 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 91 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 90 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 89 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 88 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 87 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 86 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting estimator with 85 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 84 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 83 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 82 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 81 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 80 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 79 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 78 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 77 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 76 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 75 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 74 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 23 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 22 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 21 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 20 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 19 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 18 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 17 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 16 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 15 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 14 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 13 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 12 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 11 features.
# {'year_born': 89, 'pa_race': 41, 'pa_gender': 19, 'pa_maritalstatus': 55, 'epi_AdmitType': 76, 'epi_height': 108, 'epi_weight': 102, 'ceo_HIPPS': 113, 'ceo_HHRG': 106, 'icd_code': 119, 'DiagnosisCategory': 61, 'RoughAge': 1, 'M0100_ASSMT_REASON': 46, 'M0110_EPISODE_TIMING': 88, 'M0140_ETHNIC_AI_AN': 82, 'M0140_ETHNIC_ASIAN': 107, 'M0140_ETHNIC_BLACK': 110, 'M0140_ETHNIC_HISP': 54, 'M0140_ETHNIC_NH_PI': 93, 'M0140_ETHNIC_WHITE': 40, 'M0906_DC_TRAN_DTH_DT': 99, 'M1000_DC_IPPS_14_DA': 9, 'M1000_DC_IRF_14_DA': 104, 'M1000_DC_LTC_14_DA': 116, 'M1000_DC_LTCH_14_DA': 114, 'M1000_DC_NONE_14_DA': 20, 'M1000_DC_OTH_14_DA': 111, 'M1000_DC_PSYCH_14_DA': 98, 'M1000_DC_SNF_14_DA': 103, 'M1028_ACTV_DIAG_DM': 71, 'M1028_ACTV_DIAG_NOA': 35, 'M1028_ACTV_DIAG_PVD_PAD': 30, 'M1030_THH_ENT_NUTRITION': 2, 'M1030_THH_IV_INFUSION': 12, 'M1030_THH_NONE_ABOVE': 11, 'M1030_THH_PAR_NUTRITION': 3, 'M1033_HOSP_RISK_5PLUS_MDCTN': 97, 'M1033_HOSP_RISK_COMPLIANCE': 60, 'M1033_HOSP_RISK_CRNT_EXHSTN': 75, 'M1033_HOSP_RISK_HSTRY_FALLS': 25, 'M1033_HOSP_RISK_MLTPL_ED_VISIT': 80, 'M1033_HOSP_RISK_MLTPL_HOSPZTN': 45, 'M1033_HOSP_RISK_MNTL_BHV_DCLN': 44, 'M1033_HOSP_RISK_NONE_ABOVE': 1, 'M1033_HOSP_RISK_OTHR_RISK': 51, 'M1033_HOSP_RISK_WEIGHT_LOSS': 1, 'M1046_INFLNZ_RECD_CRNT_SEASON': 96, 'M1051_PVX_RCVD_AGNCY': 95, 'M1056_PVX_RSN_NOT_RCVD_AGNCY': 86, 'M1060_HEIGHT_A': 101, 'M1060_WEIGHT_B': 115, 'M1200_VISION': 74, 'M1242_PAIN_FREQ_ACTVTY_MVMT': 63, 'M1306_UNHLD_STG2_PRSR_ULCR': 1, 'M1307_OLDST_STG2_AT_DSCHRG': 16, 'M1307_OLDST_STG2_ONST_DT': 1, 'M1311_NBR_PRSULC_STG2_A1': 87, 'M1311_NBR_PRSULC_STG3_B1': 100, 'M1311_NBR_PRSULC_STG4_C1': 112, 'M1311_NBR_ULC_SOCROC_STG2_A2': 8, 'M1311_NBR_ULC_SOCROC_STG3_B2': 1, 'M1311_NBR_ULC_SOCROC_STG4_C2': 1, 'M1311_NSTG_CVRG_E1': 118, 'M1311_NSTG_CVRG_SOCROC_E2': 1, 'M1311_NSTG_DEEP_TSUE_F1': 91, 'M1311_NSTG_DEEP_TSUE_SOCROC_F2': 15, 'M1311_NSTG_DRSG_D1': 78, 'M1311_NSTG_DRSG_SOCROC_D2': 1, 'M1324_STG_PRBLM_ULCER': 50, 'M1330_STAS_ULCR_PRSNT': 32, 'M1332_NBR_STAS_ULCR': 64, 'M1334_STUS_PRBLM_STAS_ULCR': 31, 'M1340_SRGCL_WND_PRSNT': 14, 'M1342_STUS_PRBLM_SRGCL_WND': 90, 'M1400_WHEN_DYSPNEIC': 17, 'M1600_UTI': 24, 'M1610_UR_INCONT': 117, 'M1620_BWL_INCONT': 68, 'M1630_OSTOMY': 109, 'M1700_COG_FUNCTION': 92, 'M1710_WHEN_CONFUSED': 73, 'M1720_WHEN_ANXIOUS': 105, 'M1730_PHQ2_DPRSN': 69, 'M1730_PHQ2_LACK_INTRST': 67, 'M1730_STDZ_DPRSN_SCRNG': 18, 'M1740_BD_DELUSIONS': 39, 'M1740_BD_IMP_DECISN': 72, 'M1740_BD_MEM_DEFICIT': 62, 'M1740_BD_NONE': 33, 'M1740_BD_PHYSICAL': 34, 'M1740_BD_SOC_INAPPRO': 10, 'M1740_BD_VERBAL': 28, 'M1745_BEH_PROB_FREQ': 94, 'M1800_CRNT_GROOMING': 56, 'M1810_CRNT_DRESS_UPPER': 49, 'M1820_CRNT_DRESS_LOWER': 66, 'M1830_CRNT_BATHG': 58, 'M1840_CRNT_TOILTG': 29, 'M1845_CRNT_TOILTG_HYGN': 47, 'M1850_CRNT_TRNSFRNG': 70, 'M1860_CRNT_AMBLTN': 59, 'M1870_CRNT_FEEDING': 42, 'M1910_MLT_FCTR_FALL_RISK_ASMT': 36, 'M2001_DRUG_RGMN_RVW': 23, 'M2003_MDCTN_FLWP': 22, 'M2005_MDCTN_INTRVTN': 26, 'M2010_HIGH_RISK_DRUG_EDCTN': 53, 'M2016_DRUG_EDCTN_INTRVTN': 1, 'M2020_CRNT_MGMT_ORAL_MDCTN': 84, 'M2030_CRNT_MGMT_INJCTN_MDCTN': 81, 'M2102_CARE_TYPE_SRC_ADL': 38, 'M2102_CARE_TYPE_SRC_MDCTN': 13, 'M2102_CARE_TYPE_SRC_PRCDR': 48, 'M2102_CARE_TYPE_SRC_SPRVSN': 77, 'M2200_THER_NEED_NA': 5, 'M2301_EMER_USE_AFTR_LAST_ASMT': 52, 'M2310_ECR_HYPOGLYC': 43, 'M2310_ECR_MEDICATION': 27, 'M2310_ECR_OTHER': 65, 'M2310_ECR_UNKNOWN': 83, 'M2401_INTRVTN_SMRY_DBTS_FT': 21, 'M2401_INTRVTN_SMRY_DPRSN': 37, 'M2401_INTRVTN_SMRY_FALL_PRVNT': 7, 'M2401_INTRVTN_SMRY_PAIN_MNTR': 57, 'M2401_INTRVTN_SMRY_PRSULC_PRVN': 79, 'M2401_INTRVTN_SMRY_PRSULC_WET': 85, 'M2410_INPAT_FACILITY': 6, 'M2420_DSCHRG_DISP': 4}
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(X.columns[rfe.support_])
# Out:
# Index(['RoughAge', 'M1033_HOSP_RISK_NONE_ABOVE', 'M1033_HOSP_RISK_WEIGHT_LOSS',
#        'M1306_UNHLD_STG2_PRSR_ULCR', 'M1307_OLDST_STG2_ONST_DT',
#        'M1311_NBR_ULC_SOCROC_STG3_B2', 'M1311_NBR_ULC_SOCROC_STG4_C2',
#        'M1311_NSTG_CVRG_SOCROC_E2', 'M1311_NSTG_DRSG_SOCROC_D2',
#        'M2016_DRUG_EDCTN_INTRVTN'],
#       dtype='object')

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test, rfe.predict(X_test))

# %%
print("{0:.1%} accuracy on test set.".format(acc))
# Out:
# 81.0% accuracy on test set.

# %% [markdown]
# ### Quick Evaluation using RFE Feature Selection: RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, y_train)

# Calculate the accuracy
acc = accuracy_score(y_test, rf.predict(X_test))

# Print the importances per feature
# print(dict(zip(X.columns, rf.feature_importances_.round(2))))

# Print accuracy
print("{0:.1%} accuracy on test set.".format(acc))
# Out:
# C:\Users\sjyhl\AppData\Local\Temp/ipykernel_11680/3044802180.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# 97.1% accuracy on test set.

# %%
mask = rf.feature_importances_ > 0.03

# Apply the mask to the feature dataset X
reduced_X = X.loc[:, mask]

# Prints out the selected column names
print(reduced_X.columns)
# Out:
# Index(['year_born', 'icd_code', 'RoughAge', 'M0906_DC_TRAN_DTH_DT'], dtype='object')

# %% [markdown]
# ### Check regularizing strength (LASSO)

# %%
from sklearn.linear_model import Lasso
alpha_list = [10, 1, 0.5, 0.1, 0.01, 0.001, 0.0001, 0.00001]
max_r = 0
max_alpha = 0
for alpha in alpha_list:
    
    la = Lasso(alpha=alpha, random_state=0)

    
    la.fit(X_train, y_train)
    r_squared = la.score(X_test, y_test)
    n_ignored_features = sum(la.coef_ == 0)

    
    print("The model can predict {0:.1%} of the variance in the test set.".format(r_squared))
    print("{} out of {} features were ignored.".format(n_ignored_features, len(la.coef_)))
    
    if r_squared > 0.98:
        max_r = r_squared
        max_alpha = alpha
        break
print("Max R-squared: {}, alpha: {}".format(max_r, max_alpha))
# Out:
# The model can predict 34.3% of the variance in the test set.
# 127 out of 128 features were ignored.
# The model can predict 35.6% of the variance in the test set.
# 125 out of 128 features were ignored.
# The model can predict 38.8% of the variance in the test set.
# 124 out of 128 features were ignored.
# The model can predict 50.4% of the variance in the test set.
# 118 out of 128 features were ignored.
# The model can predict 54.5% of the variance in the test set.
# 103 out of 128 features were ignored.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.353e+00, tolerance: 5.140e-01
#   model = cd_fast.enet_coordinate_descent(
# The model can predict 55.9% of the variance in the test set.
# 64 out of 128 features were ignored.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.030e+03, tolerance: 5.140e-01
#   model = cd_fast.enet_coordinate_descent(
# The model can predict 56.1% of the variance in the test set.
# 18 out of 128 features were ignored.
# The model can predict 56.2% of the variance in the test set.
# 1 out of 128 features were ignored.
# Max R-squared: 0, alpha: 0
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.092e+03, tolerance: 5.140e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
alphas = np.linspace(0.01,500,100)
lasso = Lasso(max_iter=10000)
coefs = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    coefs.append(lasso.coef_)

ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('Standardized Coefficients')
plt.title('Lasso coefficients as a function of alpha');

# %% [markdown]
# ### LASSO CV - Model w/ best alpha

# %%
from sklearn.linear_model import LassoCV

# Lasso with 5 fold cross-validation
model = LassoCV(cv=5, random_state=0, max_iter=10000)

# Fit model
model.fit(X_train, y_train)

LassoCV(cv=5, max_iter=10000, random_state=0)

model.alpha_
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1572: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.056133523941912164

# %% [markdown]
# ### Set best alpha and get coefficients

# %%
lasso_best = Lasso(alpha=model.alpha_)
lasso_best.fit(X_train, y_train)
print([coef for coef in list(zip(lasso_best.coef_, X)) if abs(coef[0]) > 0])
# Out:
# [(-0.0028985628531202692, 'year_born'), (0.013848313085452299, 'pa_race'), (-0.002440819882581564, 'pa_maritalstatus'), (-0.00043576036012019206, 'epi_weight'), (-2.7398776387955646e-05, 'ceo_HIPPS'), (-4.353041392472998e-05, 'icd_code'), (-0.011864485267326759, 'RoughAge'), (0.0011277621005223067, 'M0906_DC_TRAN_DTH_DT'), (-0.00032510905130638033, 'M1060_WEIGHT_B'), (-0.001211950112521016, 'M1311_NSTG_DEEP_TSUE_F1'), (0.01178628184283972, 'M1400_WHEN_DYSPNEIC'), (0.010285029346718239, 'M1620_BWL_INCONT'), (0.0003504772193756619, 'M1710_WHEN_CONFUSED'), (0.016006000501938, 'M1830_CRNT_BATHG'), (0.02703529393519302, 'M1870_CRNT_FEEDING')]

# %%
[coef[1] for coef in list(zip(lasso_best.coef_, X)) if abs(coef[0]) > 0]
# Out:
# ['year_born',
#  'pa_race',
#  'pa_maritalstatus',
#  'epi_weight',
#  'ceo_HIPPS',
#  'icd_code',
#  'RoughAge',
#  'M0906_DC_TRAN_DTH_DT',
#  'M1060_WEIGHT_B',
#  'M1311_NSTG_DEEP_TSUE_F1',
#  'M1400_WHEN_DYSPNEIC',
#  'M1620_BWL_INCONT',
#  'M1710_WHEN_CONFUSED',
#  'M1830_CRNT_BATHG',
#  'M1870_CRNT_FEEDING']

# %%
from sklearn import linear_model
_, _, coefs = linear_model.lars_path(X, y, method="lasso", verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11680/2003796199.py in <module>
#       1 from sklearn import linear_model
# ----> 2 _, _, coefs = linear_model.lars_path(X, y, method="lasso", verbose=True)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_least_angle.py in lars_path(X, y, Xy, Gram, max_iter, alpha_min, method, copy_X, eps, copy_Gram, verbose, return_path, return_n_iter, positive)
#     169             "Use lars_path_gram to avoid passing X and y."
#     170         )
# --> 171     return _lars_path_solver(
#     172         X=X,
#     173         y=y,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_least_angle.py in _lars_path_solver(X, y, Xy, Gram, n_samples, max_iter, alpha_min, method, copy_X, eps, copy_Gram, verbose, return_path, return_n_iter, positive)
#     499     max_features = min(max_iter, n_features)
#     500
# --> 501     dtypes = set(a.dtype for a in (X, y, Xy, Gram) if a is not None)
#     502     if len(dtypes) == 1:
#     503         # use the precision level of input data if it is consistent
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_least_angle.py in <genexpr>(.0)
#     499     max_features = min(max_iter, n_features)
#     500
# --> 501     dtypes = set(a.dtype for a in (X, y, Xy, Gram) if a is not None)
#     502     if len(dtypes) == 1:
#     503         # use the precision level of input data if it is consistent
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %% [markdown]
# ### Misc Facts about data

# %% [markdown]
# #### some columns have '-' as category

# %%
df.M1028_ACTV_DIAG_DM.unique()
# Out:
# ['imputed', 'YES', 'NO', '-']
# Categories (4, object): ['-', 'NO', 'YES', 'imputed']

# %%
df.M1028_ACTV_DIAG_PVD_PAD.unique()
# Out:
# ['imputed', 'YES', 'NO', '-']
# Categories (4, object): ['-', 'NO', 'YES', 'imputed']

# %%
df.M2003_MDCTN_FLWP.unique()
# Out:
# ['imputed', '0 - NO', '1 - YES', '-']
# Categories (4, object): ['-', '0 - NO', '1 - YES', 'imputed']

# %%
# fix above. make '-' into 'imputed'
df.loc[df["M1028_ACTV_DIAG_DM"] == "-", "M1028_ACTV_DIAG_DM"] = 'imputed'
df.loc[df["M1028_ACTV_DIAG_PVD_PAD"] == "-", "M1028_ACTV_DIAG_PVD_PAD"] ='imputed'
df.loc[df["M2003_MDCTN_FLWP"] == "-", "M2003_MDCTN_FLWP"] = 'imputed'

# %% [markdown]
# #### some columns represent single variable type, some are over multiple columns

# %%
list(df.M1400_WHEN_DYSPNEIC.unique())
# Out:
# ['2 - WITH MODERATE EXERTION (FOR EXAMPLE, WHILE DRESSING, USING COMMODE OR BEDPAN, WALKING DISTANCES LESS THAN 20 FEET)',
#  '1 - WHEN WALKING MORE THAN 20 FEET, CLIMBING STAIRS ',
#  '0 - PATIENT IS NOT SHORT OF BREATH ',
#  '4 - AT REST (DURING DAY OR NIGHT)',
#  '3 - WITH MINIMAL EXERTION (FOR EXAMPLE, WHILE EATING, TALKING, OR PERFORMING OTHER ADLS) OR WITH AGITATION',
#  'imputed']

# %%
list(df.M1033_HOSP_RISK_MLTPL_HOSPZTN.unique())
# Out:
# ['imputed', 'NO', 'YES']

# %% [markdown]
# ### Feature Evaluation using Regression

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

names=pd.DataFrame(X_train.columns)

lin_reg = LogisticRegression()

rfe_mod = RFE(lin_reg, n_features_to_select=5, step=1)

fit_model = rfe_mod.fit(X_train, y_train)
fit_model.support_
fit_model.ranking_
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([ 94,  46,  24,  60,  81, 113, 107, 118, 111, 124,  66,   2,  51,
#         93,  87, 112, 115,  59,  98,  45, 104,  14, 109, 121, 119,  25,
#        116, 103, 108,  76,  40,  35,   7,  17,  16,   8, 102,  65,  80,
#         30,  85,  50,  49,   5,  56,   6, 101, 100,  91, 106, 120,  79,
#         68,   3,  21,   1,  92, 105, 117,  13,   1,   1, 123,   1,  96,
#         20,  83,   1,  55,  37,  69,  36,  19,  95,  22,  29, 122,  73,
#        114,  97,  78, 110,  74,  72,  23,  44,  77,  67,  38,  39,  15,
#         33,  99,  61,  54,  71,  63,  34,  52,  75,  64,  47,  41,  28,
#         27,  31,  58,   4,  89,  86,  43,  18,  53,  82,  10,  57,  48,
#         32,  70,  88,  26,  42,  12,  62,  84,  90,  11,   9])

# %%
selected_features = []
for i, rank in enumerate(fit_model.ranking_):
    feature = fit_model.feature_names_in_[i]
    selected_features.append({'feature': feature, 'rank': rank})
selected_features
# Out:
# [{'feature': 'year_born', 'rank': 94},
#  {'feature': 'pa_race', 'rank': 46},
#  {'feature': 'pa_gender', 'rank': 24},
#  {'feature': 'pa_maritalstatus', 'rank': 60},
#  {'feature': 'epi_AdmitType', 'rank': 81},
#  {'feature': 'epi_height', 'rank': 113},
#  {'feature': 'epi_weight', 'rank': 107},
#  {'feature': 'ceo_HIPPS', 'rank': 118},
#  {'feature': 'ceo_HHRG', 'rank': 111},
#  {'feature': 'icd_code', 'rank': 124},
#  {'feature': 'DiagnosisCategory', 'rank': 66},
#  {'feature': 'RoughAge', 'rank': 2},
#  {'feature': 'M0100_ASSMT_REASON', 'rank': 51},
#  {'feature': 'M0110_EPISODE_TIMING', 'rank': 93},
#  {'feature': 'M0140_ETHNIC_AI_AN', 'rank': 87},
#  {'feature': 'M0140_ETHNIC_ASIAN', 'rank': 112},
#  {'feature': 'M0140_ETHNIC_BLACK', 'rank': 115},
#  {'feature': 'M0140_ETHNIC_HISP', 'rank': 59},
#  {'feature': 'M0140_ETHNIC_NH_PI', 'rank': 98},
#  {'feature': 'M0140_ETHNIC_WHITE', 'rank': 45},
#  {'feature': 'M0906_DC_TRAN_DTH_DT', 'rank': 104},
#  {'feature': 'M1000_DC_IPPS_14_DA', 'rank': 14},
#  {'feature': 'M1000_DC_IRF_14_DA', 'rank': 109},
#  {'feature': 'M1000_DC_LTC_14_DA', 'rank': 121},
#  {'feature': 'M1000_DC_LTCH_14_DA', 'rank': 119},
#  {'feature': 'M1000_DC_NONE_14_DA', 'rank': 25},
#  {'feature': 'M1000_DC_OTH_14_DA', 'rank': 116},
#  {'feature': 'M1000_DC_PSYCH_14_DA', 'rank': 103},
#  {'feature': 'M1000_DC_SNF_14_DA', 'rank': 108},
#  {'feature': 'M1028_ACTV_DIAG_DM', 'rank': 76},
#  {'feature': 'M1028_ACTV_DIAG_NOA', 'rank': 40},
#  {'feature': 'M1028_ACTV_DIAG_PVD_PAD', 'rank': 35},
#  {'feature': 'M1030_THH_ENT_NUTRITION', 'rank': 7},
#  {'feature': 'M1030_THH_IV_INFUSION', 'rank': 17},
#  {'feature': 'M1030_THH_NONE_ABOVE', 'rank': 16},
#  {'feature': 'M1030_THH_PAR_NUTRITION', 'rank': 8},
#  {'feature': 'M1033_HOSP_RISK_5PLUS_MDCTN', 'rank': 102},
#  {'feature': 'M1033_HOSP_RISK_COMPLIANCE', 'rank': 65},
#  {'feature': 'M1033_HOSP_RISK_CRNT_EXHSTN', 'rank': 80},
#  {'feature': 'M1033_HOSP_RISK_HSTRY_FALLS', 'rank': 30},
#  {'feature': 'M1033_HOSP_RISK_MLTPL_ED_VISIT', 'rank': 85},
#  {'feature': 'M1033_HOSP_RISK_MLTPL_HOSPZTN', 'rank': 50},
#  {'feature': 'M1033_HOSP_RISK_MNTL_BHV_DCLN', 'rank': 49},
#  {'feature': 'M1033_HOSP_RISK_NONE_ABOVE', 'rank': 5},
#  {'feature': 'M1033_HOSP_RISK_OTHR_RISK', 'rank': 56},
#  {'feature': 'M1033_HOSP_RISK_WEIGHT_LOSS', 'rank': 6},
#  {'feature': 'M1046_INFLNZ_RECD_CRNT_SEASON', 'rank': 101},
#  {'feature': 'M1051_PVX_RCVD_AGNCY', 'rank': 100},
#  {'feature': 'M1056_PVX_RSN_NOT_RCVD_AGNCY', 'rank': 91},
#  {'feature': 'M1060_HEIGHT_A', 'rank': 106},
#  {'feature': 'M1060_WEIGHT_B', 'rank': 120},
#  {'feature': 'M1200_VISION', 'rank': 79},
#  {'feature': 'M1242_PAIN_FREQ_ACTVTY_MVMT', 'rank': 68},
#  {'feature': 'M1306_UNHLD_STG2_PRSR_ULCR', 'rank': 3},
#  {'feature': 'M1307_OLDST_STG2_AT_DSCHRG', 'rank': 21},
#  {'feature': 'M1307_OLDST_STG2_ONST_DT', 'rank': 1},
#  {'feature': 'M1311_NBR_PRSULC_STG2_A1', 'rank': 92},
#  {'feature': 'M1311_NBR_PRSULC_STG3_B1', 'rank': 105},
#  {'feature': 'M1311_NBR_PRSULC_STG4_C1', 'rank': 117},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG2_A2', 'rank': 13},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG3_B2', 'rank': 1},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG4_C2', 'rank': 1},
#  {'feature': 'M1311_NSTG_CVRG_E1', 'rank': 123},
#  {'feature': 'M1311_NSTG_CVRG_SOCROC_E2', 'rank': 1},
#  {'feature': 'M1311_NSTG_DEEP_TSUE_F1', 'rank': 96},
#  {'feature': 'M1311_NSTG_DEEP_TSUE_SOCROC_F2', 'rank': 20},
#  {'feature': 'M1311_NSTG_DRSG_D1', 'rank': 83},
#  {'feature': 'M1311_NSTG_DRSG_SOCROC_D2', 'rank': 1},
#  {'feature': 'M1324_STG_PRBLM_ULCER', 'rank': 55},
#  {'feature': 'M1330_STAS_ULCR_PRSNT', 'rank': 37},
#  {'feature': 'M1332_NBR_STAS_ULCR', 'rank': 69},
#  {'feature': 'M1334_STUS_PRBLM_STAS_ULCR', 'rank': 36},
#  {'feature': 'M1340_SRGCL_WND_PRSNT', 'rank': 19},
#  {'feature': 'M1342_STUS_PRBLM_SRGCL_WND', 'rank': 95},
#  {'feature': 'M1400_WHEN_DYSPNEIC', 'rank': 22},
#  {'feature': 'M1600_UTI', 'rank': 29},
#  {'feature': 'M1610_UR_INCONT', 'rank': 122},
#  {'feature': 'M1620_BWL_INCONT', 'rank': 73},
#  {'feature': 'M1630_OSTOMY', 'rank': 114},
#  {'feature': 'M1700_COG_FUNCTION', 'rank': 97},
#  {'feature': 'M1710_WHEN_CONFUSED', 'rank': 78},
#  {'feature': 'M1720_WHEN_ANXIOUS', 'rank': 110},
#  {'feature': 'M1730_PHQ2_DPRSN', 'rank': 74},
#  {'feature': 'M1730_PHQ2_LACK_INTRST', 'rank': 72},
#  {'feature': 'M1730_STDZ_DPRSN_SCRNG', 'rank': 23},
#  {'feature': 'M1740_BD_DELUSIONS', 'rank': 44},
#  {'feature': 'M1740_BD_IMP_DECISN', 'rank': 77},
#  {'feature': 'M1740_BD_MEM_DEFICIT', 'rank': 67},
#  {'feature': 'M1740_BD_NONE', 'rank': 38},
#  {'feature': 'M1740_BD_PHYSICAL', 'rank': 39},
#  {'feature': 'M1740_BD_SOC_INAPPRO', 'rank': 15},
#  {'feature': 'M1740_BD_VERBAL', 'rank': 33},
#  {'feature': 'M1745_BEH_PROB_FREQ', 'rank': 99},
#  {'feature': 'M1800_CRNT_GROOMING', 'rank': 61},
#  {'feature': 'M1810_CRNT_DRESS_UPPER', 'rank': 54},
#  {'feature': 'M1820_CRNT_DRESS_LOWER', 'rank': 71},
#  {'feature': 'M1830_CRNT_BATHG', 'rank': 63},
#  {'feature': 'M1840_CRNT_TOILTG', 'rank': 34},
#  {'feature': 'M1845_CRNT_TOILTG_HYGN', 'rank': 52},
#  {'feature': 'M1850_CRNT_TRNSFRNG', 'rank': 75},
#  {'feature': 'M1860_CRNT_AMBLTN', 'rank': 64},
#  {'feature': 'M1870_CRNT_FEEDING', 'rank': 47},
#  {'feature': 'M1910_MLT_FCTR_FALL_RISK_ASMT', 'rank': 41},
#  {'feature': 'M2001_DRUG_RGMN_RVW', 'rank': 28},
#  {'feature': 'M2003_MDCTN_FLWP', 'rank': 27},
#  {'feature': 'M2005_MDCTN_INTRVTN', 'rank': 31},
#  {'feature': 'M2010_HIGH_RISK_DRUG_EDCTN', 'rank': 58},
#  {'feature': 'M2016_DRUG_EDCTN_INTRVTN', 'rank': 4},
#  {'feature': 'M2020_CRNT_MGMT_ORAL_MDCTN', 'rank': 89},
#  {'feature': 'M2030_CRNT_MGMT_INJCTN_MDCTN', 'rank': 86},
#  {'feature': 'M2102_CARE_TYPE_SRC_ADL', 'rank': 43},
#  {'feature': 'M2102_CARE_TYPE_SRC_MDCTN', 'rank': 18},
#  {'feature': 'M2102_CARE_TYPE_SRC_PRCDR', 'rank': 53},
#  {'feature': 'M2102_CARE_TYPE_SRC_SPRVSN', 'rank': 82},
#  {'feature': 'M2200_THER_NEED_NA', 'rank': 10},
#  {'feature': 'M2301_EMER_USE_AFTR_LAST_ASMT', 'rank': 57},
#  {'feature': 'M2310_ECR_HYPOGLYC', 'rank': 48},
#  {'feature': 'M2310_ECR_MEDICATION', 'rank': 32},
#  {'feature': 'M2310_ECR_OTHER', 'rank': 70},
#  {'feature': 'M2310_ECR_UNKNOWN', 'rank': 88},
#  {'feature': 'M2401_INTRVTN_SMRY_DBTS_FT', 'rank': 26},
#  {'feature': 'M2401_INTRVTN_SMRY_DPRSN', 'rank': 42},
#  {'feature': 'M2401_INTRVTN_SMRY_FALL_PRVNT', 'rank': 12},
#  {'feature': 'M2401_INTRVTN_SMRY_PAIN_MNTR', 'rank': 62},
#  {'feature': 'M2401_INTRVTN_SMRY_PRSULC_PRVN', 'rank': 84},
#  {'feature': 'M2401_INTRVTN_SMRY_PRSULC_WET', 'rank': 90},
#  {'feature': 'M2410_INPAT_FACILITY', 'rank': 11},
#  {'feature': 'M2420_DSCHRG_DISP', 'rank': 9}]

# %%
sorted(selected_features, key=lambda i: i['rank'])
# Out:
# [{'feature': 'M1307_OLDST_STG2_ONST_DT', 'rank': 1},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG3_B2', 'rank': 1},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG4_C2', 'rank': 1},
#  {'feature': 'M1311_NSTG_CVRG_SOCROC_E2', 'rank': 1},
#  {'feature': 'M1311_NSTG_DRSG_SOCROC_D2', 'rank': 1},
#  {'feature': 'RoughAge', 'rank': 2},
#  {'feature': 'M1306_UNHLD_STG2_PRSR_ULCR', 'rank': 3},
#  {'feature': 'M2016_DRUG_EDCTN_INTRVTN', 'rank': 4},
#  {'feature': 'M1033_HOSP_RISK_NONE_ABOVE', 'rank': 5},
#  {'feature': 'M1033_HOSP_RISK_WEIGHT_LOSS', 'rank': 6},
#  {'feature': 'M1030_THH_ENT_NUTRITION', 'rank': 7},
#  {'feature': 'M1030_THH_PAR_NUTRITION', 'rank': 8},
#  {'feature': 'M2420_DSCHRG_DISP', 'rank': 9},
#  {'feature': 'M2200_THER_NEED_NA', 'rank': 10},
#  {'feature': 'M2410_INPAT_FACILITY', 'rank': 11},
#  {'feature': 'M2401_INTRVTN_SMRY_FALL_PRVNT', 'rank': 12},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG2_A2', 'rank': 13},
#  {'feature': 'M1000_DC_IPPS_14_DA', 'rank': 14},
#  {'feature': 'M1740_BD_SOC_INAPPRO', 'rank': 15},
#  {'feature': 'M1030_THH_NONE_ABOVE', 'rank': 16},
#  {'feature': 'M1030_THH_IV_INFUSION', 'rank': 17},
#  {'feature': 'M2102_CARE_TYPE_SRC_MDCTN', 'rank': 18},
#  {'feature': 'M1340_SRGCL_WND_PRSNT', 'rank': 19},
#  {'feature': 'M1311_NSTG_DEEP_TSUE_SOCROC_F2', 'rank': 20},
#  {'feature': 'M1307_OLDST_STG2_AT_DSCHRG', 'rank': 21},
#  {'feature': 'M1400_WHEN_DYSPNEIC', 'rank': 22},
#  {'feature': 'M1730_STDZ_DPRSN_SCRNG', 'rank': 23},
#  {'feature': 'pa_gender', 'rank': 24},
#  {'feature': 'M1000_DC_NONE_14_DA', 'rank': 25},
#  {'feature': 'M2401_INTRVTN_SMRY_DBTS_FT', 'rank': 26},
#  {'feature': 'M2003_MDCTN_FLWP', 'rank': 27},
#  {'feature': 'M2001_DRUG_RGMN_RVW', 'rank': 28},
#  {'feature': 'M1600_UTI', 'rank': 29},
#  {'feature': 'M1033_HOSP_RISK_HSTRY_FALLS', 'rank': 30},
#  {'feature': 'M2005_MDCTN_INTRVTN', 'rank': 31},
#  {'feature': 'M2310_ECR_MEDICATION', 'rank': 32},
#  {'feature': 'M1740_BD_VERBAL', 'rank': 33},
#  {'feature': 'M1840_CRNT_TOILTG', 'rank': 34},
#  {'feature': 'M1028_ACTV_DIAG_PVD_PAD', 'rank': 35},
#  {'feature': 'M1334_STUS_PRBLM_STAS_ULCR', 'rank': 36},
#  {'feature': 'M1330_STAS_ULCR_PRSNT', 'rank': 37},
#  {'feature': 'M1740_BD_NONE', 'rank': 38},
#  {'feature': 'M1740_BD_PHYSICAL', 'rank': 39},
#  {'feature': 'M1028_ACTV_DIAG_NOA', 'rank': 40},
#  {'feature': 'M1910_MLT_FCTR_FALL_RISK_ASMT', 'rank': 41},
#  {'feature': 'M2401_INTRVTN_SMRY_DPRSN', 'rank': 42},
#  {'feature': 'M2102_CARE_TYPE_SRC_ADL', 'rank': 43},
#  {'feature': 'M1740_BD_DELUSIONS', 'rank': 44},
#  {'feature': 'M0140_ETHNIC_WHITE', 'rank': 45},
#  {'feature': 'pa_race', 'rank': 46},
#  {'feature': 'M1870_CRNT_FEEDING', 'rank': 47},
#  {'feature': 'M2310_ECR_HYPOGLYC', 'rank': 48},
#  {'feature': 'M1033_HOSP_RISK_MNTL_BHV_DCLN', 'rank': 49},
#  {'feature': 'M1033_HOSP_RISK_MLTPL_HOSPZTN', 'rank': 50},
#  {'feature': 'M0100_ASSMT_REASON', 'rank': 51},
#  {'feature': 'M1845_CRNT_TOILTG_HYGN', 'rank': 52},
#  {'feature': 'M2102_CARE_TYPE_SRC_PRCDR', 'rank': 53},
#  {'feature': 'M1810_CRNT_DRESS_UPPER', 'rank': 54},
#  {'feature': 'M1324_STG_PRBLM_ULCER', 'rank': 55},
#  {'feature': 'M1033_HOSP_RISK_OTHR_RISK', 'rank': 56},
#  {'feature': 'M2301_EMER_USE_AFTR_LAST_ASMT', 'rank': 57},
#  {'feature': 'M2010_HIGH_RISK_DRUG_EDCTN', 'rank': 58},
#  {'feature': 'M0140_ETHNIC_HISP', 'rank': 59},
#  {'feature': 'pa_maritalstatus', 'rank': 60},
#  {'feature': 'M1800_CRNT_GROOMING', 'rank': 61},
#  {'feature': 'M2401_INTRVTN_SMRY_PAIN_MNTR', 'rank': 62},
#  {'feature': 'M1830_CRNT_BATHG', 'rank': 63},
#  {'feature': 'M1860_CRNT_AMBLTN', 'rank': 64},
#  {'feature': 'M1033_HOSP_RISK_COMPLIANCE', 'rank': 65},
#  {'feature': 'DiagnosisCategory', 'rank': 66},
#  {'feature': 'M1740_BD_MEM_DEFICIT', 'rank': 67},
#  {'feature': 'M1242_PAIN_FREQ_ACTVTY_MVMT', 'rank': 68},
#  {'feature': 'M1332_NBR_STAS_ULCR', 'rank': 69},
#  {'feature': 'M2310_ECR_OTHER', 'rank': 70},
#  {'feature': 'M1820_CRNT_DRESS_LOWER', 'rank': 71},
#  {'feature': 'M1730_PHQ2_LACK_INTRST', 'rank': 72},
#  {'feature': 'M1620_BWL_INCONT', 'rank': 73},
#  {'feature': 'M1730_PHQ2_DPRSN', 'rank': 74},
#  {'feature': 'M1850_CRNT_TRNSFRNG', 'rank': 75},
#  {'feature': 'M1028_ACTV_DIAG_DM', 'rank': 76},
#  {'feature': 'M1740_BD_IMP_DECISN', 'rank': 77},
#  {'feature': 'M1710_WHEN_CONFUSED', 'rank': 78},
#  {'feature': 'M1200_VISION', 'rank': 79},
#  {'feature': 'M1033_HOSP_RISK_CRNT_EXHSTN', 'rank': 80},
#  {'feature': 'epi_AdmitType', 'rank': 81},
#  {'feature': 'M2102_CARE_TYPE_SRC_SPRVSN', 'rank': 82},
#  {'feature': 'M1311_NSTG_DRSG_D1', 'rank': 83},
#  {'feature': 'M2401_INTRVTN_SMRY_PRSULC_PRVN', 'rank': 84},
#  {'feature': 'M1033_HOSP_RISK_MLTPL_ED_VISIT', 'rank': 85},
#  {'feature': 'M2030_CRNT_MGMT_INJCTN_MDCTN', 'rank': 86},
#  {'feature': 'M0140_ETHNIC_AI_AN', 'rank': 87},
#  {'feature': 'M2310_ECR_UNKNOWN', 'rank': 88},
#  {'feature': 'M2020_CRNT_MGMT_ORAL_MDCTN', 'rank': 89},
#  {'feature': 'M2401_INTRVTN_SMRY_PRSULC_WET', 'rank': 90},
#  {'feature': 'M1056_PVX_RSN_NOT_RCVD_AGNCY', 'rank': 91},
#  {'feature': 'M1311_NBR_PRSULC_STG2_A1', 'rank': 92},
#  {'feature': 'M0110_EPISODE_TIMING', 'rank': 93},
#  {'feature': 'year_born', 'rank': 94},
#  {'feature': 'M1342_STUS_PRBLM_SRGCL_WND', 'rank': 95},
#  {'feature': 'M1311_NSTG_DEEP_TSUE_F1', 'rank': 96},
#  {'feature': 'M1700_COG_FUNCTION', 'rank': 97},
#  {'feature': 'M0140_ETHNIC_NH_PI', 'rank': 98},
#  {'feature': 'M1745_BEH_PROB_FREQ', 'rank': 99},
#  {'feature': 'M1051_PVX_RCVD_AGNCY', 'rank': 100},
#  {'feature': 'M1046_INFLNZ_RECD_CRNT_SEASON', 'rank': 101},
#  {'feature': 'M1033_HOSP_RISK_5PLUS_MDCTN', 'rank': 102},
#  {'feature': 'M1000_DC_PSYCH_14_DA', 'rank': 103},
#  {'feature': 'M0906_DC_TRAN_DTH_DT', 'rank': 104},
#  {'feature': 'M1311_NBR_PRSULC_STG3_B1', 'rank': 105},
#  {'feature': 'M1060_HEIGHT_A', 'rank': 106},
#  {'feature': 'epi_weight', 'rank': 107},
#  {'feature': 'M1000_DC_SNF_14_DA', 'rank': 108},
#  {'feature': 'M1000_DC_IRF_14_DA', 'rank': 109},
#  {'feature': 'M1720_WHEN_ANXIOUS', 'rank': 110},
#  {'feature': 'ceo_HHRG', 'rank': 111},
#  {'feature': 'M0140_ETHNIC_ASIAN', 'rank': 112},
#  {'feature': 'epi_height', 'rank': 113},
#  {'feature': 'M1630_OSTOMY', 'rank': 114},
#  {'feature': 'M0140_ETHNIC_BLACK', 'rank': 115},
#  {'feature': 'M1000_DC_OTH_14_DA', 'rank': 116},
#  {'feature': 'M1311_NBR_PRSULC_STG4_C1', 'rank': 117},
#  {'feature': 'ceo_HIPPS', 'rank': 118},
#  {'feature': 'M1000_DC_LTCH_14_DA', 'rank': 119},
#  {'feature': 'M1060_WEIGHT_B', 'rank': 120},
#  {'feature': 'M1000_DC_LTC_14_DA', 'rank': 121},
#  {'feature': 'M1610_UR_INCONT', 'rank': 122},
#  {'feature': 'M1311_NSTG_CVRG_E1', 'rank': 123},
#  {'feature': 'icd_code', 'rank': 124}]

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(X_train, y_train)


model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(X_train)
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
## !pip install statsmodels

# %%
import statsmodels.api as sm
def get_stats():
    #x = df[df.columns[:-1]]
    results = sm.OLS(y_train, X_train).fit()
    print(results.summary())
get_stats()
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       patient_deceased   R-squared (uncentered):                   0.765
# Model:                            OLS   Adj. R-squared (uncentered):              0.763
# Method:                 Least Squares   F-statistic:                              523.9
# Date:                Mon, 18 Apr 2022   Prob (F-statistic):                        0.00
# Time:                        19:33:27   Log-Likelihood:                         -6219.4
# No. Observations:               20736   AIC:                                  1.269e+04
# Df Residuals:                   20608   BIC:                                  1.371e+04
# Df Model:                         128
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# year_born                         -0.0036      0.000    -17.954      0.000      -0.004      -0.003
# pa_race                            0.0257      0.001     25.479      0.000       0.024       0.028
# pa_gender                          0.0308      0.005      6.374      0.000       0.021       0.040
# pa_maritalstatus                  -0.0135      0.001    -15.427      0.000      -0.015      -0.012
# epi_AdmitType                     -0.0073      0.003     -2.262      0.024      -0.014      -0.001
# epi_height                        -0.0008      0.000     -1.663      0.096      -0.002       0.000
# epi_weight                        -0.0005      0.000     -2.613      0.009      -0.001      -0.000
# ceo_HIPPS                      -5.284e-05   5.84e-05     -0.905      0.366      -0.000    6.16e-05
# ceo_HHRG                       -4.679e-05      0.001     -0.089      0.929      -0.001       0.001
# icd_code                        2.771e-05   1.05e-05      2.650      0.008    7.22e-06    4.82e-05
# DiagnosisCategory                 -0.0106      0.001     -9.103      0.000      -0.013      -0.008
# RoughAge                          -0.0129      0.000    -47.479      0.000      -0.013      -0.012
# M0100_ASSMT_REASON                 0.0216      0.008      2.545      0.011       0.005       0.038
# M0110_EPISODE_TIMING               0.0057      0.004      1.499      0.134      -0.002       0.013
# M0140_ETHNIC_AI_AN                 0.0178      0.055      0.324      0.746      -0.090       0.125
# M0140_ETHNIC_ASIAN                -0.1019      0.064     -1.591      0.112      -0.227       0.024
# M0140_ETHNIC_BLACK                -0.0122      0.048     -0.255      0.799      -0.106       0.082
# M0140_ETHNIC_HISP                  0.0566      0.051      1.112      0.266      -0.043       0.156
# M0140_ETHNIC_NH_PI                 0.3367      0.129      2.616      0.009       0.084       0.589
# M0140_ETHNIC_WHITE                -0.0019      0.047     -0.041      0.967      -0.095       0.091
# M0906_DC_TRAN_DTH_DT               0.0010   1.52e-05     67.274      0.000       0.001       0.001
# M1000_DC_IPPS_14_DA               -0.0111      0.027     -0.409      0.682      -0.064       0.042
# M1000_DC_IRF_14_DA                -0.0364      0.029     -1.241      0.215      -0.094       0.021
# M1000_DC_LTC_14_DA                -0.0380      0.057     -0.667      0.505      -0.150       0.074
# M1000_DC_LTCH_14_DA               -0.0844      0.062     -1.364      0.173      -0.206       0.037
# M1000_DC_NONE_14_DA               -0.1115      0.028     -3.919      0.000      -0.167      -0.056
# M1000_DC_OTH_14_DA                 0.1299      0.090      1.440      0.150      -0.047       0.307
# M1000_DC_PSYCH_14_DA               0.0084      0.077      0.109      0.913      -0.142       0.159
# M1000_DC_SNF_14_DA                -0.0882      0.027     -3.273      0.001      -0.141      -0.035
# M1028_ACTV_DIAG_DM                -0.0156      0.010     -1.559      0.119      -0.035       0.004
# M1028_ACTV_DIAG_NOA               -0.0031      0.010     -0.317      0.751      -0.022       0.016
# M1028_ACTV_DIAG_PVD_PAD            0.0241      0.010      2.365      0.018       0.004       0.044
# M1030_THH_ENT_NUTRITION           -0.0062      0.027     -0.232      0.817      -0.059       0.047
# M1030_THH_IV_INFUSION             -0.0235      0.026     -0.913      0.361      -0.074       0.027
# M1030_THH_NONE_ABOVE              -0.0263      0.024     -1.074      0.283      -0.074       0.022
# M1030_THH_PAR_NUTRITION            0.1272      0.035      3.638      0.000       0.059       0.196
# M1033_HOSP_RISK_5PLUS_MDCTN       -0.0385      0.014     -2.675      0.007      -0.067      -0.010
# M1033_HOSP_RISK_COMPLIANCE         0.0033      0.008      0.427      0.670      -0.012       0.018
# M1033_HOSP_RISK_CRNT_EXHSTN        0.0202      0.007      2.906      0.004       0.007       0.034
# M1033_HOSP_RISK_HSTRY_FALLS       -0.0355      0.007     -5.184      0.000      -0.049      -0.022
# M1033_HOSP_RISK_MLTPL_ED_VISIT     0.0378      0.009      4.266      0.000       0.020       0.055
# M1033_HOSP_RISK_MLTPL_HOSPZTN     -0.0240      0.009     -2.641      0.008      -0.042      -0.006
# M1033_HOSP_RISK_MNTL_BHV_DCLN     -0.0046      0.009     -0.537      0.591      -0.021       0.012
# M1033_HOSP_RISK_NONE_ABOVE        -0.0432      0.019     -2.335      0.020      -0.079      -0.007
# M1033_HOSP_RISK_OTHR_RISK         -0.0013      0.007     -0.198      0.843      -0.014       0.012
# M1033_HOSP_RISK_WEIGHT_LOSS        0.0855      0.010      8.649      0.000       0.066       0.105
# M1046_INFLNZ_RECD_CRNT_SEASON     -0.0088      0.001     -6.529      0.000      -0.012      -0.006
# M1051_PVX_RCVD_AGNCY              -0.0697      0.016     -4.301      0.000      -0.101      -0.038
# M1056_PVX_RSN_NOT_RCVD_AGNCY       0.0118      0.005      2.296      0.022       0.002       0.022
# M1060_HEIGHT_A                     0.0011      0.001      1.904      0.057   -3.09e-05       0.002
# M1060_WEIGHT_B                    -0.0002    5.9e-05     -3.156      0.002      -0.000   -7.06e-05
# M1200_VISION                      -0.0038      0.007     -0.564      0.573      -0.017       0.009
# M1242_PAIN_FREQ_ACTVTY_MVMT       -0.0091      0.002     -3.984      0.000      -0.014      -0.005
# M1306_UNHLD_STG2_PRSR_ULCR        -0.0109      0.047     -0.233      0.816      -0.103       0.081
# M1307_OLDST_STG2_AT_DSCHRG         0.0114      0.028      0.409      0.683      -0.043       0.066
# M1307_OLDST_STG2_ONST_DT           0.0276      0.022      1.267      0.205      -0.015       0.070
# M1311_NBR_PRSULC_STG2_A1          -0.0086      0.005     -1.576      0.115      -0.019       0.002
# M1311_NBR_PRSULC_STG3_B1           0.0286      0.010      2.988      0.003       0.010       0.047
# M1311_NBR_PRSULC_STG4_C1           0.0120      0.010      1.236      0.217      -0.007       0.031
# M1311_NBR_ULC_SOCROC_STG2_A2      -0.0102      0.023     -0.437      0.662      -0.056       0.035
# M1311_NBR_ULC_SOCROC_STG3_B2       0.0383      0.026      1.489      0.137      -0.012       0.089
# M1311_NBR_ULC_SOCROC_STG4_C2       0.0375      0.039      0.964      0.335      -0.039       0.114
# M1311_NSTG_CVRG_E1                 0.0228      0.011      2.163      0.031       0.002       0.043
# M1311_NSTG_CVRG_SOCROC_E2          0.0382      0.028      1.371      0.170      -0.016       0.093
# M1311_NSTG_DEEP_TSUE_F1           -0.0273      0.010     -2.681      0.007      -0.047      -0.007
# M1311_NSTG_DEEP_TSUE_SOCROC_F2    -0.1964      0.156     -1.256      0.209      -0.503       0.110
# M1311_NSTG_DRSG_D1                -0.0326      0.021     -1.568      0.117      -0.073       0.008
# M1311_NSTG_DRSG_SOCROC_D2          0.0243      0.062      0.393      0.694      -0.097       0.145
# M1324_STG_PRBLM_ULCER             -0.0153      0.004     -3.508      0.000      -0.024      -0.007
# M1330_STAS_ULCR_PRSNT              0.0082      0.013      0.652      0.515      -0.017       0.033
# M1332_NBR_STAS_ULCR               -0.0040      0.008     -0.490      0.624      -0.020       0.012
# M1334_STUS_PRBLM_STAS_ULCR         0.0109      0.014      0.773      0.440      -0.017       0.039
# M1340_SRGCL_WND_PRSNT             -0.0392      0.008     -5.196      0.000      -0.054      -0.024
# M1342_STUS_PRBLM_SRGCL_WND        -0.0071      0.003     -2.623      0.009      -0.012      -0.002
# M1400_WHEN_DYSPNEIC                0.0350      0.003     11.781      0.000       0.029       0.041
# M1600_UTI                         -0.0289      0.007     -3.970      0.000      -0.043      -0.015
# M1610_UR_INCONT                   -0.0053      0.005     -1.100      0.271      -0.015       0.004
# M1620_BWL_INCONT                   0.0079      0.003      2.965      0.003       0.003       0.013
# M1630_OSTOMY                      -0.0792      0.018     -4.512      0.000      -0.114      -0.045
# M1700_COG_FUNCTION                -0.0043      0.006     -0.706      0.480      -0.016       0.008
# M1710_WHEN_CONFUSED                0.0098      0.005      2.075      0.038       0.001       0.019
# M1720_WHEN_ANXIOUS                -0.0014      0.004     -0.353      0.724      -0.009       0.007
# M1730_PHQ2_DPRSN                  -0.0025      0.011     -0.238      0.812      -0.023       0.018
# M1730_PHQ2_LACK_INTRST             0.0038      0.011      0.362      0.717      -0.017       0.024
# M1730_STDZ_DPRSN_SCRNG             0.0122      0.010      1.228      0.219      -0.007       0.032
# M1740_BD_DELUSIONS                 0.0135      0.026      0.516      0.606      -0.038       0.065
# M1740_BD_IMP_DECISN               -0.0011      0.014     -0.075      0.940      -0.029       0.027
# M1740_BD_MEM_DEFICIT               0.0052      0.013      0.398      0.691      -0.021       0.031
# M1740_BD_NONE                      0.0010      0.016      0.062      0.951      -0.031       0.033
# M1740_BD_PHYSICAL                  0.0300      0.046      0.649      0.516      -0.061       0.121
# M1740_BD_SOC_INAPPRO              -0.0639      0.052     -1.238      0.216      -0.165       0.037
# M1740_BD_VERBAL                   -0.0022      0.028     -0.076      0.939      -0.057       0.053
# M1745_BEH_PROB_FREQ               -0.0018      0.003     -0.622      0.534      -0.008       0.004
# M1800_CRNT_GROOMING                0.0091      0.008      1.164      0.245      -0.006       0.024
# M1810_CRNT_DRESS_UPPER             0.0028      0.009      0.311      0.756      -0.015       0.020
# M1820_CRNT_DRESS_LOWER             0.0101      0.007      1.380      0.167      -0.004       0.025
# M1830_CRNT_BATHG                   0.0034      0.003      1.136      0.256      -0.002       0.009
# M1840_CRNT_TOILTG                  0.0187      0.005      4.027      0.000       0.010       0.028
# M1845_CRNT_TOILTG_HYGN            -0.0095      0.006     -1.500      0.134      -0.022       0.003
# M1850_CRNT_TRNSFRNG                0.0063      0.005      1.155      0.248      -0.004       0.017
# M1860_CRNT_AMBLTN                  0.0027      0.004      0.664      0.507      -0.005       0.011
# M1870_CRNT_FEEDING                 0.0101      0.005      1.843      0.065      -0.001       0.021
# M1910_MLT_FCTR_FALL_RISK_ASMT     -0.0148      0.015     -0.989      0.323      -0.044       0.015
# M2001_DRUG_RGMN_RVW               -0.0428      0.021     -2.082      0.037      -0.083      -0.003
# M2003_MDCTN_FLWP                  -0.0183      0.016     -1.127      0.260      -0.050       0.014
# M2005_MDCTN_INTRVTN                0.0048      0.006      0.822      0.411      -0.007       0.016
# M2010_HIGH_RISK_DRUG_EDCTN         0.0195      0.009      2.220      0.026       0.002       0.037
# M2016_DRUG_EDCTN_INTRVTN           0.0761      0.025      3.014      0.003       0.027       0.126
# M2020_CRNT_MGMT_ORAL_MDCTN        -0.0007      0.005     -0.146      0.884      -0.009       0.008
# M2030_CRNT_MGMT_INJCTN_MDCTN       0.0042      0.004      0.944      0.345      -0.005       0.013
# M2102_CARE_TYPE_SRC_ADL           -0.0174      0.011     -1.616      0.106      -0.039       0.004
# M2102_CARE_TYPE_SRC_MDCTN          0.0107      0.012      0.928      0.354      -0.012       0.033
# M2102_CARE_TYPE_SRC_PRCDR         -0.0184      0.010     -1.894      0.058      -0.037       0.001
# M2102_CARE_TYPE_SRC_SPRVSN         0.0069      0.004      1.719      0.086      -0.001       0.015
# M2200_THER_NEED_NA                 0.1171      0.029      3.978      0.000       0.059       0.175
# M2301_EMER_USE_AFTR_LAST_ASMT      0.0337      0.008      4.240      0.000       0.018       0.049
# M2310_ECR_HYPOGLYC                 0.0400      0.049      0.812      0.417      -0.057       0.136
# M2310_ECR_MEDICATION              -0.0853      0.066     -1.297      0.195      -0.214       0.044
# M2310_ECR_OTHER                    0.0280      0.033      0.857      0.391      -0.036       0.092
# M2310_ECR_UNKNOWN                  0.0242      0.038      0.644      0.520      -0.050       0.098
# M2401_INTRVTN_SMRY_DBTS_FT         0.0141      0.007      2.159      0.031       0.001       0.027
# M2401_INTRVTN_SMRY_DPRSN           0.0178      0.006      2.766      0.006       0.005       0.030
# M2401_INTRVTN_SMRY_FALL_PRVNT      0.0492      0.020      2.472      0.013       0.010       0.088
# M2401_INTRVTN_SMRY_PAIN_MNTR      -0.0016      0.013     -0.126      0.900      -0.027       0.024
# M2401_INTRVTN_SMRY_PRSULC_PRVN    -0.0023      0.007     -0.327      0.743      -0.016       0.011
# M2401_INTRVTN_SMRY_PRSULC_WET     -0.0073      0.009     -0.854      0.393      -0.024       0.009
# M2410_INPAT_FACILITY              -0.0024      0.013     -0.178      0.859      -0.028       0.024
# M2420_DSCHRG_DISP                  0.0684      0.008      8.423      0.000       0.053       0.084
# ==============================================================================
# Omnibus:                      936.733   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1066.370
# Skew:                           0.553   Prob(JB):                    2.76e-232
# Kurtosis:                       2.902   Cond. No.                     5.36e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 5.36e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
def get_models():
    models = dict()
    for i in range(2, 10):
        rfe = RFE(estimator=LogisticRegression(), n_features_to_select=i)
        model = LogisticRegression()
        models[str(i)] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# %%
models = get_models()

# %%
def evaluate_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
    return scores

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from matplotlib import pyplot

## UNCOMMENT AND RUN if you have a lot of time. Will take a long time.

# results, names = list(), list()
# for name, model in models.items():
#     scores = evaluate_model(model, X_train, y_train)
#     results.append(scores)
#     names.append(name)    
# # plot model performance for comparison
# pyplot.boxplot(results, labels=names, showmeans=True)
# pyplot.show()

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

def get_different_models():
    models = dict()
    # lr
    rfe = RFE(estimator=LogisticRegression(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['lr'] = Pipeline(steps=[('s',rfe),('m',model)])
    # lin
    rfe = RFE(estimator=LinearRegression(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['lin'] = Pipeline(steps=[('s',rfe),('m',model)])
    # cart
    rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['cart'] = Pipeline(steps=[('s',rfe),('m',model)])
    # rf
    rfe = RFE(estimator=RandomForestClassifier(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['rf'] = Pipeline(steps=[('s',rfe),('m',model)])
    # gbm
    rfe = RFE(estimator=GradientBoostingClassifier(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['gbm'] = Pipeline(steps=[('s',rfe),('m',model)])
    return models
diff_models = get_different_models()

# %%
def evaluate_different_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
    return scores

## UNCOMMENT AND RUN if you have a lot of time. Will take a long time.

# results, names = list(), list()
# for name, model in diff_models.items():
#     scores = evaluate_different_model(model, X, y)
#     results.append(scores)
#     names.append(name)

# pyplot.boxplot(results, labels=names, showmeans=True)
# pyplot.show()

# %% [markdown]
# ### Feature Elimination and Variance Check: GBR

# %%
def fe_gbr(n_):
    from sklearn.ensemble import GradientBoostingRegressor

    # Select 10 features with RFE on a GradientBoostingRegressor, drop 3 features on each step
    rfe_gb = RFE(estimator=GradientBoostingRegressor(),
                n_features_to_select=n_, step=3)
    rfe_gb.fit(X_train, y_train)

    # Calculate the R squared on the test set
    r_squared = rfe_gb.score(X_test, y_test)
    print('The model can explain {0:.1%} of the variance in the test set'.format(r_squared))

    # Assign the support array to gb_mask
    gb_mask = rfe_gb.support_
    return gb_mask, r_squared

# %% [markdown]
# ### Feature Elimination and Variance Check: RandomForest

# %%
def fe_rf(n_):
    from sklearn.ensemble import RandomForestRegressor

    rfe_rf = RFE(estimator=RandomForestRegressor(),
                n_features_to_select=n_, step=3)
    rfe_rf.fit(X_train, y_train)

    # Calculate the R squared on the test set
    r_squared = rfe_rf.score(X_test, y_test)
    print('The model can explain {0:.1%} of the variance in the test set'.format(r_squared))

    # Assign the support array to rf_mask
    rf_mask = rfe_rf.support_
    return rf_mask, r_squared

# %% [markdown]
# ### Feature Elimination and Variance Check: Logistic

# %%
def fe_logistic(n_):
    from sklearn.linear_model import LogisticRegression
    rfe = RFE(estimator=LogisticRegression(), n_features_to_select=n_, step=3)
    rfe.fit(X_train, y_train)

    # Calculate the R squared on the test set
    r_squared = rfe.score(X_test, y_test)
    print('The model can explain {0:.1%} of the variance in the test set'.format(r_squared))

    # Assign the support array to rf_mask
    logi_mask = rfe.support_
    return logi_mask, r_squared

# %% [markdown]
# ### Run All Feature Elimination code and compare

# %%
# RUN ALL MODELS

result = {}
for n in range(5, 130, 5):
    g, gr = fe_gbr(n)
    r, rr = fe_rf(n)
    lo, lor = fe_logistic(n)
    print(f'Number of Features: {n}')
    print(f'Gradient Boosing R-squared value: {gr}')
    print(f'Random Forest R-squared value: {rr}')
    print(f'Logistic Regression R-squared value: {lor}')
    result[n] = {'GB': gr, 'RF': rr, 'LR': lor}
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 66.7% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X[:, features], y, **fit_params)
# The model can explain 89.1% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X[:, features], y, **fit_params)
# The model can explain 91.0% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 87.8% of the variance in the test set
# Number of Features: 115
# Gradient Boosing R-squared value: 0.7272608091452226
# Random Forest R-squared value: 0.9101490518943662
# Logistic Regression R-squared value: 0.8784722222222222
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 72.7% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X[:, features], y, **fit_params)
# The model can explain 91.1% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 87.7% of the variance in the test set
# Number of Features: 120
# Gradient Boosing R-squared value: 0.7272618250767037
# Random Forest R-squared value: 0.9106634255298764
# Logistic Regression R-squared value: 0.8770254629629629
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 72.7% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X[:, features], y, **fit_params)
# The model can explain 91.2% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 87.7% of the variance in the test set
# Number of Features: 125
# Gradient Boosing R-squared value: 0.7272879518756343
# Random Forest R-squared value: 0.9120154917004153
# Logistic Regression R-squared value: 0.8765914351851852
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
result
# Out:
# {5: {'GB': 0.6666949025563207,
#   'RF': 0.890556042895147,
#   'LR': 0.5908564814814815},
#  10: {'GB': 0.7125193498747047,
#   'RF': 0.9111775651730585,
#   'LR': 0.8059895833333334},
#  15: {'GB': 0.7294360788960418,
#   'RF': 0.9179249679496185,
#   'LR': 0.8062789351851852},
#  20: {'GB': 0.7288360060136382,
#   'RF': 0.9114274689795978,
#   'LR': 0.8101851851851852},
#  25: {'GB': 0.729024240254193,
#   'RF': 0.9126600235684981,
#   'LR': 0.8136574074074074},
#  30: {'GB': 0.7280130216257921,
#   'RF': 0.9127017911990855,
#   'LR': 0.8178530092592593},
#  35: {'GB': 0.7284477168602357,
#   'RF': 0.9142718797214435,
#   'LR': 0.8221932870370371},
#  40: {'GB': 0.7286136215566417,
#   'RF': 0.913890004241788,
#   'LR': 0.8211805555555556},
#  45: {'GB': 0.728154155331417,
#   'RF': 0.9128750040200505,
#   'LR': 0.8210358796296297},
#  50: {'GB': 0.7272161276648442,
#   'RF': 0.9129842784373293,
#   'LR': 0.8207465277777778},
#  55: {'GB': 0.7275276027057529,
#   'RF': 0.9115200129454089,
#   'LR': 0.8297164351851852},
#  60: {'GB': 0.7271529411542517,
#   'RF': 0.9107188232135827,
#   'LR': 0.8295717592592593},
#  65: {'GB': 0.7272119684814917,
#   'RF': 0.9127907667818912,
#   'LR': 0.8276909722222222},
#  70: {'GB': 0.7272889307462508,
#   'RF': 0.910721338631111,
#   'LR': 0.8253761574074074},
#  75: {'GB': 0.7272816984850752,
#   'RF': 0.9120537494460794,
#   'LR': 0.8300057870370371},
#  80: {'GB': 0.7272534904335769,
#   'RF': 0.910216734175304,
#   'LR': 0.8291377314814815},
#  85: {'GB': 0.7272868075240175,
#   'RF': 0.9110825642878011,
#   'LR': 0.8305844907407407},
#  90: {'GB': 0.7272826773556916,
#   'RF': 0.9112564790857508,
#   'LR': 0.8318865740740741},
#  95: {'GB': 0.7272889307462509,
#   'RF': 0.9110031238923703,
#   'LR': 0.8298611111111112},
#  100: {'GB': 0.7272879518756343,
#   'RF': 0.9094538606872238,
#   'LR': 0.8305844907407407},
#  105: {'GB': 0.7272618250767038,
#   'RF': 0.9100174312097423,
#   'LR': 0.8304398148148148},
#  110: {'GB': 0.7272868075240175,
#   'RF': 0.9089624767979613,
#   'LR': 0.8748553240740741},
#  115: {'GB': 0.7272608091452226,
#   'RF': 0.9101490518943662,
#   'LR': 0.8784722222222222},
#  120: {'GB': 0.7272618250767037,
#   'RF': 0.9106634255298764,
#   'LR': 0.8770254629629629},
#  125: {'GB': 0.7272879518756343,
#   'RF': 0.9120154917004153,
#   'LR': 0.8765914351851852}}

# %%
import matplotlib.pyplot as plt

gb = []
rf = []
lr = []
n = []
for k, v in result.items():
    gb.append(v['GB'])
    rf.append(v['RF'])
    lr.append(v['LR'])
    n.append(k)

plt.plot(n, gb, linestyle='-', marker='o', label='Gradient Boosting')
plt.plot(n, rf, linestyle='-', marker='o', label='Random Forest')
plt.plot(n, lr, linestyle='-', marker='o', label='Logistic Regression')

# x axis label
plt.xlabel('Number of features to be selected (RFE)')

# y axis label
plt.ylabel('R-squared value')

plt.legend()
plt.show()

# %%
# Sum the votes of the three models
votes = np.sum([lcv_mask, rf_mask, gb_mask], axis=0)
print(votes)

# Create a mask for features selected by all 3 models
meta_mask = votes == 3
print(meta_mask)

# Apply the dimensionality reduction on X
X_reduced = X.loc[:, meta_mask]
print(X_reduced.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11680/493139408.py in <module>
#       1 # Sum the votes of the three models
# ----> 2 votes = np.sum([lcv_mask, rf_mask, gb_mask], axis=0)
#       3 print(votes)
#       4
#       5 # Create a mask for features selected by all 3 models
#
# NameError: name 'lcv_mask' is not defined

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression

# Create the RFE object and compute a cross-validated score.
# The "accuracy" scoring shows the proportion of correct classifications

min_features_to_select = 1  # Minimum number of features to consider

rfecv = RFECV(
    estimator=LogisticRegression(),
    step=1,
    cv=StratifiedKFold(2),
    scoring="accuracy",
    min_features_to_select=min_features_to_select,
)
rfecv.fit(X_train, y_train)

print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (accuracy)")
plt.plot(
    range(min_features_to_select, len(rfecv.grid_scores_) + min_features_to_select),
    rfecv.grid_scores_,
)
plt.legend()
plt.show()
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but RFECV was fitted with feature names
#   warnings.warn(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: The `grid_scores_` attribute is deprecated in version 1.0 in favor of `cv_results_` and will be removed in version 1.2.
#   warnings.warn(msg, category=FutureWarning)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Optimal number of features : 110

# %%
selected_features = []
for i, rank in enumerate(rfecv.ranking_):
    feature = rfecv.feature_names_in_[i]
    selected_features.append({'feature': feature, 'rank': rank})
features_selected = [f['feature'] for f in selected_features if f['rank'] == 1]

# %%
df[(features_selected + ['patient_deceased'])].to_csv('chosen.csv')

# %%
features_selected
# Out:
# ['year_born',
#  'pa_race',
#  'pa_gender',
#  'pa_maritalstatus',
#  'epi_AdmitType',
#  'DiagnosisCategory',
#  'RoughAge',
#  'M0100_ASSMT_REASON',
#  'M0110_EPISODE_TIMING',
#  'M0140_ETHNIC_AI_AN',
#  'M0140_ETHNIC_HISP',
#  'M0140_ETHNIC_NH_PI',
#  'M0140_ETHNIC_WHITE',
#  'M0906_DC_TRAN_DTH_DT',
#  'M1000_DC_IPPS_14_DA',
#  'M1000_DC_NONE_14_DA',
#  'M1000_DC_PSYCH_14_DA',
#  'M1028_ACTV_DIAG_DM',
#  'M1028_ACTV_DIAG_NOA',
#  'M1028_ACTV_DIAG_PVD_PAD',
#  'M1030_THH_ENT_NUTRITION',
#  'M1030_THH_IV_INFUSION',
#  'M1030_THH_NONE_ABOVE',
#  'M1030_THH_PAR_NUTRITION',
#  'M1033_HOSP_RISK_5PLUS_MDCTN',
#  'M1033_HOSP_RISK_COMPLIANCE',
#  'M1033_HOSP_RISK_CRNT_EXHSTN',
#  'M1033_HOSP_RISK_HSTRY_FALLS',
#  'M1033_HOSP_RISK_MLTPL_ED_VISIT',
#  'M1033_HOSP_RISK_MLTPL_HOSPZTN',
#  'M1033_HOSP_RISK_MNTL_BHV_DCLN',
#  'M1033_HOSP_RISK_NONE_ABOVE',
#  'M1033_HOSP_RISK_OTHR_RISK',
#  'M1033_HOSP_RISK_WEIGHT_LOSS',
#  'M1046_INFLNZ_RECD_CRNT_SEASON',
#  'M1051_PVX_RCVD_AGNCY',
#  'M1056_PVX_RSN_NOT_RCVD_AGNCY',
#  'M1060_HEIGHT_A',
#  'M1200_VISION',
#  'M1242_PAIN_FREQ_ACTVTY_MVMT',
#  'M1306_UNHLD_STG2_PRSR_ULCR',
#  'M1307_OLDST_STG2_AT_DSCHRG',
#  'M1307_OLDST_STG2_ONST_DT',
#  'M1311_NBR_PRSULC_STG2_A1',
#  'M1311_NBR_PRSULC_STG3_B1',
#  'M1311_NBR_ULC_SOCROC_STG2_A2',
#  'M1311_NBR_ULC_SOCROC_STG3_B2',
#  'M1311_NBR_ULC_SOCROC_STG4_C2',
#  'M1311_NSTG_CVRG_SOCROC_E2',
#  'M1311_NSTG_DEEP_TSUE_F1',
#  'M1311_NSTG_DEEP_TSUE_SOCROC_F2',
#  'M1311_NSTG_DRSG_D1',
#  'M1311_NSTG_DRSG_SOCROC_D2',
#  'M1324_STG_PRBLM_ULCER',
#  'M1330_STAS_ULCR_PRSNT',
#  'M1332_NBR_STAS_ULCR',
#  'M1334_STUS_PRBLM_STAS_ULCR',
#  'M1340_SRGCL_WND_PRSNT',
#  'M1342_STUS_PRBLM_SRGCL_WND',
#  'M1400_WHEN_DYSPNEIC',
#  'M1600_UTI',
#  'M1620_BWL_INCONT',
#  'M1700_COG_FUNCTION',
#  'M1710_WHEN_CONFUSED',
#  'M1730_PHQ2_DPRSN',
#  'M1730_PHQ2_LACK_INTRST',
#  'M1730_STDZ_DPRSN_SCRNG',
#  'M1740_BD_DELUSIONS',
#  'M1740_BD_IMP_DECISN',
#  'M1740_BD_MEM_DEFICIT',
#  'M1740_BD_NONE',
#  'M1740_BD_PHYSICAL',
#  'M1740_BD_SOC_INAPPRO',
#  'M1740_BD_VERBAL',
#  'M1745_BEH_PROB_FREQ',
#  'M1800_CRNT_GROOMING',
#  'M1810_CRNT_DRESS_UPPER',
#  'M1820_CRNT_DRESS_LOWER',
#  'M1830_CRNT_BATHG',
#  'M1840_CRNT_TOILTG',
#  'M1845_CRNT_TOILTG_HYGN',
#  'M1850_CRNT_TRNSFRNG',
#  'M1860_CRNT_AMBLTN',
#  'M1870_CRNT_FEEDING',
#  'M1910_MLT_FCTR_FALL_RISK_ASMT',
#  'M2001_DRUG_RGMN_RVW',
#  'M2003_MDCTN_FLWP',
#  'M2005_MDCTN_INTRVTN',
#  'M2010_HIGH_RISK_DRUG_EDCTN',
#  'M2016_DRUG_EDCTN_INTRVTN',
#  'M2020_CRNT_MGMT_ORAL_MDCTN',
#  'M2030_CRNT_MGMT_INJCTN_MDCTN',
#  'M2102_CARE_TYPE_SRC_ADL',
#  'M2102_CARE_TYPE_SRC_MDCTN',
#  'M2102_CARE_TYPE_SRC_PRCDR',
#  'M2102_CARE_TYPE_SRC_SPRVSN',
#  'M2200_THER_NEED_NA',
#  'M2301_EMER_USE_AFTR_LAST_ASMT',
#  'M2310_ECR_HYPOGLYC',
#  'M2310_ECR_MEDICATION',
#  'M2310_ECR_OTHER',
#  'M2310_ECR_UNKNOWN',
#  'M2401_INTRVTN_SMRY_DBTS_FT',
#  'M2401_INTRVTN_SMRY_DPRSN',
#  'M2401_INTRVTN_SMRY_FALL_PRVNT',
#  'M2401_INTRVTN_SMRY_PAIN_MNTR',
#  'M2401_INTRVTN_SMRY_PRSULC_PRVN',
#  'M2401_INTRVTN_SMRY_PRSULC_WET',
#  'M2410_INPAT_FACILITY',
#  'M2420_DSCHRG_DISP']

# %%
len(features_selected)
# Out:
# 110
