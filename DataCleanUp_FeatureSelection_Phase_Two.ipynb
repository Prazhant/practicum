# %%
import pandas as pd
from pathlib import Path  
import sys
import sqlite3

CUT_OF_UNIQUE_VALUES=40

# %%
data_filtered_cedd=pd.read_csv("cleaned_data_with_binary_dead.csv")
df_counts  = pd.DataFrame(columns = ['col', 'count'])
for col in data_filtered_cedd:
    no_of_unique_values=data_filtered_cedd[col].nunique()
    df_counts.loc[len(df_counts)]=[col,no_of_unique_values]
#     if( not col.startswith( 'Unnamed' ) && no_of_unique_values<20):
#         print("%s--->%s"%(col,))
df_counts = df_counts.sort_values(by=['count'], ascending=False)
display(df_counts.head(30))

count=0

for col in data_filtered_cedd:
    no_of_unique_values=data_filtered_cedd[col].nunique()
    if( not col.startswith( 'Unnamed' ) and no_of_unique_values<40):
        count =count+1
        #data_filtered_cedd[col].fillna("imputed",inplace=True)
        data_filtered_cedd[col]=pd.Categorical(data_filtered_cedd[col])
                
data_filtered_cedd.dtypes.value_counts()



count
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (75,83,88,136) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                           col  count
# 0                  Unnamed: 0  28122
# 2              Unnamed: 0.1.1  28122
# 1                Unnamed: 0.1  28122
# 29                     ceo_id  15744
# 28                     epi_id   7432
# 4                       pa_id   5930
# 13                epi_SocDate   1056
# 22                   icd_code    967
# 23       icd_code_description    965
# 14         epi_StartOfEpisode    833
# 25           cedd_dateofdeath    772
# 31    M0090_INFO_COMPLETED_DT    660
# 40       M0906_DC_TRAN_DTH_DT    619
# 15           epi_EndOfEpisode    616
# 16          epi_DischargeDate    613
# 26                DaysToDeath    334
# 70             M1060_WEIGHT_B    303
# 19                  ceo_HIPPS    226
# 18                 epi_weight    181
# 136       M2200_THER_NEED_NBR    108
# 5                   year_born     90
# 17                 epi_height     72
# 27                   RoughAge     67
# 20                   ceo_HHRG     39
# 69             M1060_HEIGHT_A     31
# 12                   dcr_desc     21
# 11                  epi_dcrid     21
# 76   M1311_NBR_PRSULC_STG2_A1     12
# 88      M1322_NBR_PRSULC_STG1     12
# 24          DiagnosisCategory     11
# 133

# %% [markdown]
# ### New Binary Column for label and drop alive patients with less than 365 days of history

# %%
from datetime import timedelta
import numpy as np

##### adding our binary column to denote if patient is dead
df = data_filtered_cedd
df['patient_deceased'] = np.where((df['DaysToDeath'] <= 365) | (df['dcc_desc'] == 'PATIENT EXPIRED'), 1, 0)

# %%
##### defining our year threshold, and converting neccesary col's to datetimes

threesixtyfive = timedelta(days = 365)

df['epi_SocDate'] = pd.to_datetime(df['epi_SocDate'])
df['epi_EndOfEpisode'] = pd.to_datetime(df['epi_EndOfEpisode'])
df['M0906_DC_TRAN_DTH_DT'] = pd.to_datetime(df['M0906_DC_TRAN_DTH_DT'].fillna(df['epi_SocDate']))

# %%
##### dropping all 'alive' patients with LESS than a year of history

for index, row in df.iterrows():
    if row['patient_deceased'] == 0 and row['epi_EndOfEpisode'] - row['epi_SocDate'] < threesixtyfive:
        df.drop(index, axis = 0, inplace = True)

# %%
##### dropping all 'dead' patients with MORE than a year of history

for index, row in df.iterrows():
    if row['patient_deceased'] == 1 and row['epi_EndOfEpisode'] - row['epi_SocDate'] > threesixtyfive:
        row['patient_deceased'] == 0

# %%
len(df)
# Out:
# 12981

# %%
df["M1056_PVX_RSN_NOT_RCVD_AGNCY"].cat.categories
df.groupby(['M1056_PVX_RSN_NOT_RCVD_AGNCY']).size()

df["M1200_VISION"].cat.categories
df.groupby(['M1200_VISION']).size()
# Out:
# M1200_VISION
# 0 - NORMAL VISION: SEES ADEQUATELY IN MOST SITUATIONS; CAN SEE MEDICATION LABELS, NEWSPRINT                                                                        5242
# 1 - PARTIALLY IMPAIRED: CANNOT SEE MEDICATION LABELS OR NEWSPRINT, BUT CAN SEE OBSTACLES IN PATH, AND THE SURROUNDING LAYOUT; CAN COUNT FINGERS AT ARM'S LENGTH    1847
# 2 - SEVERELY IMPAIRED: CANNOT LOCATE OBJECTS WITHOUT HEARING OR TOUCHING THEM OR PATIENT NONRESPONSIVE                                                               95
# dtype: int64

# %% [markdown]
# ### Drop columns with no meaning

# %%
df = df.drop(columns=['CreatedDate', 'CreatedBy', 'UpdateDate', 'UpdateBy', 'ActiveFlag'])

# %%
df['DaysToDeath']
# Out:
# 40       194.0
# 41       194.0
# 42       194.0
# 43       194.0
# 76        12.0
#          ...
# 28117      2.0
# 28118      2.0
# 28119      2.0
# 28120      2.0
# 28121      2.0
# Name: DaysToDeath, Length: 12981, dtype: float64

# %% [markdown]
# ### Find columns with name ID

# %%
[col for col in df.columns if 'id' in col]
# Out:
# ['pa_id', 'epi_dcrid', 'epi_id', 'ceo_id']

# %%
[col for col in df.columns if 'Id' in col]
# Out:
# ['DispositionId']

# %% [markdown]
# ### Drop ID columns... this could give model too much hint

# %%
df = df.drop(columns=['DispositionId', 'pa_id', 'epi_dcrid', 'epi_id', 'ceo_id'])

# %% [markdown]
# ### Drop records with DaysToDeath = 0

# %%
df.dropna(subset=['DaysToDeath'])
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  year_born pa_race pa_gender  \
# 40             40            40              40       1930     NaN    MALE
# 41             41            41              41       1930     NaN    MALE
# 42             42            42              42       1930     NaN    MALE
# 43             43            43              43       1930     NaN    MALE
# 76             76            76              76       1966     NaN    FEMALE
# ...           ...           ...             ...        ...     ...       ...
# 28117       28117         28117           28117       1940     NaN    FEMALE
# 28118       28118         28118           28118       1940     NaN    FEMALE
# 28119       28119         28119           28119       1940     NaN    FEMALE
# 28120       28120         28120           28120       1940     NaN    FEMALE
# 28121       28121         28121           28121       1940     NaN    FEMALE
#
#       pa_maritalstatus    epi_AdmitType         dcc_desc         dcr_desc  \
# 40                 NaN  RECERTIFICATION  PATIENT EXPIRED  PATIENT EXPIRED
# 41                 NaN  RECERTIFICATION  PATIENT EXPIRED  PATIENT EXPIRED
# 42                 NaN  RECERTIFICATION  PATIENT EXPIRED  PATIENT EXPIRED
# 43                 NaN  RECERTIFICATION  PATIENT EXPIRED  PATIENT EXPIRED
# 76                 NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# ...                ...              ...              ...              ...
# 28117              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# 28118              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# 28119              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# 28120              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
# 28121              NaN    NEW ADMISSION  PATIENT EXPIRED  PATIENT EXPIRED
#
#        ... M2310_ECR_UNKNOWN  \
# 40     ...               NaN
# 41     ...               NaN
# 42     ...               NaN
# 43     ...               NaN
# 76     ...               NaN
# ...    ...               ...
# 28117  ...               NaN
# 28118  ...               NaN
# 28119  ...                NO
# 28120  ...               NaN
# 28121  ...               NaN
#
#                               M2401_INTRVTN_SMRY_DBTS_FT  \
# 40                                                   NaN
# 41                                                   NaN
# 42                                                   NaN
# 43                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 28117                                                NaN
# 28118                                                NaN
# 28119  NA - PATIENT IS NOT DIABETIC OR IS MISSING LOW...
# 28120                                                NaN
# 28121                                                NaN
#
#                                 M2401_INTRVTN_SMRY_DPRSN  \
# 40                                                   NaN
# 41                                                   NaN
# 42                                                   NaN
# 43                                                   NaN
# 76                                                   NaN
# ...                                                  ...
# 28117                                                NaN
# 28118                                                NaN
# 28119  NA - (C2) PATIENT HAS NO DIAGNOSIS OF DEPRESSI...
# 28120                                                NaN
# 28121                                                NaN
#
#       M2401_INTRVTN_SMRY_FALL_PRVNT  M2401_INTRVTN_SMRY_PAIN_MNTR  \
# 40                              NaN                           NaN
# 41                              NaN                           NaN
# 42                              NaN                           NaN
# 43                              NaN                           NaN
# 76                              NaN                           NaN
# ...                             ...                           ...
# 28117                           NaN                           NaN
# 28118                           NaN                           NaN
# 28119                       1 - YES                       1 - YES
# 28120                           NaN                           NaN
# 28121                           NaN                           NaN
#
#        M2401_INTRVTN_SMRY_PRSULC_PRVN  \
# 40                                NaN
# 41                                NaN
# 42                                NaN
# 43                                NaN
# 76                                NaN
# ...                               ...
# 28117                             NaN
# 28118                             NaN
# 28119                         1 - YES
# 28120                             NaN
# 28121                             NaN
#
#                            M2401_INTRVTN_SMRY_PRSULC_WET M2410_INPAT_FACILITY  \
# 40                                                   NaN                  NaN
# 41                                                   NaN                  NaN
# 42                                                   NaN                  NaN
# 43                                                   NaN                  NaN
# 76                                                   NaN                  NaN
# ...                                                  ...                  ...
# 28117                                                NaN                  NaN
# 28118                                                NaN                  NaN
# 28119  NA - PATIENT HAS NO PRESSURE ULCERS OR HAS NO ...         1 - HOSPITAL
# 28120                                                NaN                  NaN
# 28121                                                NaN                  NaN
#
#       M2420_DSCHRG_DISP patient_deceased
# 40                  NaN                1
# 41                  NaN                1
# 42                  NaN                1
# 43                  NaN                1
# 76                  NaN                1
# ...                 ...              ...
# 28117               NaN                1
# 28118               NaN                1
# 28119               NaN                1
# 28120               NaN                1
# 28121               NaN                1
#
# [11611 rows x 146 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df.select_dtypes(include=numerics)
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  year_born  epi_height  \
# 40             40            40              40       1930         NaN
# 41             41            41              41       1930         NaN
# 42             42            42              42       1930         NaN
# 43             43            43              43       1930         NaN
# 76             76            76              76       1966         NaN
# ...           ...           ...             ...        ...         ...
# 28117       28117         28117           28117       1940         NaN
# 28118       28118         28118           28118       1940         NaN
# 28119       28119         28119           28119       1940         NaN
# 28120       28120         28120           28120       1940         NaN
# 28121       28121         28121           28121       1940         NaN
#
#        epi_weight  DaysToDeath  RoughAge  patient_deceased
# 40            NaN        194.0       NaN                 1
# 41            NaN        194.0       NaN                 1
# 42            NaN        194.0       NaN                 1
# 43            NaN        194.0       NaN                 1
# 76            NaN         12.0       NaN                 1
# ...           ...          ...       ...               ...
# 28117         NaN          2.0      82.0                 1
# 28118         NaN          2.0      82.0                 1
# 28119         NaN          2.0      82.0                 1
# 28120         NaN          2.0      82.0                 1
# 28121         NaN          2.0      82.0                 1
#
# [12981 rows x 9 columns]

# %% [markdown]
# ### Drop columns that are giving hints as response variables (like cedd_dateofdeath).

# %%
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'])

# %%
### Also drop dcc_desc and dcr_desc

# %%
df.drop(['M2200_THER_NEED_NBR', 'M1322_NBR_PRSULC_STG1', 'M0090_INFO_COMPLETED_DT', 'ceo_OASIScorrectionnum', 'DaysToDeath', 'cedd_dateofdeath', 'ceas_ascode', 'epi_DischargeDate', 'epi_EndOfEpisode', 'epi_StartOfEpisode', 'epi_SocDate', 'dcr_desc', 'dcc_desc', 'icd_code_description'], inplace = True, axis = 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import numpy as np

imputer = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='imputed')
idf = pd.DataFrame(imputer.fit_transform(df))
idf.columns=df.columns
# idf.index=df.index

#
df = idf
for col in df:
    no_of_unique_values=df[col].nunique()
    if( not col.startswith( 'Unnamed' ) and no_of_unique_values<40):        
        df[col]=pd.Categorical(df[col])

# %%
df.dtypes
# Out:
# year_born                           object
# pa_race                           category
# pa_gender                         category
# pa_maritalstatus                  category
# epi_AdmitType                     category
#                                     ...
# M2401_INTRVTN_SMRY_PRSULC_PRVN    category
# M2401_INTRVTN_SMRY_PRSULC_WET     category
# M2410_INPAT_FACILITY              category
# M2420_DSCHRG_DISP                 category
# patient_deceased                  category
# Length: 129, dtype: object

# %% [markdown]
# #### detect columns that contain numeric value when it shouldn't be. (This runs quite a long time)

# %%
for column_name in df.columns:
    if column_name != 'year_born':
        for index, row in df.iterrows():
            if isinstance(row[column_name], (int, float)):
                print(column_name)
                df[column_name] = df[column_name].astype(str)
                break
# Out:
# pa_race
# pa_maritalstatus
# epi_height
# epi_weight
# RoughAge
# M1311_NBR_ULC_SOCROC_STG2_A2
# M1311_NBR_ULC_SOCROC_STG3_B2
# M1311_NBR_ULC_SOCROC_STG4_C2
# M1311_NSTG_CVRG_SOCROC_E2
# M1311_NSTG_DEEP_TSUE_SOCROC_F2
# M1311_NSTG_DRSG_SOCROC_D2
# patient_deceased

# %%
# Use Ordinal Encoder for all numeric type category

from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
enc.fit(df)
enc.categories_
# Out:
# [array([1909, 1914, 1915, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924,
#         1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935,
#         1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946,
#         1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#         1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#         1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
#         1980, 1981, 1982, 1983, 1984, 1985, 1988, 1989, 1990, 1993, 1996,
#         1999, 2011], dtype=object),
#  array(['1.0', '2.0', '3.0', '5.0', '6.0', 'imputed'], dtype=object),
#  array(['FEMALE', 'MALE  '], dtype=object),
#  array(['1.0', '2.0', '25000.0', '3.0', '4.0', '5.0', '6.0', '8.0',
#         'imputed'], dtype=object),
#  array(['NEW ADMISSION', 'READMISSION', 'RECERTIFICATION'], dtype=object),
#  array(['5.0', '5.3', '5.6', '55.0', '56.25', '57.0', '59.0', '59.8',
#         '60.0', '60.5', '60.98', '61.0', '61.2', '61.96', '61.97', '62.0',
#         '62.9', '62.99', '63.0', '63.35', '63.6', '63.78', '63.9', '64.0',
#         '64.8', '64.9', '64.96', '65.0', '65.25', '65.98', '66.0', '66.54',
#         '66.75', '66.96', '67.0', '67.48', '67.5', '67.8', '67.9', '67.99',
#         '68.0', '68.11', '68.25', '68.9', '68.97', '69.0', '70.0', '70.08',
#         '70.5', '70.8', '70.87', '70.9', '70.98', '71.0', '71.25', '71.96',
#         '72.0', '72.5', '73.0', '73.97', '74.0', '75.0', 'imputed'],
#        dtype=object),
#  array(['100.0', '100.1', '101.0', '104.94', '106.0', '108.0', '108.9',
#         '109.0', '110.0', '111.0', '111.1', '112.0', '112.42', '114.0',
#         '116.0', '118.0', '119.0', '119.4', '120.0', '121.0', '121.11',
#         '122.0', '122.54', '123.65', '125.0', '126.2', '127.0', '127.6',
#         '128.0', '129.0', '130.0', '134.0', '134.6', '135.0', '137.0',
#         '137.4', '139.0', '140.0', '143.0', '144.0', '144.32', '144.4',
#         '146.4', '147.0', '147.4', '148.0', '149.0', '150.0', '151.0',
#         '151.8', '151.9', '152.0', '152.46', '152.9', '154.0', '155.0',
#         '155.4', '156.64', '157.0', '158.0', '158.11', '159.0', '159.37',
#         '160.0', '161.0', '161.8', '163.0', '164.0', '164.12', '165.0',
#         '166.01', '168.9', '169.0', '169.4', '169.62', '170.0', '170.06',
#         '171.0', '171.1', '173.0', '174.0', '175.0', '176.0', '177.0',
#         '178.0', '178.2', '179.0', '179.3', '179.52', '180.0', '181.0',
#         '184.0', '184.6', '185.0', '189.4', '189.86', '189.99', '192.0',
#         '193.0', '194.0', '195.0', '195.8', '197.0', '198.0', '198.9',
#         '199.6', '200.0', '200.42', '202.4', '202.8', '204.6', '206.58',
#         '208.0', '211.0', '212.74', '212.96', '215.6', '216.0', '216.7',
#         '219.0', '220.0', '222.0', '224.84', '225.0', '227.7', '233.64',
#         '233.86', '235.0', '235.84', '237.2', '239.8', '243.0', '247.0',
#         '250.0', '251.0', '251.9', '264.0', '269.72', '271.0', '272.0',
#         '297.66', '311.0', '321.0', '333.3', '338.0', '412.72', '58.52',
#         '80.0', '84.0', '84.2', '86.0', '89.0', '91.3', '92.62', '95.0',
#         '96.0', '99.0', '99.2', '99.4', 'imputed'], dtype=object),
#  array(['1AFKS', '1AFKU', '1AGKS', '1AGKT', '1AGKU', '1AGNS', '1AHKS',
#         '1AHKT', '1AHLS', '1AHMS', '1AHNS', '1BFKS', '1BFKT', '1BFKU',
#         '1BFKV', '1BFLS', '1BGKS', '1BGKT', '1BGKU', '1BGKV', '1BGLS',
#         '1BGLT', '1BGMS', '1BGPS', '1BGPT', '1BHKS', '1BHKT', '1BHKU',
#         '1BHKV', '1BHLS', '1BHLT', '1BHMS', '1BHNS', '1BHNU', '1BHPS',
#         '1CFKS', '1CFKT', '1CFKU', '1CFKV', '1CFPT', '1CGKS', '1CGKT',
#         '1CGKU', '1CGKV', '1CGKW', '1CGLS', '1CGLT', '1CGMS', '1CGMT',
#         '1CGMU', '1CGMV', '1CGNS', '1CGPS', '1CGPT', '1CGPU', '1CGPV',
#         '1CGPW', '1CHKS', '1CHKT', '1CHKU', '1CHKV', '1CHKW', '1CHLS',
#         '1CHLT', '1CHLV', '1CHMS', '1CHMT', '1CHMU', '1CHMV', '1CHMW',
#         '1CHNS', '1CHNT', '1CHNU', '1CHNW', '1CHPS', '1CHPT', '1CHPU',
#         '1CHPV', '1CHPW', '2AFKS', '2AFMS', '2BFKS', '2BFKT', '2BFLS',
#         '2BFLT', '2BFLU', '2BFMS', '2BHKS', '2BHLS', '2BHLT', '2CFKS',
#         '2CFKT', '2CFLS', '2CFLT', '2CFMT', '2CFMU', '2CFMV', '2CHLS',
#         '2CHLT', '2CHMT', '2CHMW', '3AFKS', '3AFMS', '3AGKS', '3AGKT',
#         '3AGKU', '3AGMS', '3AHKS', '3AHKT', '3AHKU', '3AHLS', '3AHMS',
#         '3AHMT', '3AHPS', '3BFKS', '3BGKS', '3BGKT', '3BGLS', '3BHKS',
#         '3BHKT', '3BHKU', '3BHKV', '3BHKW', '3BHMS', '3BHMT', '3BHPS',
#         '3BHPT', '3BHPU', '3CFKT', '3CFKV', '3CFKW', '3CGKS', '3CGKT',
#         '3CGKU', '3CGKV', '3CGMU', '3CHKS', '3CHKT', '3CHKU', '3CHKV',
#         '3CHKW', '3CHKX', '3CHMS', '3CHMT', '3CHMW', '3CHPS', '4AFLS',
#         '4BFMS', '4CFKW', '4CGMX', '5AFKS', '5AHKS', '5BFKS', '5BGKS',
#         '5BHKS', '5BHKT', '5BHKU', '5CFKT', '5CGKU', '5CHKS', '5CHKT',
#         '5CHKU', '5CHKV', 'imputed'], dtype=object),
#  array(['C1F1S1', 'C1F1S2', 'C1F1S3', 'C1F2S1', 'C1F2S3', 'C1F2S4',
#         'C1F3S1', 'C1F3S2', 'C1F3S3', 'C1F3S4', 'C1F3S5', 'C2F1S1',
#         'C2F1S2', 'C2F1S3', 'C2F2S1', 'C2F2S2', 'C2F2S3', 'C2F2S5',
#         'C2F3S1', 'C2F3S2', 'C2F3S3', 'C2F3S4', 'C2F3S5', 'C3F1S1',
#         'C3F1S2', 'C3F1S3', 'C3F1S5', 'C3F2S1', 'C3F2S2', 'C3F2S3',
#         'C3F2S4', 'C3F2S5', 'C3F3S1', 'C3F3S2', 'C3F3S3', 'C3F3S4',
#         'C3F3S5', 'imputed'], dtype=object),
#  array(['348.31', '787.20', 'A04.71', 'A04.72', 'A09', 'A40.8', 'A41.01',
#         'A41.02', 'A41.1', 'A41.50', 'A41.51', 'A41.52', 'A41.59',
#         'A41.81', 'A41.89', 'A41.9', 'B00.4', 'B02.39', 'B02.8', 'B18.2',
#         'B37.2', 'C01', 'C02.9', 'C09.9', 'C10.9', 'C15.3', 'C15.5',
#         'C15.9', 'C16.0', 'C16.9', 'C17.0', 'C18.0', 'C18.1', 'C18.7',
#         'C18.9', 'C19', 'C20', 'C22.0', 'C22.9', 'C25.0', 'C25.1', 'C25.2',
#         'C25.3', 'C25.9', 'C26.9', 'C32.1', 'C32.9', 'C34.11', 'C34.12',
#         'C34.2', 'C34.31', 'C34.32', 'C34.81', 'C34.91', 'C34.92',
#         'C44.329', 'C44.722', 'C45.0', 'C50.112', 'C50.212', 'C50.411',
#         'C50.412', 'C50.911', 'C50.912', 'C53.0', 'C53.9', 'C54.1',
#         'C56.1', 'C61', 'C64.1', 'C64.2', 'C67.9', 'C71.0', 'C71.1',
#         'C71.3', 'C71.6', 'C71.7', 'C71.9', 'C73', 'C76.0', 'C76.3',
#         'C78.01', 'C78.6', 'C78.7', 'C78.89', 'C79.31', 'C79.51', 'C79.81',
#         'C7A.1', 'C83.30', 'C83.39', 'C85.90', 'C88.4', 'C90.00', 'C91.10',
#         'C92.00', 'C92.50', 'C95.90', 'D46.9', 'D49.6', 'D50.0', 'D50.9',
#         'D59.1', 'D61.818', 'D62', 'D64.9', 'D68.0', 'D69.6', 'E03.9',
#         'E10.22', 'E10.621', 'E10.622', 'E11.22', 'E11.29', 'E11.36',
#         'E11.40', 'E11.41', 'E11.42', 'E11.51', 'E11.52', 'E11.59',
#         'E11.621', 'E11.622', 'E11.649', 'E11.65', 'E11.69', 'E11.9',
#         'E43', 'E46', 'E53.8', 'E83.52', 'E86.0', 'E87.0', 'E87.1',
#         'F03.90', 'F03.91', 'F20.0', 'F31.9', 'F32.9', 'F41.9', 'G06.0',
#         'G12.21', 'G14', 'G20', 'G25.0', 'G30.0', 'G30.1', 'G30.9',
#         'G31.01', 'G31.09', 'G31.2', 'G31.83', 'G31.84', 'G31.85', 'G35',
#         'G37.3', 'G37.9', 'G40.109', 'G40.209', 'G40.89', 'G40.909',
#         'G40.919', 'G50.0', 'G60.0', 'G60.9', 'G61.0', 'G61.81', 'G62.1',
#         'G70.00', 'G70.01', 'G72.81', 'G72.9', 'G80.8', 'G80.9', 'G81.14',
#         'G82.50', 'G83.4', 'G89.29', 'G89.3', 'G89.4', 'G90.09', 'G90.3',
#         'G92', 'G93.40', 'G93.41', 'I05.9', 'I10', 'I11.0', 'I11.9',
#         'I12.0', 'I12.9', 'I13.0', 'I13.10', 'I13.11', 'I13.2', 'I16.1',
#         'I21.09', 'I21.19', 'I21.3', 'I21.4', 'I21.A1', 'I25.10',
#         'I25.110', 'I25.5', 'I26.93', 'I26.99', 'I27.20', 'I31.3', 'I33.0',
#         'I35.0', 'I42.8', 'I44.1', 'I47.1', 'I48.0', 'I48.19', 'I48.20',
#         'I48.91', 'I48.92', 'I49.8', 'I50.1', 'I50.22', 'I50.23', 'I50.30',
#         'I50.32', 'I50.33', 'I50.40', 'I50.42', 'I50.43', 'I50.810',
#         'I50.9', 'I63.512', 'I63.9', 'I65.23', 'I69.154', 'I69.254',
#         'I69.298', 'I69.311', 'I69.318', 'I69.320', 'I69.321', 'I69.322',
#         'I69.328', 'I69.334', 'I69.351', 'I69.354', 'I69.391', 'I69.393',
#         'I69.398', 'I70.235', 'I70.248', 'I70.262', 'I73.9', 'I74.3',
#         'I82.401', 'I82.411', 'I82.413', 'I82.431', 'I82.432', 'I82.621',
#         'I83.012', 'I83.018', 'I83.022', 'I87.2', 'I87.311', 'I87.312',
#         'I87.313', 'I87.331', 'I87.332', 'I87.333', 'I89.0', 'I95.1',
#         'I96', 'J02.9', 'J06.9', 'J10.00', 'J10.1', 'J13', 'J15.1',
#         'J15.212', 'J15.6', 'J15.9', 'J18.0', 'J18.1', 'J18.8', 'J18.9',
#         'J20.9', 'J40', 'J43.1', 'J43.2', 'J43.8', 'J43.9', 'J44.0',
#         'J44.1', 'J44.9', 'J45.20', 'J45.41', 'J45.901', 'J45.909',
#         'J47.1', 'J69.0', 'J81.0', 'J84.10', 'J84.112', 'J84.9', 'J85.1',
#         'J86.9', 'J90', 'J96.02', 'J96.10', 'J96.11', 'J96.12', 'J96.21',
#         'J96.91', 'J98.01', 'J98.2', 'K21.9', 'K22.10', 'K22.2', 'K22.70',
#         'K26.9', 'K27.9', 'K29.70', 'K29.80', 'K31.1', 'K31.819', 'K50.90',
#         'K51.00', 'K51.90', 'K52.1', 'K52.9', 'K55.1', 'K56.699', 'K57.20',
#         'K57.30', 'K57.90', 'K58.9', 'K59.00', 'K59.09', 'K61.1', 'K61.39',
#         'K62.5', 'K62.89', 'K63.0', 'K63.1', 'K63.2', 'K65.1', 'K70.10',
#         'K70.30', 'K70.31', 'K72.00', 'K72.10', 'K72.90', 'K74.60',
#         'K74.69', 'K75.81', 'K75.9', 'K81.0', 'K81.9', 'K83.1', 'K85.10',
#         'K85.90', 'K86.1', 'K90.9', 'K91.2', 'K91.870', 'K92.0', 'K92.2',
#         'K94.02', 'K94.22', 'K94.23', 'L02.211', 'L02.213', 'L02.214',
#         'L02.31', 'L02.413', 'L02.611', 'L02.612', 'L03.031', 'L03.113',
#         'L03.115', 'L03.116', 'L03.213', 'L03.311', 'L12.0', 'L29.8',
#         'L30.9', 'L76.32', 'L89.012', 'L89.132', 'L89.150', 'L89.151',
#         'L89.152', 'L89.153', 'L89.154', 'L89.210', 'L89.212', 'L89.214',
#         'L89.220', 'L89.222', 'L89.223', 'L89.224', 'L89.310', 'L89.311',
#         'L89.312', 'L89.313', 'L89.314', 'L89.320', 'L89.321', 'L89.322',
#         'L89.323', 'L89.324', 'L89.512', 'L89.513', 'L89.522', 'L89.523',
#         'L89.610', 'L89.611', 'L89.612', 'L89.613', 'L89.614', 'L89.620',
#         'L89.621', 'L89.622', 'L89.623', 'L89.890', 'L89.892', 'L89.893',
#         'L89.894', 'L89.896', 'L97.111', 'L97.311', 'L97.412', 'L97.521',
#         'L97.811', 'L97.812', 'L97.821', 'L97.822', 'L98.421', 'L98.492',
#         'M00.061', 'M00.861', 'M00.9', 'M06.89', 'M10.9', 'M13.0', 'M15.0',
#         'M15.9', 'M16.0', 'M16.12', 'M17.0', 'M17.11', 'M17.12', 'M19.011',
#         'M19.012', 'M21.371', 'M24.561', 'M27.2', 'M32.9', 'M35.2',
#         'M35.3', 'M43.16', 'M46.26', 'M47.812', 'M48.02', 'M48.061',
#         'M48.062', 'M48.07', 'M48.54XD', 'M48.56XD', 'M51.16', 'M51.17',
#         'M51.36', 'M51.37', 'M51.86', 'M54.12', 'M54.2', 'M54.31',
#         'M54.42', 'M70.61', 'M75.01', 'M75.41', 'M80.021D', 'M80.022D',
#         'M80.051D', 'M80.052D', 'M80.08XD', 'M80.88XD', 'M84.350D',
#         'M84.452D', 'M84.58XD', 'M86.672', 'M96.1', 'N10', 'N12', 'N13.2',
#         'N13.30', 'N13.6', 'N13.9', 'N17.9', 'N18.3', 'N18.4', 'N30.00',
#         'N30.90', 'N31.9', 'N39.0', 'N40.1', 'N48.29', 'N49.3', 'N61.1',
#         'R13.10', 'R13.13', 'R60.0', 'S01.01XD', 'S01.81XD', 'S02.2XXD',
#         'S02.32XD', 'S06.360D', 'S06.5X0D', 'S06.5X9D', 'S06.6X0D',
#         'S12.100D', 'S12.9XXD', 'S22.068D', 'S22.070D', 'S22.080D',
#         'S22.088D', 'S22.089A', 'S22.089D', 'S22.20XD', 'S22.31XD',
#         'S22.41XD', 'S22.42XD', 'S32.010D', 'S32.011D', 'S32.018D',
#         'S32.019D', 'S32.020D', 'S32.028D', 'S32.030D', 'S32.038D',
#         'S32.040D', 'S32.048D', 'S32.059D', 'S32.10XD', 'S32.501D',
#         'S32.502D', 'S32.511D', 'S32.591D', 'S32.592D', 'S39.012A',
#         'S39.012D', 'S41.111D', 'S42.201D', 'S42.202D', 'S42.211D',
#         'S42.212D', 'S42.215D', 'S42.302D', 'S43.005D', 'S46.011D',
#         'S51.012D', 'S51.811D', 'S51.812D', 'S52.501D', 'S52.502D',
#         'S52.571D', 'S61.011D', 'S61.401D', 'S62.92XD', 'S71.002D',
#         'S71.102D', 'S71.111D', 'S71.112D', 'S72.001D', 'S72.002D',
#         'S72.011D', 'S72.012D', 'S72.022D', 'S72.041D', 'S72.111D',
#         'S72.112D', 'S72.114D', 'S72.141D', 'S72.142D', 'S72.145D',
#         'S72.22XD', 'S72.302D', 'S72.402D', 'S72.8X1D', 'S72.91XD',
#         'S76.012D', 'S81.001A', 'S81.002D', 'S81.801D', 'S81.802A',
#         'S81.811A', 'S81.811D', 'S81.812D', 'S81.832D', 'S82.001D',
#         'S82.142D', 'S82.202D', 'S82.301D', 'S82.842E', 'S82.891D',
#         'S82.892D', 'S91.002D', 'S91.105D', 'S91.111D', 'S91.112D',
#         'S91.205D', 'S91.301D', 'S91.302D', 'S93.401D', 'T22.212D',
#         'T24.212D', 'T24.331D', 'T25.222D', 'T79.6XXD', 'T79.8XXD',
#         'T80.211A', 'T81.31XA', 'T81.31XD', 'T81.41XA', 'T81.42XA',
#         'T81.43XA', 'T81.43XD', 'T81.49XA', 'T81.83XD', 'T81.89XD',
#         'T82.7XXA', 'T82.7XXD', 'T82.897D', 'T83.511A', 'T83.518D',
#         'T84.021D', 'T84.030D', 'T84.498D', 'T84.51XA', 'T84.52XA',
#         'T84.52XD', 'T84.53XD', 'T84.59XA', 'T84.63XA', 'T84.84XD',
#         'T84.89XA', 'T85.79XD', 'T87.43', 'T87.54', 'T87.81', 'T87.89',
#         'U07.1', 'Z43.0', 'Z43.1', 'Z43.2', 'Z43.3', 'Z43.4', 'Z43.5',
#         'Z43.6', 'Z45.2', 'Z46.6', 'Z47.1', 'Z47.81', 'Z47.89', 'Z48.00',
#         'Z48.01', 'Z48.03', 'Z48.22', 'Z48.3', 'Z48.811', 'Z48.812',
#         'Z48.813', 'Z48.815', 'Z48.816', 'Z48.817', 'imputed'],
#        dtype=object),
#  array(['Cancer', 'Dementia, Cerebral Degeneration', 'Heart',
#         'Kidney, excluding cancer', 'Liver, excluding cancer',
#         'Lung, excluding cancer', 'Neurological', 'Other', 'Stroke/Coma',
#         'Unspecified/AFTT', 'heart', 'imputed'], dtype=object),
#  array(['10.0', '100.0', '101.0', '102.0', '103.0', '104.0', '106.0',
#         '108.0', '112.0', '28.0', '33.0', '36.0', '42.0', '43.0', '45.0',
#         '48.0', '49.0', '50.0', '51.0', '52.0', '53.0', '54.0', '55.0',
#         '56.0', '57.0', '58.0', '59.0', '60.0', '61.0', '62.0', '63.0',
#         '64.0', '65.0', '66.0', '67.0', '68.0', '69.0', '70.0', '71.0',
#         '72.0', '73.0', '74.0', '75.0', '76.0', '77.0', '78.0', '79.0',
#         '80.0', '81.0', '82.0', '83.0', '84.0', '85.0', '86.0', '87.0',
#         '88.0', '89.0', '90.0', '91.0', '92.0', '93.0', '94.0', '95.0',
#         '96.0', '97.0', '98.0', '99.0', 'imputed'], dtype=object),
#  array(['1 - START OF CARE - FURTHER VISITS PLANNED',
#         '3 - RESUMPTION OF CARE (AFTER INPATIENT STAY)',
#         '4 - RECERTIFICATION (FOLLOW-UP) REASSESSMENT',
#         '5 - OTHER FOLLOW-UP',
#         '6 - TRANSFERRED TO AN INPATIENT FACILITY - PATIENT NOT DISCHARGED FROM AGENCY',
#         '7 - TRANSFERRED TO AN INPATIENT FACILITY - PATIENT DISCHARGED FROM AGENCY',
#         '8 - DEATH AT HOME', '9 - DISCHARGE FROM AGENCY'], dtype=object),
#  array(['EARLY', 'LATER', 'NOT APPLICABLE', 'UNKNOWN', 'imputed'],
#        dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['2008-03-21T00:00:00.000000000', '2009-04-30T00:00:00.000000000',
#         '2010-12-29T00:00:00.000000000', '2011-11-07T00:00:00.000000000',
#         '2013-10-18T00:00:00.000000000', '2014-10-25T00:00:00.000000000',
#         '2015-01-28T00:00:00.000000000', '2015-07-15T00:00:00.000000000',
#         '2015-09-22T00:00:00.000000000', '2015-09-30T00:00:00.000000000',
#         '2016-02-24T00:00:00.000000000', '2016-03-05T00:00:00.000000000',
#         '2016-03-09T00:00:00.000000000', '2016-07-22T00:00:00.000000000',
#         '2016-08-20T00:00:00.000000000', '2016-09-16T00:00:00.000000000',
#         '2017-01-02T00:00:00.000000000', '2017-01-20T00:00:00.000000000',
#         '2017-02-06T00:00:00.000000000', '2017-02-28T00:00:00.000000000',
#         '2017-03-31T00:00:00.000000000', '2017-04-07T00:00:00.000000000',
#         '2017-04-13T00:00:00.000000000', '2017-04-18T00:00:00.000000000',
#         '2017-05-16T00:00:00.000000000', '2017-06-02T00:00:00.000000000',
#         '2017-06-18T00:00:00.000000000', '2017-06-24T00:00:00.000000000',
#         '2017-07-24T00:00:00.000000000', '2017-07-29T00:00:00.000000000',
#         '2017-08-10T00:00:00.000000000', '2017-09-15T00:00:00.000000000',
#         '2017-09-29T00:00:00.000000000', '2017-10-06T00:00:00.000000000',
#         '2017-11-17T00:00:00.000000000', '2017-12-06T00:00:00.000000000',
#         '2017-12-15T00:00:00.000000000', '2018-01-02T00:00:00.000000000',
#         '2018-01-03T00:00:00.000000000', '2018-01-04T00:00:00.000000000',
#         '2018-01-09T00:00:00.000000000', '2018-02-03T00:00:00.000000000',
#         '2018-02-17T00:00:00.000000000', '2018-03-22T00:00:00.000000000',
#         '2018-03-28T00:00:00.000000000', '2018-03-30T00:00:00.000000000',
#         '2018-04-03T00:00:00.000000000', '2018-05-01T00:00:00.000000000',
#         '2018-05-02T00:00:00.000000000', '2018-05-07T00:00:00.000000000',
#         '2018-05-20T00:00:00.000000000', '2018-05-25T00:00:00.000000000',
#         '2018-06-06T00:00:00.000000000', '2018-06-08T00:00:00.000000000',
#         '2018-06-09T00:00:00.000000000', '2018-06-10T00:00:00.000000000',
#         '2018-06-15T00:00:00.000000000', '2018-06-17T00:00:00.000000000',
#         '2018-06-20T00:00:00.000000000', '2018-07-03T00:00:00.000000000',
#         '2018-07-05T00:00:00.000000000', '2018-07-13T00:00:00.000000000',
#         '2018-07-20T00:00:00.000000000', '2018-07-23T00:00:00.000000000',
#         '2018-07-30T00:00:00.000000000', '2018-07-31T00:00:00.000000000',
#         '2018-08-24T00:00:00.000000000', '2018-08-30T00:00:00.000000000',
#         '2018-09-04T00:00:00.000000000', '2018-09-06T00:00:00.000000000',
#         '2018-09-07T00:00:00.000000000', '2018-09-08T00:00:00.000000000',
#         '2018-09-12T00:00:00.000000000', '2018-09-15T00:00:00.000000000',
#         '2018-09-18T00:00:00.000000000', '2018-10-02T00:00:00.000000000',
#         '2018-10-04T00:00:00.000000000', '2018-10-12T00:00:00.000000000',
#         '2018-10-27T00:00:00.000000000', '2018-10-29T00:00:00.000000000',
#         '2018-11-01T00:00:00.000000000', '2018-11-03T00:00:00.000000000',
#         '2018-11-05T00:00:00.000000000', '2018-11-08T00:00:00.000000000',
#         '2018-11-10T00:00:00.000000000', '2018-11-13T00:00:00.000000000',
#         '2018-11-20T00:00:00.000000000', '2018-11-28T00:00:00.000000000',
#         '2018-12-07T00:00:00.000000000', '2018-12-19T00:00:00.000000000',
#         '2018-12-26T00:00:00.000000000', '2019-01-03T00:00:00.000000000',
#         '2019-01-05T00:00:00.000000000', '2019-01-07T00:00:00.000000000',
#         '2019-01-11T00:00:00.000000000', '2019-01-18T00:00:00.000000000',
#         '2019-01-21T00:00:00.000000000', '2019-01-24T00:00:00.000000000',
#         '2019-01-26T00:00:00.000000000', '2019-01-31T00:00:00.000000000',
#         '2019-02-02T00:00:00.000000000', '2019-02-07T00:00:00.000000000',
#         '2019-02-09T00:00:00.000000000', '2019-02-18T00:00:00.000000000',
#         '2019-02-20T00:00:00.000000000', '2019-02-21T00:00:00.000000000',
#         '2019-02-27T00:00:00.000000000', '2019-02-28T00:00:00.000000000',
#         '2019-03-01T00:00:00.000000000', '2019-03-05T00:00:00.000000000',
#         '2019-03-10T00:00:00.000000000', '2019-03-11T00:00:00.000000000',
#         '2019-03-17T00:00:00.000000000', '2019-03-20T00:00:00.000000000',
#         '2019-03-22T00:00:00.000000000', '2019-03-28T00:00:00.000000000',
#         '2019-03-29T00:00:00.000000000', '2019-04-03T00:00:00.000000000',
#         '2019-04-10T00:00:00.000000000', '2019-04-13T00:00:00.000000000',
#         '2019-04-14T00:00:00.000000000', '2019-04-19T00:00:00.000000000',
#         '2019-04-23T00:00:00.000000000', '2019-05-01T00:00:00.000000000',
#         '2019-05-04T00:00:00.000000000', '2019-05-05T00:00:00.000000000',
#         '2019-05-06T00:00:00.000000000', '2019-05-08T00:00:00.000000000',
#         '2019-05-11T00:00:00.000000000', '2019-05-13T00:00:00.000000000',
#         '2019-05-20T00:00:00.000000000', '2019-05-23T00:00:00.000000000',
#         '2019-06-02T00:00:00.000000000', '2019-06-04T00:00:00.000000000',
#         '2019-06-05T00:00:00.000000000', '2019-06-10T00:00:00.000000000',
#         '2019-06-11T00:00:00.000000000', '2019-06-20T00:00:00.000000000',
#         '2019-06-21T00:00:00.000000000', '2019-06-23T00:00:00.000000000',
#         '2019-06-25T00:00:00.000000000', '2019-06-26T00:00:00.000000000',
#         '2019-07-02T00:00:00.000000000', '2019-07-20T00:00:00.000000000',
#         '2019-07-24T00:00:00.000000000', '2019-07-25T00:00:00.000000000',
#         '2019-07-26T00:00:00.000000000', '2019-08-01T00:00:00.000000000',
#         '2019-08-03T00:00:00.000000000', '2019-08-05T00:00:00.000000000',
#         '2019-08-10T00:00:00.000000000', '2019-08-11T00:00:00.000000000',
#         '2019-08-14T00:00:00.000000000', '2019-08-22T00:00:00.000000000',
#         '2019-08-24T00:00:00.000000000', '2019-08-26T00:00:00.000000000',
#         '2019-08-29T00:00:00.000000000', '2019-09-03T00:00:00.000000000',
#         '2019-09-06T00:00:00.000000000', '2019-09-08T00:00:00.000000000',
#         '2019-09-09T00:00:00.000000000', '2019-09-10T00:00:00.000000000',
#         '2019-09-11T00:00:00.000000000', '2019-09-13T00:00:00.000000000',
#         '2019-09-17T00:00:00.000000000', '2019-09-18T00:00:00.000000000',
#         '2019-09-19T00:00:00.000000000', '2019-09-20T00:00:00.000000000',
#         '2019-09-22T00:00:00.000000000', '2019-09-25T00:00:00.000000000',
#         '2019-09-26T00:00:00.000000000', '2019-09-27T00:00:00.000000000',
#         '2019-09-28T00:00:00.000000000', '2019-10-02T00:00:00.000000000',
#         '2019-10-03T00:00:00.000000000', '2019-10-04T00:00:00.000000000',
#         '2019-10-07T00:00:00.000000000', '2019-10-08T00:00:00.000000000',
#         '2019-10-10T00:00:00.000000000', '2019-10-11T00:00:00.000000000',
#         '2019-10-13T00:00:00.000000000', '2019-10-14T00:00:00.000000000',
#         '2019-10-15T00:00:00.000000000', '2019-10-16T00:00:00.000000000',
#         '2019-10-17T00:00:00.000000000', '2019-10-18T00:00:00.000000000',
#         '2019-10-20T00:00:00.000000000', '2019-10-22T00:00:00.000000000',
#         '2019-10-24T00:00:00.000000000', '2019-10-26T00:00:00.000000000',
#         '2019-10-28T00:00:00.000000000', '2019-10-29T00:00:00.000000000',
#         '2019-10-30T00:00:00.000000000', '2019-10-31T00:00:00.000000000',
#         '2019-11-01T00:00:00.000000000', '2019-11-02T00:00:00.000000000',
#         '2019-11-04T00:00:00.000000000', '2019-11-05T00:00:00.000000000',
#         '2019-11-06T00:00:00.000000000', '2019-11-07T00:00:00.000000000',
#         '2019-11-08T00:00:00.000000000', '2019-11-09T00:00:00.000000000',
#         '2019-11-10T00:00:00.000000000', '2019-11-11T00:00:00.000000000',
#         '2019-11-12T00:00:00.000000000', '2019-11-13T00:00:00.000000000',
#         '2019-11-14T00:00:00.000000000', '2019-11-15T00:00:00.000000000',
#         '2019-11-16T00:00:00.000000000', '2019-11-18T00:00:00.000000000',
#         '2019-11-19T00:00:00.000000000', '2019-11-20T00:00:00.000000000',
#         '2019-11-21T00:00:00.000000000', '2019-11-22T00:00:00.000000000',
#         '2019-11-23T00:00:00.000000000', '2019-11-24T00:00:00.000000000',
#         '2019-11-25T00:00:00.000000000', '2019-11-26T00:00:00.000000000',
#         '2019-11-27T00:00:00.000000000', '2019-11-28T00:00:00.000000000',
#         '2019-11-29T00:00:00.000000000', '2019-11-30T00:00:00.000000000',
#         '2019-12-01T00:00:00.000000000', '2019-12-02T00:00:00.000000000',
#         '2019-12-03T00:00:00.000000000', '2019-12-04T00:00:00.000000000',
#         '2019-12-05T00:00:00.000000000', '2019-12-06T00:00:00.000000000',
#         '2019-12-07T00:00:00.000000000', '2019-12-08T00:00:00.000000000',
#         '2019-12-09T00:00:00.000000000', '2019-12-10T00:00:00.000000000',
#         '2019-12-11T00:00:00.000000000', '2019-12-12T00:00:00.000000000',
#         '2019-12-13T00:00:00.000000000', '2019-12-14T00:00:00.000000000',
#         '2019-12-15T00:00:00.000000000', '2019-12-16T00:00:00.000000000',
#         '2019-12-17T00:00:00.000000000', '2019-12-18T00:00:00.000000000',
#         '2019-12-19T00:00:00.000000000', '2019-12-20T00:00:00.000000000',
#         '2019-12-21T00:00:00.000000000', '2019-12-22T00:00:00.000000000',
#         '2019-12-23T00:00:00.000000000', '2019-12-24T00:00:00.000000000',
#         '2019-12-25T00:00:00.000000000', '2019-12-26T00:00:00.000000000',
#         '2019-12-27T00:00:00.000000000', '2019-12-28T00:00:00.000000000',
#         '2019-12-29T00:00:00.000000000', '2019-12-30T00:00:00.000000000',
#         '2019-12-31T00:00:00.000000000', '2020-01-01T00:00:00.000000000',
#         '2020-01-02T00:00:00.000000000', '2020-01-03T00:00:00.000000000',
#         '2020-01-04T00:00:00.000000000', '2020-01-05T00:00:00.000000000',
#         '2020-01-06T00:00:00.000000000', '2020-01-07T00:00:00.000000000',
#         '2020-01-08T00:00:00.000000000', '2020-01-09T00:00:00.000000000',
#         '2020-01-10T00:00:00.000000000', '2020-01-11T00:00:00.000000000',
#         '2020-01-12T00:00:00.000000000', '2020-01-13T00:00:00.000000000',
#         '2020-01-14T00:00:00.000000000', '2020-01-15T00:00:00.000000000',
#         '2020-01-16T00:00:00.000000000', '2020-01-17T00:00:00.000000000',
#         '2020-01-18T00:00:00.000000000', '2020-01-19T00:00:00.000000000',
#         '2020-01-20T00:00:00.000000000', '2020-01-21T00:00:00.000000000',
#         '2020-01-22T00:00:00.000000000', '2020-01-23T00:00:00.000000000',
#         '2020-01-24T00:00:00.000000000', '2020-01-25T00:00:00.000000000',
#         '2020-01-26T00:00:00.000000000', '2020-01-27T00:00:00.000000000',
#         '2020-01-28T00:00:00.000000000', '2020-01-29T00:00:00.000000000',
#         '2020-01-30T00:00:00.000000000', '2020-01-31T00:00:00.000000000',
#         '2020-02-01T00:00:00.000000000', '2020-02-02T00:00:00.000000000',
#         '2020-02-03T00:00:00.000000000', '2020-02-04T00:00:00.000000000',
#         '2020-02-05T00:00:00.000000000', '2020-02-06T00:00:00.000000000',
#         '2020-02-07T00:00:00.000000000', '2020-02-08T00:00:00.000000000',
#         '2020-02-09T00:00:00.000000000', '2020-02-10T00:00:00.000000000',
#         '2020-02-11T00:00:00.000000000', '2020-02-12T00:00:00.000000000',
#         '2020-02-13T00:00:00.000000000', '2020-02-14T00:00:00.000000000',
#         '2020-02-15T00:00:00.000000000', '2020-02-16T00:00:00.000000000',
#         '2020-02-17T00:00:00.000000000', '2020-02-18T00:00:00.000000000',
#         '2020-02-19T00:00:00.000000000', '2020-02-20T00:00:00.000000000',
#         '2020-02-21T00:00:00.000000000', '2020-02-22T00:00:00.000000000',
#         '2020-02-23T00:00:00.000000000', '2020-02-24T00:00:00.000000000',
#         '2020-02-25T00:00:00.000000000', '2020-02-26T00:00:00.000000000',
#         '2020-02-27T00:00:00.000000000', '2020-02-28T00:00:00.000000000',
#         '2020-02-29T00:00:00.000000000', '2020-03-01T00:00:00.000000000',
#         '2020-03-02T00:00:00.000000000', '2020-03-03T00:00:00.000000000',
#         '2020-03-04T00:00:00.000000000', '2020-03-05T00:00:00.000000000',
#         '2020-03-06T00:00:00.000000000', '2020-03-07T00:00:00.000000000',
#         '2020-03-08T00:00:00.000000000', '2020-03-09T00:00:00.000000000',
#         '2020-03-10T00:00:00.000000000', '2020-03-11T00:00:00.000000000',
#         '2020-03-12T00:00:00.000000000', '2020-03-13T00:00:00.000000000',
#         '2020-03-14T00:00:00.000000000', '2020-03-15T00:00:00.000000000',
#         '2020-03-16T00:00:00.000000000', '2020-03-17T00:00:00.000000000',
#         '2020-03-18T00:00:00.000000000', '2020-03-19T00:00:00.000000000',
#         '2020-03-20T00:00:00.000000000', '2020-03-21T00:00:00.000000000',
#         '2020-03-22T00:00:00.000000000', '2020-03-23T00:00:00.000000000',
#         '2020-03-24T00:00:00.000000000', '2020-03-25T00:00:00.000000000',
#         '2020-03-26T00:00:00.000000000', '2020-03-27T00:00:00.000000000',
#         '2020-03-28T00:00:00.000000000', '2020-03-29T00:00:00.000000000',
#         '2020-03-30T00:00:00.000000000', '2020-03-31T00:00:00.000000000',
#         '2020-04-01T00:00:00.000000000', '2020-04-02T00:00:00.000000000',
#         '2020-04-03T00:00:00.000000000', '2020-04-04T00:00:00.000000000',
#         '2020-04-05T00:00:00.000000000', '2020-04-06T00:00:00.000000000',
#         '2020-04-07T00:00:00.000000000', '2020-04-08T00:00:00.000000000',
#         '2020-04-09T00:00:00.000000000', '2020-04-10T00:00:00.000000000',
#         '2020-04-11T00:00:00.000000000', '2020-04-12T00:00:00.000000000',
#         '2020-04-13T00:00:00.000000000', '2020-04-14T00:00:00.000000000',
#         '2020-04-15T00:00:00.000000000', '2020-04-16T00:00:00.000000000',
#         '2020-04-17T00:00:00.000000000', '2020-04-18T00:00:00.000000000',
#         '2020-04-19T00:00:00.000000000', '2020-04-20T00:00:00.000000000',
#         '2020-04-21T00:00:00.000000000', '2020-04-22T00:00:00.000000000',
#         '2020-04-23T00:00:00.000000000', '2020-04-24T00:00:00.000000000',
#         '2020-04-25T00:00:00.000000000', '2020-04-26T00:00:00.000000000',
#         '2020-04-27T00:00:00.000000000', '2020-04-28T00:00:00.000000000',
#         '2020-04-29T00:00:00.000000000', '2020-04-30T00:00:00.000000000',
#         '2020-05-01T00:00:00.000000000', '2020-05-02T00:00:00.000000000',
#         '2020-05-03T00:00:00.000000000', '2020-05-04T00:00:00.000000000',
#         '2020-05-05T00:00:00.000000000', '2020-05-06T00:00:00.000000000',
#         '2020-05-07T00:00:00.000000000', '2020-05-08T00:00:00.000000000',
#         '2020-05-09T00:00:00.000000000', '2020-05-10T00:00:00.000000000',
#         '2020-05-11T00:00:00.000000000', '2020-05-12T00:00:00.000000000',
#         '2020-05-13T00:00:00.000000000', '2020-05-14T00:00:00.000000000',
#         '2020-05-15T00:00:00.000000000', '2020-05-16T00:00:00.000000000',
#         '2020-05-17T00:00:00.000000000', '2020-05-18T00:00:00.000000000',
#         '2020-05-19T00:00:00.000000000', '2020-05-20T00:00:00.000000000',
#         '2020-05-21T00:00:00.000000000', '2020-05-22T00:00:00.000000000',
#         '2020-05-23T00:00:00.000000000', '2020-05-24T00:00:00.000000000',
#         '2020-05-25T00:00:00.000000000', '2020-05-26T00:00:00.000000000',
#         '2020-05-27T00:00:00.000000000', '2020-05-28T00:00:00.000000000',
#         '2020-05-29T00:00:00.000000000', '2020-05-30T00:00:00.000000000',
#         '2020-05-31T00:00:00.000000000', '2020-06-01T00:00:00.000000000',
#         '2020-06-02T00:00:00.000000000', '2020-06-03T00:00:00.000000000',
#         '2020-06-04T00:00:00.000000000', '2020-06-05T00:00:00.000000000',
#         '2020-06-06T00:00:00.000000000', '2020-06-07T00:00:00.000000000',
#         '2020-06-08T00:00:00.000000000', '2020-06-09T00:00:00.000000000',
#         '2020-06-10T00:00:00.000000000', '2020-06-11T00:00:00.000000000',
#         '2020-06-12T00:00:00.000000000', '2020-06-13T00:00:00.000000000',
#         '2020-06-14T00:00:00.000000000', '2020-06-15T00:00:00.000000000',
#         '2020-06-16T00:00:00.000000000', '2020-06-17T00:00:00.000000000',
#         '2020-06-18T00:00:00.000000000', '2020-06-19T00:00:00.000000000',
#         '2020-06-20T00:00:00.000000000', '2020-06-21T00:00:00.000000000',
#         '2020-06-22T00:00:00.000000000', '2020-06-23T00:00:00.000000000',
#         '2020-06-24T00:00:00.000000000', '2020-06-25T00:00:00.000000000',
#         '2020-06-26T00:00:00.000000000', '2020-06-27T00:00:00.000000000',
#         '2020-06-28T00:00:00.000000000', '2020-06-29T00:00:00.000000000',
#         '2020-06-30T00:00:00.000000000', '2020-07-01T00:00:00.000000000',
#         '2020-07-02T00:00:00.000000000', '2020-07-03T00:00:00.000000000',
#         '2020-07-04T00:00:00.000000000', '2020-07-05T00:00:00.000000000',
#         '2020-07-06T00:00:00.000000000', '2020-07-07T00:00:00.000000000',
#         '2020-07-08T00:00:00.000000000', '2020-07-09T00:00:00.000000000',
#         '2020-07-10T00:00:00.000000000', '2020-07-11T00:00:00.000000000',
#         '2020-07-12T00:00:00.000000000', '2020-07-13T00:00:00.000000000',
#         '2020-07-14T00:00:00.000000000', '2020-07-15T00:00:00.000000000',
#         '2020-07-16T00:00:00.000000000', '2020-07-17T00:00:00.000000000',
#         '2020-07-18T00:00:00.000000000', '2020-07-19T00:00:00.000000000',
#         '2020-07-20T00:00:00.000000000', '2020-07-21T00:00:00.000000000',
#         '2020-07-22T00:00:00.000000000', '2020-07-23T00:00:00.000000000',
#         '2020-07-24T00:00:00.000000000', '2020-07-25T00:00:00.000000000',
#         '2020-07-26T00:00:00.000000000', '2020-07-27T00:00:00.000000000',
#         '2020-07-28T00:00:00.000000000', '2020-07-29T00:00:00.000000000',
#         '2020-07-30T00:00:00.000000000', '2020-07-31T00:00:00.000000000',
#         '2020-08-01T00:00:00.000000000', '2020-08-02T00:00:00.000000000',
#         '2020-08-03T00:00:00.000000000', '2020-08-04T00:00:00.000000000',
#         '2020-08-05T00:00:00.000000000', '2020-08-06T00:00:00.000000000',
#         '2020-08-07T00:00:00.000000000', '2020-08-08T00:00:00.000000000',
#         '2020-08-09T00:00:00.000000000', '2020-08-10T00:00:00.000000000',
#         '2020-08-11T00:00:00.000000000', '2020-08-12T00:00:00.000000000',
#         '2020-08-13T00:00:00.000000000', '2020-08-14T00:00:00.000000000',
#         '2020-08-15T00:00:00.000000000', '2020-08-16T00:00:00.000000000',
#         '2020-08-17T00:00:00.000000000', '2020-08-18T00:00:00.000000000',
#         '2020-08-19T00:00:00.000000000', '2020-08-20T00:00:00.000000000',
#         '2020-08-21T00:00:00.000000000', '2020-08-22T00:00:00.000000000',
#         '2020-08-23T00:00:00.000000000', '2020-08-24T00:00:00.000000000',
#         '2020-08-25T00:00:00.000000000', '2020-08-26T00:00:00.000000000',
#         '2020-08-27T00:00:00.000000000', '2020-08-28T00:00:00.000000000',
#         '2020-08-29T00:00:00.000000000', '2020-08-30T00:00:00.000000000',
#         '2020-08-31T00:00:00.000000000', '2020-09-01T00:00:00.000000000',
#         '2020-09-02T00:00:00.000000000', '2020-09-03T00:00:00.000000000',
#         '2020-09-04T00:00:00.000000000', '2020-09-05T00:00:00.000000000',
#         '2020-09-06T00:00:00.000000000', '2020-09-07T00:00:00.000000000',
#         '2020-09-08T00:00:00.000000000', '2020-09-09T00:00:00.000000000',
#         '2020-09-10T00:00:00.000000000', '2020-09-11T00:00:00.000000000',
#         '2020-09-12T00:00:00.000000000', '2020-09-13T00:00:00.000000000',
#         '2020-09-14T00:00:00.000000000', '2020-09-15T00:00:00.000000000',
#         '2020-09-16T00:00:00.000000000', '2020-09-17T00:00:00.000000000',
#         '2020-09-18T00:00:00.000000000', '2020-09-19T00:00:00.000000000',
#         '2020-09-20T00:00:00.000000000', '2020-09-21T00:00:00.000000000',
#         '2020-09-22T00:00:00.000000000', '2020-09-23T00:00:00.000000000',
#         '2020-09-24T00:00:00.000000000', '2020-09-25T00:00:00.000000000',
#         '2020-09-26T00:00:00.000000000', '2020-09-27T00:00:00.000000000',
#         '2020-09-28T00:00:00.000000000', '2020-09-29T00:00:00.000000000',
#         '2020-09-30T00:00:00.000000000', '2020-10-01T00:00:00.000000000',
#         '2020-10-02T00:00:00.000000000', '2020-10-03T00:00:00.000000000',
#         '2020-10-04T00:00:00.000000000', '2020-10-05T00:00:00.000000000',
#         '2020-10-06T00:00:00.000000000', '2020-10-07T00:00:00.000000000',
#         '2020-10-08T00:00:00.000000000', '2020-10-09T00:00:00.000000000',
#         '2020-10-10T00:00:00.000000000', '2020-10-11T00:00:00.000000000',
#         '2020-10-12T00:00:00.000000000', '2020-10-13T00:00:00.000000000',
#         '2020-10-14T00:00:00.000000000', '2020-10-15T00:00:00.000000000',
#         '2020-10-16T00:00:00.000000000', '2020-10-17T00:00:00.000000000',
#         '2020-10-18T00:00:00.000000000', '2020-10-19T00:00:00.000000000',
#         '2020-10-20T00:00:00.000000000', '2020-10-21T00:00:00.000000000',
#         '2020-10-22T00:00:00.000000000', '2020-10-23T00:00:00.000000000',
#         '2020-10-24T00:00:00.000000000', '2020-10-25T00:00:00.000000000',
#         '2020-10-26T00:00:00.000000000', '2020-10-27T00:00:00.000000000',
#         '2020-10-28T00:00:00.000000000', '2020-10-29T00:00:00.000000000',
#         '2020-10-30T00:00:00.000000000', '2020-10-31T00:00:00.000000000',
#         '2020-11-01T00:00:00.000000000', '2020-11-02T00:00:00.000000000',
#         '2020-11-03T00:00:00.000000000', '2020-11-04T00:00:00.000000000',
#         '2020-11-05T00:00:00.000000000', '2020-11-06T00:00:00.000000000',
#         '2020-11-07T00:00:00.000000000', '2020-11-08T00:00:00.000000000',
#         '2020-11-09T00:00:00.000000000', '2020-11-10T00:00:00.000000000',
#         '2020-11-11T00:00:00.000000000', '2020-11-12T00:00:00.000000000',
#         '2020-11-13T00:00:00.000000000', '2020-11-14T00:00:00.000000000',
#         '2020-11-15T00:00:00.000000000', '2020-11-16T00:00:00.000000000',
#         '2020-11-17T00:00:00.000000000', '2020-11-18T00:00:00.000000000',
#         '2020-11-19T00:00:00.000000000', '2020-11-20T00:00:00.000000000',
#         '2020-11-21T00:00:00.000000000', '2020-11-22T00:00:00.000000000',
#         '2020-11-23T00:00:00.000000000', '2020-11-24T00:00:00.000000000',
#         '2020-11-25T00:00:00.000000000', '2020-11-26T00:00:00.000000000',
#         '2020-11-27T00:00:00.000000000', '2020-11-28T00:00:00.000000000',
#         '2020-11-29T00:00:00.000000000', '2020-11-30T00:00:00.000000000',
#         '2020-12-01T00:00:00.000000000', '2020-12-02T00:00:00.000000000',
#         '2020-12-03T00:00:00.000000000', '2020-12-04T00:00:00.000000000',
#         '2020-12-05T00:00:00.000000000', '2020-12-06T00:00:00.000000000',
#         '2020-12-07T00:00:00.000000000', '2020-12-08T00:00:00.000000000',
#         '2020-12-09T00:00:00.000000000', '2020-12-10T00:00:00.000000000',
#         '2020-12-11T00:00:00.000000000', '2020-12-12T00:00:00.000000000',
#         '2020-12-13T00:00:00.000000000', '2020-12-14T00:00:00.000000000',
#         '2020-12-15T00:00:00.000000000', '2020-12-16T00:00:00.000000000',
#         '2020-12-17T00:00:00.000000000', '2020-12-18T00:00:00.000000000',
#         '2020-12-19T00:00:00.000000000', '2020-12-20T00:00:00.000000000',
#         '2020-12-21T00:00:00.000000000', '2020-12-22T00:00:00.000000000',
#         '2020-12-23T00:00:00.000000000', '2020-12-24T00:00:00.000000000',
#         '2020-12-25T00:00:00.000000000', '2020-12-26T00:00:00.000000000',
#         '2020-12-27T00:00:00.000000000', '2020-12-28T00:00:00.000000000',
#         '2020-12-29T00:00:00.000000000', '2020-12-30T00:00:00.000000000',
#         '2020-12-31T00:00:00.000000000', '2021-01-01T00:00:00.000000000',
#         '2021-01-02T00:00:00.000000000', '2021-01-03T00:00:00.000000000',
#         '2021-01-04T00:00:00.000000000', '2021-01-05T00:00:00.000000000',
#         '2021-01-06T00:00:00.000000000', '2021-01-07T00:00:00.000000000',
#         '2021-01-08T00:00:00.000000000', '2021-01-09T00:00:00.000000000',
#         '2021-01-10T00:00:00.000000000', '2021-01-11T00:00:00.000000000',
#         '2021-01-12T00:00:00.000000000', '2021-01-13T00:00:00.000000000',
#         '2021-01-14T00:00:00.000000000', '2021-01-15T00:00:00.000000000',
#         '2021-01-16T00:00:00.000000000', '2021-01-17T00:00:00.000000000',
#         '2021-01-18T00:00:00.000000000', '2021-01-19T00:00:00.000000000',
#         '2021-01-20T00:00:00.000000000', '2021-01-21T00:00:00.000000000',
#         '2021-01-22T00:00:00.000000000', '2021-01-23T00:00:00.000000000',
#         '2021-01-24T00:00:00.000000000', '2021-01-25T00:00:00.000000000',
#         '2021-01-26T00:00:00.000000000', '2021-01-27T00:00:00.000000000',
#         '2021-01-28T00:00:00.000000000', '2021-01-29T00:00:00.000000000',
#         '2021-01-30T00:00:00.000000000', '2021-01-31T00:00:00.000000000',
#         '2021-02-01T00:00:00.000000000', '2021-02-02T00:00:00.000000000',
#         '2021-02-03T00:00:00.000000000', '2021-02-04T00:00:00.000000000',
#         '2021-02-05T00:00:00.000000000', '2021-02-06T00:00:00.000000000',
#         '2021-02-07T00:00:00.000000000', '2021-02-08T00:00:00.000000000',
#         '2021-02-09T00:00:00.000000000', '2021-02-10T00:00:00.000000000',
#         '2021-02-11T00:00:00.000000000', '2021-02-12T00:00:00.000000000',
#         '2021-02-13T00:00:00.000000000', '2021-02-14T00:00:00.000000000',
#         '2021-02-15T00:00:00.000000000', '2021-02-16T00:00:00.000000000',
#         '2021-02-17T00:00:00.000000000', '2021-02-18T00:00:00.000000000',
#         '2021-02-19T00:00:00.000000000', '2021-02-20T00:00:00.000000000',
#         '2021-02-21T00:00:00.000000000', '2021-02-22T00:00:00.000000000',
#         '2021-02-23T00:00:00.000000000', '2021-02-24T00:00:00.000000000',
#         '2021-02-25T00:00:00.000000000', '2021-02-26T00:00:00.000000000',
#         '2021-02-27T00:00:00.000000000', '2021-02-28T00:00:00.000000000',
#         '2021-03-01T00:00:00.000000000', '2021-03-02T00:00:00.000000000',
#         '2021-03-03T00:00:00.000000000', '2021-03-04T00:00:00.000000000',
#         '2021-03-05T00:00:00.000000000', '2021-03-06T00:00:00.000000000',
#         '2021-03-07T00:00:00.000000000', '2021-03-08T00:00:00.000000000',
#         '2021-03-09T00:00:00.000000000', '2021-03-10T00:00:00.000000000',
#         '2021-03-11T00:00:00.000000000', '2021-03-12T00:00:00.000000000',
#         '2021-03-13T00:00:00.000000000', '2021-03-14T00:00:00.000000000',
#         '2021-03-15T00:00:00.000000000', '2021-03-16T00:00:00.000000000',
#         '2021-03-17T00:00:00.000000000', '2021-03-18T00:00:00.000000000',
#         '2021-03-19T00:00:00.000000000', '2021-03-20T00:00:00.000000000',
#         '2021-03-21T00:00:00.000000000', '2021-03-22T00:00:00.000000000',
#         '2021-03-23T00:00:00.000000000', '2021-03-24T00:00:00.000000000',
#         '2021-03-25T00:00:00.000000000', '2021-03-26T00:00:00.000000000',
#         '2021-03-27T00:00:00.000000000', '2021-03-28T00:00:00.000000000',
#         '2021-03-29T00:00:00.000000000', '2021-03-30T00:00:00.000000000',
#         '2021-03-31T00:00:00.000000000', '2021-04-01T00:00:00.000000000',
#         '2021-04-02T00:00:00.000000000', '2021-04-03T00:00:00.000000000',
#         '2021-04-04T00:00:00.000000000', '2021-04-05T00:00:00.000000000',
#         '2021-04-06T00:00:00.000000000', '2021-04-07T00:00:00.000000000',
#         '2021-04-08T00:00:00.000000000', '2021-04-09T00:00:00.000000000',
#         '2021-04-10T00:00:00.000000000', '2021-04-11T00:00:00.000000000',
#         '2021-04-12T00:00:00.000000000', '2021-04-13T00:00:00.000000000',
#         '2021-04-14T00:00:00.000000000', '2021-04-15T00:00:00.000000000',
#         '2021-04-16T00:00:00.000000000', '2021-04-17T00:00:00.000000000',
#         '2021-04-18T00:00:00.000000000', '2021-04-19T00:00:00.000000000',
#         '2021-04-20T00:00:00.000000000', '2021-04-21T00:00:00.000000000',
#         '2021-04-22T00:00:00.000000000', '2021-04-23T00:00:00.000000000',
#         '2021-04-24T00:00:00.000000000', '2021-04-25T00:00:00.000000000',
#         '2021-04-26T00:00:00.000000000', '2021-04-27T00:00:00.000000000',
#         '2021-04-28T00:00:00.000000000', '2021-04-29T00:00:00.000000000',
#         '2021-04-30T00:00:00.000000000', '2021-05-01T00:00:00.000000000',
#         '2021-05-02T00:00:00.000000000', '2021-05-03T00:00:00.000000000',
#         '2021-05-04T00:00:00.000000000', '2021-05-05T00:00:00.000000000',
#         '2021-05-06T00:00:00.000000000', '2021-05-07T00:00:00.000000000',
#         '2021-05-08T00:00:00.000000000', '2021-05-09T00:00:00.000000000',
#         '2021-05-10T00:00:00.000000000', '2021-05-11T00:00:00.000000000',
#         '2021-05-12T00:00:00.000000000', '2021-05-13T00:00:00.000000000',
#         '2021-05-14T00:00:00.000000000', '2021-05-15T00:00:00.000000000',
#         '2021-05-16T00:00:00.000000000', '2021-05-17T00:00:00.000000000',
#         '2021-05-18T00:00:00.000000000', '2021-05-19T00:00:00.000000000',
#         '2021-05-20T00:00:00.000000000', '2021-05-21T00:00:00.000000000',
#         '2021-05-22T00:00:00.000000000', '2021-05-23T00:00:00.000000000',
#         '2021-05-24T00:00:00.000000000', '2021-05-25T00:00:00.000000000',
#         '2021-05-26T00:00:00.000000000', '2021-05-27T00:00:00.000000000',
#         '2021-05-28T00:00:00.000000000', '2021-05-29T00:00:00.000000000',
#         '2021-05-30T00:00:00.000000000', '2021-05-31T00:00:00.000000000',
#         '2021-06-01T00:00:00.000000000', '2021-06-02T00:00:00.000000000',
#         '2021-06-03T00:00:00.000000000', '2021-06-04T00:00:00.000000000',
#         '2021-06-05T00:00:00.000000000', '2021-06-06T00:00:00.000000000',
#         '2021-06-07T00:00:00.000000000', '2021-06-08T00:00:00.000000000',
#         '2021-06-09T00:00:00.000000000', '2021-06-10T00:00:00.000000000',
#         '2021-06-11T00:00:00.000000000', '2021-06-12T00:00:00.000000000',
#         '2021-06-13T00:00:00.000000000', '2021-06-14T00:00:00.000000000',
#         '2021-06-15T00:00:00.000000000', '2021-06-16T00:00:00.000000000',
#         '2021-06-17T00:00:00.000000000', '2021-06-18T00:00:00.000000000',
#         '2021-06-19T00:00:00.000000000', '2021-06-20T00:00:00.000000000',
#         '2021-06-21T00:00:00.000000000', '2021-06-22T00:00:00.000000000',
#         '2021-06-23T00:00:00.000000000', '2021-06-24T00:00:00.000000000',
#         '2021-06-25T00:00:00.000000000', '2021-06-26T00:00:00.000000000',
#         '2021-06-27T00:00:00.000000000', '2021-06-28T00:00:00.000000000',
#         '2021-06-29T00:00:00.000000000', '2021-06-30T00:00:00.000000000',
#         '2021-07-01T00:00:00.000000000', '2021-07-02T00:00:00.000000000',
#         '2021-07-03T00:00:00.000000000', '2021-07-04T00:00:00.000000000',
#         '2021-07-05T00:00:00.000000000', '2021-07-06T00:00:00.000000000',
#         '2021-07-07T00:00:00.000000000', '2021-07-08T00:00:00.000000000',
#         '2021-07-09T00:00:00.000000000', '2021-07-10T00:00:00.000000000',
#         '2021-07-11T00:00:00.000000000', '2021-07-12T00:00:00.000000000',
#         '2021-07-13T00:00:00.000000000', '2021-07-14T00:00:00.000000000',
#         '2021-07-15T00:00:00.000000000', '2021-07-16T00:00:00.000000000',
#         '2021-07-17T00:00:00.000000000', '2021-07-18T00:00:00.000000000',
#         '2021-07-19T00:00:00.000000000', '2021-07-20T00:00:00.000000000',
#         '2021-07-21T00:00:00.000000000', '2021-07-22T00:00:00.000000000',
#         '2021-07-23T00:00:00.000000000', '2021-07-24T00:00:00.000000000',
#         '2021-07-26T00:00:00.000000000', '2021-07-27T00:00:00.000000000',
#         '2021-07-28T00:00:00.000000000', '2021-07-29T00:00:00.000000000',
#         '2021-08-01T00:00:00.000000000', '2021-08-02T00:00:00.000000000',
#         '2021-08-03T00:00:00.000000000', '2021-08-04T00:00:00.000000000',
#         '2021-08-05T00:00:00.000000000', '2021-08-06T00:00:00.000000000',
#         '2021-08-07T00:00:00.000000000', '2021-08-09T00:00:00.000000000',
#         '2021-08-10T00:00:00.000000000', '2021-08-11T00:00:00.000000000',
#         '2021-08-12T00:00:00.000000000', '2021-08-13T00:00:00.000000000',
#         '2021-08-14T00:00:00.000000000', '2021-08-15T00:00:00.000000000',
#         '2021-08-16T00:00:00.000000000', '2021-08-17T00:00:00.000000000',
#         '2021-08-18T00:00:00.000000000', '2021-08-19T00:00:00.000000000',
#         '2021-08-20T00:00:00.000000000', '2021-08-21T00:00:00.000000000',
#         '2021-08-23T00:00:00.000000000', '2021-08-24T00:00:00.000000000',
#         '2021-08-25T00:00:00.000000000', '2021-08-26T00:00:00.000000000',
#         '2021-08-27T00:00:00.000000000', '2021-08-28T00:00:00.000000000',
#         '2021-08-30T00:00:00.000000000', '2021-08-31T00:00:00.000000000',
#         '2021-09-01T00:00:00.000000000', '2021-09-02T00:00:00.000000000',
#         '2021-09-03T00:00:00.000000000', '2021-09-04T00:00:00.000000000',
#         '2021-09-05T00:00:00.000000000', '2021-09-07T00:00:00.000000000',
#         '2021-09-08T00:00:00.000000000', '2021-09-09T00:00:00.000000000',
#         '2021-09-10T00:00:00.000000000', '2021-09-13T00:00:00.000000000',
#         '2021-09-14T00:00:00.000000000', '2021-09-15T00:00:00.000000000',
#         '2021-09-17T00:00:00.000000000', '2021-09-20T00:00:00.000000000',
#         '2021-09-21T00:00:00.000000000', '2021-09-22T00:00:00.000000000',
#         '2021-09-23T00:00:00.000000000', '2021-09-24T00:00:00.000000000',
#         '2021-09-25T00:00:00.000000000', '2021-09-27T00:00:00.000000000',
#         '2021-09-28T00:00:00.000000000', '2021-09-29T00:00:00.000000000',
#         '2021-09-30T00:00:00.000000000', '2021-10-01T00:00:00.000000000',
#         '2021-10-02T00:00:00.000000000', '2021-10-03T00:00:00.000000000',
#         '2021-10-04T00:00:00.000000000', '2021-10-05T00:00:00.000000000',
#         '2021-10-06T00:00:00.000000000', '2021-10-07T00:00:00.000000000',
#         '2021-10-08T00:00:00.000000000', '2021-10-09T00:00:00.000000000',
#         '2021-10-11T00:00:00.000000000', '2021-10-12T00:00:00.000000000',
#         '2021-10-13T00:00:00.000000000', '2021-10-14T00:00:00.000000000',
#         '2021-10-15T00:00:00.000000000', '2021-10-16T00:00:00.000000000',
#         '2021-10-18T00:00:00.000000000', '2021-10-19T00:00:00.000000000',
# ...
#         'IGNORED', 'imputed'], dtype=object),
#  array(['0 - VERY RARELY OR NEVER HAS BOWEL INCONTINENCE ',
#         '1 - LESS THAN ONCE WEEKLY ', '2 - ONE TO THREE TIMES WEEKLY ',
#         '3 - FOUR TO SIX TIMES WEEKLY ', '4 - ON A DAILY BASIS ',
#         '5 - MORE OFTEN THAN ONCE DAILY ',
#         'NA - PATIENT HAS OSTOMY FOR BOWEL ELIMINATION', 'UK - UNKNOWN',
#         'imputed'], dtype=object),
#  array(['0 - PATIENT DOES NOT HAVE AN OSTOMY FOR BOWEL ELIMINATION. ',
#         "1 - PATIENT'S OSTOMY WAS NOT RELATED TO AN INPATIENT STAY AND DID NOT NECESSITATE CHANGE IN MEDICAL OR TREATMENT REGIMEN. ",
#         '2 - THE OSTOMY WAS RELATED TO AN INPATIENT STAY OR DID NECESSITATE CHANGE IN MEDICAL OR TREATMENT REGIMEN.',
#         'imputed'], dtype=object),
#  array(['0 - ALERT/ORIENTED, ABLE TO FOCUS AND SHIFT ATTENTION, COMPREHENDS AND RECALLS TASK DIRECTIONS INDEPENDENTLY. ',
#         '1 - REQUIRES PROMPTING (CUING, REPETITION, REMINDERS) ONLY UNDER STRESSFUL OR UNFAMILIAR CONDITIONS. ',
#         '2 - REQUIRES ASSISTANCE AND SOME DIRECTION IN SPECIFIC SITUATIONS (FOR EXAMPLE,  ON ALL TASKS INVOLVING SHIFTING OF ATTENTION), OR CONSISTENTLY REQUIRES LOW STIMULUS ENVIRONMENT DUE TO DISTRACTIBILITY. ',
#         '3 - REQUIRES CONSIDERABLE ASSISTANCE IN ROUTINE SITUATIONS. IS NOT ALERT AND ORIENTED OR IS UNABLE TO SHIFT ATTENTION AND RECALL DIRECTIONS MORE THAN HALF THE TIME.',
#         '4 - TOTALLY DEPENDENT DUE TO DISTURBANCES SUCH AS CONSTANT DISORIENTATION, COMA, PERSISTENT VEGETATIVE STATE, OR DELIRIUM.',
#         'imputed'], dtype=object),
#  array(['0 - NEVER ', '1 - IN NEW OR COMPLEX SITUATIONS ONLY ',
#         '2 - ON AWAKENING OR AT NIGHT ONLY ',
#         '3 - DURING THE DAY AND EVENING, BUT NOT CONSTANTLY ',
#         '4 - CONSTANTLY', 'NA - PATIENT NONRESPONSIVE', 'imputed'],
#        dtype=object),
#  array(['0 - NONE OF THE TIME', '1 - LESS OFTEN THAN DAILY ',
#         '2 - DAILY, BUT NOT CONSTANTLY', '3 - ALL OF THE TIME ',
#         'NA - PATIENT NONRESPONSIVE', 'imputed'], dtype=object),
#  array(['0 - NOT AT ALL (0 - 1 DAY) ', '1 - SEVERAL DAYS (2 - 6 DAYS) ',
#         '2 - MORE THAN HALF OF THE DAYS (7 - 11 DAYS) ',
#         '3 - NEARLY EVERY DAY (12 - 14 DAYS) ', 'N/A - UNABLE TO RESPOND',
#         'imputed'], dtype=object),
#  array(['0 - NOT AT ALL (0 - 1 DAY) ', '1 - SEVERAL DAYS (2 - 6 DAYS) ',
#         '2 - MORE THAN HALF OF THE DAYS (7 - 11 DAYS) ',
#         '3 - NEARLY EVERY DAY (12 - 14 DAYS) ', 'N/A - UNABLE TO RESPOND',
#         'imputed'], dtype=object),
#  array(['0 - NO',
#         '1 - YES, PATIENT WAS SCREENED USING THE PHQ-2(c) SCALE. (INSTRUCTIONS FOR THIS TWO-QUESTION TOOL: ASK PATIENT: "OVER THE LAST TWO WEEKS, HOW OFTEN HAVE YOU BEEN BOTHERED BY ANY OF THE FOLLOWING PROBLEMS")',
#         '2 - YES, PATIENT WAS SCREENED WITH A DIFFERENT STANDARDIZED, VALIDATED ASSESSMENT AND THE PATIENT MEETS CRITERIA FOR FURTHER EVALUATION FOR DEPRESSION.',
#         '3 - YES, PATIENT WAS SCREENED WITH A DIFFERENT STANDARDIZED, VALIDATED ASSESSMENT AND THE PATIENT DOES NOT MEET CRITERIA FOR FURTHER EVALUATION FOR DEPRESSION.',
#         'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['0 - NEVER', '1 - LESS THAN ONCE A MONTH', '2 - ONCE A MONTH',
#         '3 - SEVERAL TIMES EACH MONTH', '4 - SEVERAL TIMES A WEEK',
#         '5 - AT LEAST DAILY', 'imputed'], dtype=object),
#  array(['0 - ABLE TO GROOM SELF UNAIDED, WITH OR WITHOUT THE USE OF ASSISTIVE DEVICES OR ADAPTED METHODS',
#         '1 - GROOMING UTENSILS MUST BE PLACED WITHIN REACH BEFORE ABLE TO COMPLETE GROOMING ACTIVITIES',
#         '2 - SOMEONE MUST ASSIST THE PATIENT TO GROOM SELF',
#         '3 - PATIENT DEPENDS ENTIRELY UPON SOMEONE ELSE FOR GROOMING NEEDS',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO GET CLOTHES OUT OF CLOSETS AND DRAWERS, PUT THEM ON AND REMOVE THEM FROM THE UPPER BODY WITHOUT ASSISTANCE',
#         '1 - ABLE TO DRESS UPPER BODY WITHOUT ASSISTANCE IF CLOTHING IS LAID OUT OR HANDED TO THE PATIENT',
#         '2 - SOMEONE MUST HELP THE PATIENT PUT ON UPPER BODY CLOTHING',
#         '3 - PATIENT DEPENDS ENTIRELY UPON ANOTHER PERSON TO DRESS UPPER BODY',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO OBTAIN, PUT ON, AND REMOVE CLOTHING AND SHOES WITHOUT ASSISTANCE',
#         '1 - ABLE TO DRESS LOWER BODY WITHOUT ASSISTANCE IF CLOTHING AND SHOES ARE LAID OUT OR HANDED TO THE PATIENT',
#         '2 - SOMEONE MUST HELP PATIENT PUT ON UNDERGARMENTS, SLACKS, SOCKS OR NYLONS, AND SHOES',
#         '3 - PATIENT DEPENDS ENTIRELY UPON ANOTHER PERSON TO DRESS LOWER BODY',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO BATHE SELF IN SHOWER OR TUB INDEPENDENTLY, INCLUDING GETTING IN AND OUT OF TUB/SHOWER.',
#         '1 - WITH THE USE OF DEVICES, IS ABLE TO BATHE SELF IN SHOWER OR TUB INDEPENDENTLY, INCLUDING GETTING IN AND OUT OF THE TUB/SHOWER. ',
#         '2 - ABLE TO BATHE IN SHOWER OR TUB WITH THE INTERMITTENT ASSISTANCE OF ANOTHER PERSON: (A) FOR INTERMITTENT SUPERVISION OR ENCOURAGEMENT OR REMINDERS, OR (B) TO GET IN AND OUT OF THE SHOWER OR TUB, OR (C) FOR WASHING DIFFICULT TO REACH AREAS. ',
#         '3 - ABLE TO PARTICIPATE IN BATHING SELF IN SHOWER OR TUB, BUT REQUIRES PRESENCE OF ANOTHER PERSON THROUGHOUT THE BATH FOR ASSISTANCE OR SUPERVISION. ',
#         '4 - UNABLE TO USE THE SHOWER OR TUB, BUT ABLE TO BATHE SELF INDEPENDENTLY, WITH OR WITHOUT THE USE OF DEVICES, AT THE SINK, IN CHAIR, OR ON COMMODE. ',
#         '5 - UNABLE TO USE THE SHOWER OR TUB, BUT ABLE TO PARTICIPATE IN BATHING SELF IN BED, AT THE SINK, IN BEDSIDE CHAIR, OR ON COMMODE, WITH THE ASSISTANCE OR SUPERVISION OF ANOTHER PERSON.',
#         '6 - UNABLE TO PARTICIPATE EFFECTIVELY IN BATHING AND IS BATHED TOTALLY BY ANOTHER PERSON.',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO GET TO AND FROM THE TOILET AND TRANSFER INDEPENDENTLY WITH OR WITHOUT A DEVICE. ',
#         '1 - WHEN REMINDED, ASSISTED, OR SUPERVISED BY ANOTHER PERSON, ABLE TO GET TO AND FROM THE TOILET AND TRANSFER. ',
#         '2 - UNABLE TO GET TO AND FROM THE TOILET BUT IS ABLE TO USE A BEDSIDE COMMODE (WITH OR WITHOUT ASSISTANCE). ',
#         '3 - UNABLE TO GET TO AND FROM THE TOILET OR BEDSIDE COMMODE BUT IS ABLE TO USE A BEDPAN/URINAL INDEPENDENTLY. ',
#         '4 - IS TOTALLY DEPENDENT IN TOILETING.', 'imputed'], dtype=object),
#  array(['0 - ABLE TO MANAGE TOILETING HYGIENE AND CLOTHING MANAGEMENT WITHOUT ASSISTANCE.',
#         '1 - ABLE TO MANAGE TOILETING HYGIENE AND CLOTHING MANAGEMENT WITHOUT ASSISTANCE IF SUPPLIES/IMPLEMENTS ARE LAID OUT FOR THE PATIENT. ',
#         '2 -SOMEONE MUST HELP THE PATIENT TO MAINTAIN TOILETING HYGIENE AND/OR ADJUST CLOTHING. ',
#         '3 - PATIENT DEPENDS ENTIRELY UPON ANOTHER PERSON TO MAINTAIN TOILETING HYGIENE.',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY TRANSFER',
#         '1 - ABLE TO TRANSFER WITH MINIMAL HUMAN ASSISTANCE OR WITH USE OF AN ASSISTIVE DEVICE',
#         '2 - ABLE TO BEAR WEIGHT AND PIVOT DURING THE TRANSFER PROCESS BUT UNABLE TO TRANSFER SELF',
#         '3 - UNABLE TO TRANSFER SELF AND IS UNABLE TO BEAR WEIGHT OR PIVOT WHEN TRANSFERRED BY ANOTHER PERSON',
#         '4 - BEDFAST, UNABLE TO TRANSFER BUT IS ABLE TO TURN AND POSITION SELF IN BED',
#         '5 - BEDFAST, UNABLE TO TRANSFER AND IS UNABLE TO TURN AND POSITION SELF',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY WALK ON EVEN AND UNEVEN SURFACES AND NEGOTIATE STAIRS WITH OR WITHOUT RAILINGS (SPECIFICALLY: NEEDS NO HUMAN ASSISTANCE OR ASSISTIVE DEVICE).',
#         '1 - WITH THE USE OF A ONE-HANDED DEVICE (FOR EXAMPLE, CANE, SINGLE CRUTCH, HEMI-WALKER), ABLE TO INDEPENDENTLY WALK ON EVEN AND UNEVEN SURFACES AND NEGOTIATE STAIRS WITH OR WITHOUT RAILINGS.',
#         '2 - REQUIRES USE OF A TWO-HANDED DEVICE (FOR EXAMPLE, WALKER OR CRUTCHES) TO WALK ALONE ON A LEVEL SURFACE AND/OR REQUIRES HUMAN SUPERVISION OR ASSISTANCE TO NEGOTIATE STAIRS OR STEPS OR UNEVEN SURFACES.',
#         '3 - ABLE TO WALK ONLY WITH THE SUPERVISION OR ASSISTANCE OF ANOTHER PERSON AT ALL TIMES. ',
#         '4 - CHAIRFAST, UNABLE TO AMBULATE BUT IS ABLE TO WHEEL SELF INDEPENDENTLY. ',
#         '5 - CHAIRFAST, UNABLE TO AMBULATE AND IS UNABLE TO WHEEL SELF. ',
#         '6 - BEDFAST, UNABLE TO AMBULATE OR BE UP IN A CHAIR', 'imputed'],
#        dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY FEED SELF',
#         '1 - ABLE TO FEED SELF INDEPENDENTLY BUT REQUIRES: (A) MEAL SET-UP; OR (B) INTERMITTENT ASSISTANCE OR SUPERVISION FROM ANOTHER PERSON; OR (C) A LIQUID, PUREED OR GROUND MEAT DIET',
#         '2 - UNABLE TO FEED SELF AND MUST BE ASSISTED OR SUPERVISED THROUGHOUT THE MEAL/SNACK',
#         '3 - ABLE TO TAKE IN NUTRIENTS ORALLY AND RECEIVES SUPPLEMENTAL NUTRIENTS THROUGH A NASOGASTRIC TUBE OR GASTROSTOMY',
#         '4 - UNABLE TO TAKE IN NUTRIENTS ORALLY AND IS FED NUTRIENTS THROUGH NASOGASTRIC TUBE OR GASTROSTOMY',
#         '5 - UNABLE TO TAKE IN NUTRIENTS ORALLY OR BY TUBE FEEDING',
#         'imputed'], dtype=object),
#  array(['0 - NO.', '1 -YES, AND IT DOES NOT INDICATE A RISK FOR FALLS. ',
#         '2 - YES, AND IT DOES INDICATE A RISK FOR FALLS.', 'imputed'],
#        dtype=object),
#  array(['-', '0 - NO - NO ISSUES FOUND DURING REVIEW',
#         '1 - YES - ISSUES FOUND DURING REVIEW',
#         '9 - NA - PATIENT IS NOT TAKING ANY MEDICATIONS', 'imputed'],
#        dtype=object),
#  array(['-', '0 - NO', '1 - YES', 'imputed'], dtype=object),
#  array(['-', '0 - NO', '1 - YES',
#         '9 - NA - THERE WERE NO POTENTIALLY CLINICALLY SIGNIFICANT MEDICATION ISSUES IDENTIFIED SINCE SOC/ROC OR PATIENT IS NOT TAKING ANY MEDICATIONS',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - PATIENT NOT TAKING ANY HIGH RISK DRUGS OR PATIENT/CAREGIVER FULLY KNOWLEDGEABLE ABOUT SPECIAL PRECAUTIONS ASSOCIATED WITH ALL HIGH-RISK MEDICATIONS',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES', 'NA - PATIENT NOT TAKING ANY DRUGS',
#         'imputed'], dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY TAKE THE CORRECT ORAL MEDICATION(S) AND PROPER DOSAGE(S) AT THE CORRECT TIMES. ',
#         '1 - ABLE TO TAKE MEDICATION(S) AT THE CORRECT TIMES IF: (A) INDIVIDUAL DOSAGES ARE PREPARED IN ADVANCE BY ANOTHER PERSON; OR (B) ANOTHER PERSON DEVELOPS A DRUG DIARY OR CHART. ',
#         '2 - ABLE TO TAKE MEDICATION(S) AT THE CORRECT TIMES IF GIVEN REMINDERS BY ANOTHER PERSON AT THE APPROPRIATE TIMES ',
#         '3 - UNABLE TO TAKE MEDICATION UNLESS ADMINISTERED BY ANOTHER PERSON. ',
#         'NA - NO ORAL MEDICATIONS PRESCRIBED.', 'imputed'], dtype=object),
#  array(['0 - ABLE TO INDEPENDENTLY TAKE THE CORRECT MEDICATION(S) AND PROPER DOSAGE(S) AT THE CORRECT TIMES. ',
#         '1 - ABLE TO TAKE INJECTABLE MEDICATION(S) AT THE CORRECT TIMES IF: (A) INDIVIDUAL SYRINGES ARE PREPARED IN ADVANCE BY ANOTHER PERSON; OR (B) ANOTHER PERSON DEVELOPS A DRUG DIARY OR CHART. ',
#         '2 - ABLE TO TAKE MEDICATION(S) AT THE CORRECT TIMES IF GIVEN REMINDERS BY ANOTHER PERSON BASED ON THE FREQUENCY OF THE INJECTION ',
#         '3 - UNABLE TO TAKE INJECTABLE MEDICATION UNLESS ADMINISTERED BY ANOTHER PERSON. ',
#         'NA - NO INJECTABLE MEDICATIONS PRESCRIBED', 'imputed'],
#        dtype=object),
#  array(['0 - NO ASSISTANCE NEEDED –PATIENT IS INDEPENDENT OR DOES NOT HAVE NEEDS IN THIS AREA',
#         '1 - NON-AGENCY CAREGIVER(S) CURRENTLY PROVIDE ASSISTANCE',
#         '2 - NON-AGENCY CAREGIVER(S) NEED TRAINING/ SUPPORTIVE SERVICES TO PROVIDE ASSISTANCE',
#         '3 - NON-AGENCY CAREGIVER(S) ARE NOT LIKELY TO PROVIDE ASSISTANCE OR IT IS UNCLEAR IF THEY WILL PROVIDE ASSISTANCE',
#         '4 - ASSISTANCE NEEDED, BUT NO NON-AGENCY CAREGIVER(S) AVAILABLE',
#         'imputed'], dtype=object),
#  array(['0 - NO ASSISTANCE NEEDED –PATIENT IS INDEPENDENT OR DOES NOT HAVE NEEDS IN THIS AREA',
#         '1 - NON-AGENCY CAREGIVER(S) CURRENTLY PROVIDE ASSISTANCE',
#         '2 - NON-AGENCY CAREGIVER(S) NEED TRAINING/ SUPPORTIVE SERVICES TO PROVIDE ASSISTANCE',
#         '3 - NON-AGENCY CAREGIVER(S) ARE NOT LIKELY TO PROVIDE ASSISTANCE OR IT IS UNCLEAR IF THEY WILL PROVIDE ASSISTANCE',
#         '4 - ASSISTANCE NEEDED, BUT NO NON-AGENCY CAREGIVER(S) AVAILABLE',
#         'imputed'], dtype=object),
#  array(['0 - NO ASSISTANCE NEEDED –PATIENT IS INDEPENDENT OR DOES NOT HAVE NEEDS IN THIS AREA',
#         '1 - NON-AGENCY CAREGIVER(S) CURRENTLY PROVIDE ASSISTANCE',
#         '2 - NON-AGENCY CAREGIVER(S) NEED TRAINING/ SUPPORTIVE SERVICES TO PROVIDE ASSISTANCE',
#         '3 - NON-AGENCY CAREGIVER(S) ARE NOT LIKELY TO PROVIDE ASSISTANCE OR IT IS UNCLEAR IF THEY WILL PROVIDE ASSISTANCE',
#         '4 - ASSISTANCE NEEDED, BUT NO NON-AGENCY CAREGIVER(S) AVAILABLE',
#         'imputed'], dtype=object),
#  array(['0 - NO ASSISTANCE NEEDED –PATIENT IS INDEPENDENT OR DOES NOT HAVE NEEDS IN THIS AREA',
#         '1 - NON-AGENCY CAREGIVER(S) CURRENTLY PROVIDE ASSISTANCE',
#         '2 - NON-AGENCY CAREGIVER(S) NEED TRAINING/ SUPPORTIVE SERVICES TO PROVIDE ASSISTANCE',
#         '3 - NON-AGENCY CAREGIVER(S) ARE NOT LIKELY TO PROVIDE ASSISTANCE OR IT IS UNCLEAR IF THEY WILL PROVIDE ASSISTANCE',
#         '4 - ASSISTANCE NEEDED, BUT NO NON-AGENCY CAREGIVER(S) AVAILABLE',
#         'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['0 - NO',
#         '1 - YES, USED HOSPITAL EMERGENCY DEPARTMENT WITHOUT HOSPITAL ADMISSION ',
#         '2 - YES, USED HOSPITAL EMERGENCY DEPARTMENT WITH HOSPITAL ADMISSION',
#         'UK - UNKNOWN', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['NO', 'YES', 'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - PATIENT IS NOT DIABETIC OR IS MISSING LOWER LEGS DUE TO CONGENITAL OR ACQUIRED CONDITION (BILATERAL AMPUTEE).',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - (C2) PATIENT HAS NO DIAGNOSIS OF DEPRESSION AND EVERY STANDARDIZED, VALIDATED DEPRESSION SCREENING CONDUCTED AT OR SINCE THE MOST RECENT SOC/ROC ASSESSMENT INDICATES THE PATIENT HAS: 1) NO SYMPTOMS OF DEPRESSION; OR 2) HAS SOME SYMPTOMS OF DEPRESSION BUT DOES NOT MEET CRITERIA FOR FURTHER EVALUATION OF DEPRESSION BASED ON SCREENING TOOL USED.',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - (C2) EVERY STANDARDIZED, VALIDATED MULTI-FACTOR FALL RISK ASSESSMENT CONDUCTED AT OR SINCE THE MOST RECENT SOC/ROC ASSESSMENT INDICATES THE PATIENT HAS NO RISK FOR FALLS.',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - (C2) EVERY STANDARDIZED, VALIDATED PAIN ASSESSMENT CONDUCTED AT OR SINCE THE MOST RECENT SOC/ROC ASSESSMENT INDICATES THE PATIENT HAS NO PAIN.',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - (C2) EVERY STANDARDIZED, VALIDATED PRESSURE ULCER RISK ASSESSMENT CONDUCTED AT OR SINCE THE RECENT SOC/ROC  ASSESSMENT INDICATES THE PATIENT IS NOT AT RISK OF DEVELOPING PRESSURE ULCERS.',
#         'imputed'], dtype=object),
#  array(['0 - NO', '1 - YES',
#         'NA - PATIENT HAS NO PRESSURE ULCERS OR HAS NO PRESSURE ULCERS FOR WHICH MOIST WOUND HEALING IS INDICATED.',
#         'imputed'], dtype=object),
#  array(['1 - HOSPITAL', '2 - REHABILITATION FACILITY', '3 - NURSING HOME',
#         '4 - HOSPICE', 'NA - NO INPATIENT FACILITY ADMISSION', 'imputed'],
#        dtype=object),
#  array(['1 - PATIENT REMAINED IN THE COMMUNITY (WITHOUT FORMAL ASSISTIVE SERVICES) ',
#         '2 - PATIENT REMAINED IN THE COMMUNITY (WITH FORMAL ASSISTIVE SERVICES) ',
#         '3 - PATIENT TRANSFERRED TO A NON-INSTITUTIONAL HOSPICE ',
#         '4 - UNKNOWN BECAUSE PATIENT MOVED TO A GEOGRAPHIC LOCATION NOT SERVED BY THIS AGENCY ',
#         'UK - OTHER UNKNOWN', 'imputed'], dtype=object),
#  array(['0', '1'], dtype=object)]

# %%
xdf = enc.transform(df) # transform using encoder

# %%
df2 = pd.DataFrame(xdf, columns=df.columns) # numpy to dataframe

# %%
X = df2.iloc[:,:-1]

# %%
y = df2.iloc[:,-1:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)

# %% [markdown]
# ### Quick Evaluation using RFE Feature Selection: LogisticRegression

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
rfe = RFE(estimator=LogisticRegression(), n_features_to_select=10, verbose=1)

rfe.fit(X_train, y_train)

print(dict(zip(X.columns, rfe.ranking_)))
# Out:
# Fitting estimator with 128 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 127 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 126 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 125 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 124 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 123 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 122 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 121 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 120 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 119 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 118 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 117 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 116 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 115 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 114 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 113 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 112 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 111 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 110 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 109 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 108 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 107 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 106 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 105 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 104 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 103 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 102 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 101 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 100 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 99 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 98 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 97 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 96 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 95 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 94 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 93 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 92 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 91 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 90 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 89 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 88 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 87 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 86 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 85 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 84 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 83 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 82 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 81 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 80 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 79 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 78 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 77 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 76 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 75 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 74 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# {'year_born': 82, 'pa_race': 32, 'pa_gender': 80, 'pa_maritalstatus': 54, 'epi_AdmitType': 1, 'epi_height': 89, 'epi_weight': 103, 'ceo_HIPPS': 83, 'ceo_HHRG': 61, 'icd_code': 114, 'DiagnosisCategory': 48, 'RoughAge': 9, 'M0100_ASSMT_REASON': 58, 'M0110_EPISODE_TIMING': 109, 'M0140_ETHNIC_AI_AN': 34, 'M0140_ETHNIC_ASIAN': 36, 'M0140_ETHNIC_BLACK': 55, 'M0140_ETHNIC_HISP': 46, 'M0140_ETHNIC_NH_PI': 44, 'M0140_ETHNIC_WHITE': 119, 'M0906_DC_TRAN_DTH_DT': 100, 'M1000_DC_IPPS_14_DA': 68, 'M1000_DC_IRF_14_DA': 18, 'M1000_DC_LTC_14_DA': 35, 'M1000_DC_LTCH_14_DA': 28, 'M1000_DC_NONE_14_DA': 1, 'M1000_DC_OTH_14_DA': 41, 'M1000_DC_PSYCH_14_DA': 42, 'M1000_DC_SNF_14_DA': 16, 'M1028_ACTV_DIAG_DM': 5, 'M1028_ACTV_DIAG_NOA': 91, 'M1028_ACTV_DIAG_PVD_PAD': 113, 'M1030_THH_ENT_NUTRITION': 117, 'M1030_THH_IV_INFUSION': 110, 'M1030_THH_NONE_ABOVE': 115, 'M1030_THH_PAR_NUTRITION': 105, 'M1033_HOSP_RISK_5PLUS_MDCTN': 97, 'M1033_HOSP_RISK_COMPLIANCE': 73, 'M1033_HOSP_RISK_CRNT_EXHSTN': 86, 'M1033_HOSP_RISK_HSTRY_FALLS': 111, 'M1033_HOSP_RISK_MLTPL_ED_VISIT': 49, 'M1033_HOSP_RISK_MLTPL_HOSPZTN': 53, 'M1033_HOSP_RISK_MNTL_BHV_DCLN': 108, 'M1033_HOSP_RISK_NONE_ABOVE': 116, 'M1033_HOSP_RISK_OTHR_RISK': 112, 'M1033_HOSP_RISK_WEIGHT_LOSS': 1, 'M1046_INFLNZ_RECD_CRNT_SEASON': 79, 'M1051_PVX_RCVD_AGNCY': 30, 'M1056_PVX_RSN_NOT_RCVD_AGNCY': 76, 'M1060_HEIGHT_A': 88, 'M1060_WEIGHT_B': 71, 'M1200_VISION': 118, 'M1242_PAIN_FREQ_ACTVTY_MVMT': 69, 'M1306_UNHLD_STG2_PRSR_ULCR': 22, 'M1307_OLDST_STG2_AT_DSCHRG': 43, 'M1307_OLDST_STG2_ONST_DT': 6, 'M1311_NBR_PRSULC_STG2_A1': 24, 'M1311_NBR_PRSULC_STG3_B1': 101, 'M1311_NBR_PRSULC_STG4_C1': 47, 'M1311_NBR_ULC_SOCROC_STG2_A2': 23, 'M1311_NBR_ULC_SOCROC_STG3_B2': 10, 'M1311_NBR_ULC_SOCROC_STG4_C2': 3, 'M1311_NSTG_CVRG_E1': 98, 'M1311_NSTG_CVRG_SOCROC_E2': 8, 'M1311_NSTG_DEEP_TSUE_F1': 25, 'M1311_NSTG_DEEP_TSUE_SOCROC_F2': 2, 'M1311_NSTG_DRSG_D1': 107, 'M1311_NSTG_DRSG_SOCROC_D2': 7, 'M1324_STG_PRBLM_ULCER': 87, 'M1330_STAS_ULCR_PRSNT': 13, 'M1332_NBR_STAS_ULCR': 14, 'M1334_STUS_PRBLM_STAS_ULCR': 50, 'M1340_SRGCL_WND_PRSNT': 33, 'M1342_STUS_PRBLM_SRGCL_WND': 66, 'M1400_WHEN_DYSPNEIC': 63, 'M1600_UTI': 1, 'M1610_UR_INCONT': 104, 'M1620_BWL_INCONT': 27, 'M1630_OSTOMY': 59, 'M1700_COG_FUNCTION': 78, 'M1710_WHEN_CONFUSED': 90, 'M1720_WHEN_ANXIOUS': 51, 'M1730_PHQ2_DPRSN': 84, 'M1730_PHQ2_LACK_INTRST': 77, 'M1730_STDZ_DPRSN_SCRNG': 20, 'M1740_BD_DELUSIONS': 19, 'M1740_BD_IMP_DECISN': 74, 'M1740_BD_MEM_DEFICIT': 75, 'M1740_BD_NONE': 102, 'M1740_BD_PHYSICAL': 21, 'M1740_BD_SOC_INAPPRO': 15, 'M1740_BD_VERBAL': 31, 'M1745_BEH_PROB_FREQ': 94, 'M1800_CRNT_GROOMING': 1, 'M1810_CRNT_DRESS_UPPER': 1, 'M1820_CRNT_DRESS_LOWER': 85, 'M1830_CRNT_BATHG': 52, 'M1840_CRNT_TOILTG': 92, 'M1845_CRNT_TOILTG_HYGN': 1, 'M1850_CRNT_TRNSFRNG': 26, 'M1860_CRNT_AMBLTN': 72, 'M1870_CRNT_FEEDING': 37, 'M1910_MLT_FCTR_FALL_RISK_ASMT': 4, 'M2001_DRUG_RGMN_RVW': 81, 'M2003_MDCTN_FLWP': 11, 'M2005_MDCTN_INTRVTN': 60, 'M2010_HIGH_RISK_DRUG_EDCTN': 99, 'M2016_DRUG_EDCTN_INTRVTN': 45, 'M2020_CRNT_MGMT_ORAL_MDCTN': 1, 'M2030_CRNT_MGMT_INJCTN_MDCTN': 65, 'M2102_CARE_TYPE_SRC_ADL': 40, 'M2102_CARE_TYPE_SRC_MDCTN': 29, 'M2102_CARE_TYPE_SRC_PRCDR': 67, 'M2102_CARE_TYPE_SRC_SPRVSN': 62, 'M2200_THER_NEED_NA': 106, 'M2301_EMER_USE_AFTR_LAST_ASMT': 57, 'M2310_ECR_HYPOGLYC': 93, 'M2310_ECR_MEDICATION': 95, 'M2310_ECR_OTHER': 64, 'M2310_ECR_UNKNOWN': 96, 'M2401_INTRVTN_SMRY_DBTS_FT': 39, 'M2401_INTRVTN_SMRY_DPRSN': 38, 'M2401_INTRVTN_SMRY_FALL_PRVNT': 1, 'M2401_INTRVTN_SMRY_PAIN_MNTR': 56, 'M2401_INTRVTN_SMRY_PRSULC_PRVN': 70, 'M2401_INTRVTN_SMRY_PRSULC_WET': 17, 'M2410_INPAT_FACILITY': 12, 'M2420_DSCHRG_DISP': 1}
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(X.columns[rfe.support_])
# Out:
# Index(['epi_AdmitType', 'M1000_DC_NONE_14_DA', 'M1033_HOSP_RISK_WEIGHT_LOSS',
#        'M1600_UTI', 'M1800_CRNT_GROOMING', 'M1810_CRNT_DRESS_UPPER',
#        'M1845_CRNT_TOILTG_HYGN', 'M2020_CRNT_MGMT_ORAL_MDCTN',
#        'M2401_INTRVTN_SMRY_FALL_PRVNT', 'M2420_DSCHRG_DISP'],
#       dtype='object')

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test, rfe.predict(X_test))

# %%
print("{0:.1%} accuracy on test set.".format(acc))
# Out:
# 96.1% accuracy on test set.

# %% [markdown]
# ### Quick Evaluation using RFE Feature Selection: RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, y_train)

# Calculate the accuracy
acc = accuracy_score(y_test, rf.predict(X_test))

# Print the importances per feature
# print(dict(zip(X.columns, rf.feature_importances_.round(2))))

# Print accuracy
print("{0:.1%} accuracy on test set.".format(acc))
# Out:
# C:\Users\sjyhl\AppData\Local\Temp/ipykernel_11680/3044802180.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# 99.4% accuracy on test set.

# %%
mask = rf.feature_importances_ > 0.03

# Apply the mask to the feature dataset X
reduced_X = X.loc[:, mask]

# Prints out the selected column names
print(reduced_X.columns)
# Out:
# Index(['year_born', 'epi_AdmitType', 'icd_code', 'RoughAge',
#        'M0906_DC_TRAN_DTH_DT'],
#       dtype='object')

# %% [markdown]
# ### Check regularizing strength (LASSO)

# %%
from sklearn.linear_model import Lasso
alpha_list = [10, 1, 0.5, 0.1, 0.01, 0.001, 0.0001, 0.00001]
max_r = 0
max_alpha = 0
for alpha in alpha_list:
    
    la = Lasso(alpha=alpha, random_state=0)

    
    la.fit(X_train, y_train)
    r_squared = la.score(X_test, y_test)
    n_ignored_features = sum(la.coef_ == 0)

    
    print("The model can predict {0:.1%} of the variance in the test set.".format(r_squared))
    print("{} out of {} features were ignored.".format(n_ignored_features, len(la.coef_)))
    
    if r_squared > 0.98:
        max_r = r_squared
        max_alpha = alpha
        break
print("Max R-squared: {}, alpha: {}".format(max_r, max_alpha))
# Out:
# The model can predict 1.8% of the variance in the test set.
# 127 out of 128 features were ignored.
# The model can predict 9.6% of the variance in the test set.
# 125 out of 128 features were ignored.
# The model can predict 10.2% of the variance in the test set.
# 125 out of 128 features were ignored.
# The model can predict 11.0% of the variance in the test set.
# 123 out of 128 features were ignored.
# The model can predict 19.6% of the variance in the test set.
# 113 out of 128 features were ignored.
# The model can predict 21.5% of the variance in the test set.
# 86 out of 128 features were ignored.
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.207e+02, tolerance: 3.328e-02
#   model = cd_fast.enet_coordinate_descent(
# The model can predict 22.0% of the variance in the test set.
# 18 out of 128 features were ignored.
# The model can predict 21.6% of the variance in the test set.
# 2 out of 128 features were ignored.
# Max R-squared: 0, alpha: 0
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.272e+02, tolerance: 3.328e-02
#   model = cd_fast.enet_coordinate_descent(

# %%
alphas = np.linspace(0.01,500,100)
lasso = Lasso(max_iter=10000)
coefs = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    coefs.append(lasso.coef_)

ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('Standardized Coefficients')
plt.title('Lasso coefficients as a function of alpha');

# %% [markdown]
# ### LASSO CV - Model w/ best alpha

# %%
from sklearn.linear_model import LassoCV

# Lasso with 5 fold cross-validation
model = LassoCV(cv=5, random_state=0, max_iter=10000)

# Fit model
model.fit(X_train, y_train)

LassoCV(cv=5, max_iter=10000, random_state=0)

model.alpha_
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1572: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.011280550615976699

# %% [markdown]
# ### Set best alpha and get coefficients

# %%
lasso_best = Lasso(alpha=model.alpha_)
lasso_best.fit(X_train, y_train)
print([coef for coef in list(zip(lasso_best.coef_, X)) if abs(coef[0]) > 0])
# Out:
# [(-0.0009127603833497757, 'year_born'), (0.005194601985186305, 'pa_race'), (-0.0022145544233238596, 'pa_maritalstatus'), (-0.036037058763925434, 'epi_AdmitType'), (0.00015623103941018394, 'epi_weight'), (-0.0005661480077865416, 'ceo_HIPPS'), (0.0026380322094490746, 'ceo_HHRG'), (-1.2702720153512071e-05, 'icd_code'), (-0.0030878851465404858, 'DiagnosisCategory'), (-0.0005978478537886747, 'RoughAge'), (0.00022276946142691558, 'M0906_DC_TRAN_DTH_DT'), (0.0006159670680873082, 'M1046_INFLNZ_RECD_CRNT_SEASON'), (-8.790738389294052e-05, 'M1060_WEIGHT_B'), (0.003620509613602093, 'M1400_WHEN_DYSPNEIC'), (0.004782789431287642, 'M1850_CRNT_TRNSFRNG')]

# %%
[coef[1] for coef in list(zip(lasso_best.coef_, X)) if abs(coef[0]) > 0]
# Out:
# ['year_born',
#  'pa_race',
#  'pa_maritalstatus',
#  'epi_AdmitType',
#  'epi_weight',
#  'ceo_HIPPS',
#  'ceo_HHRG',
#  'icd_code',
#  'DiagnosisCategory',
#  'RoughAge',
#  'M0906_DC_TRAN_DTH_DT',
#  'M1046_INFLNZ_RECD_CRNT_SEASON',
#  'M1060_WEIGHT_B',
#  'M1400_WHEN_DYSPNEIC',
#  'M1850_CRNT_TRNSFRNG']

# %% [markdown]
# ### Misc Facts about data

# %% [markdown]
# #### some columns have '-' as category

# %%
df.M1028_ACTV_DIAG_DM.unique()
# Out:
# ['imputed', 'NO', 'YES', '-']
# Categories (4, object): ['-', 'NO', 'YES', 'imputed']

# %%
df.M1028_ACTV_DIAG_PVD_PAD.unique()
# Out:
# ['imputed', 'NO', 'YES', '-']
# Categories (4, object): ['-', 'NO', 'YES', 'imputed']

# %%
df.M2003_MDCTN_FLWP.unique()
# Out:
# ['imputed', '0 - NO', '1 - YES', '-']
# Categories (4, object): ['-', '0 - NO', '1 - YES', 'imputed']

# %%
# fix above. make '-' into 'imputed'
df.loc[df["M1028_ACTV_DIAG_DM"] == "-", "M1028_ACTV_DIAG_DM"] = 'imputed'
df.loc[df["M1028_ACTV_DIAG_PVD_PAD"] == "-", "M1028_ACTV_DIAG_PVD_PAD"] ='imputed'
df.loc[df["M2003_MDCTN_FLWP"] == "-", "M2003_MDCTN_FLWP"] = 'imputed'

# %% [markdown]
# #### some columns represent single variable type, some are over multiple columns

# %%
list(df.M1400_WHEN_DYSPNEIC.unique())
# Out:
# ['2 - WITH MODERATE EXERTION (FOR EXAMPLE, WHILE DRESSING, USING COMMODE OR BEDPAN, WALKING DISTANCES LESS THAN 20 FEET)',
#  'imputed',
#  '3 - WITH MINIMAL EXERTION (FOR EXAMPLE, WHILE EATING, TALKING, OR PERFORMING OTHER ADLS) OR WITH AGITATION',
#  '4 - AT REST (DURING DAY OR NIGHT)',
#  '0 - PATIENT IS NOT SHORT OF BREATH ',
#  '1 - WHEN WALKING MORE THAN 20 FEET, CLIMBING STAIRS ']

# %%
list(df.M1033_HOSP_RISK_MLTPL_HOSPZTN.unique())
# Out:
# ['imputed', 'YES', 'NO']

# %% [markdown]
# ### Feature Evaluation using Regression

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

names=pd.DataFrame(X_train.columns)

lin_reg = LogisticRegression()

rfe_mod = RFE(lin_reg, n_features_to_select=5, step=1)

fit_model = rfe_mod.fit(X_train, y_train)
fit_model.support_
fit_model.ranking_
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([ 87,  37,  85,  59,   1,  94, 108,  88,  66, 119,  53,  14,  63,
#        114,  39,  41,  60,  51,  49, 124, 105,  73,  23,  40,  33,   2,
#         46,  47,  21,  10,  96, 118, 122, 115, 120, 110, 102,  78,  91,
#        116,  54,  58, 113, 121, 117,   5,  84,  35,  81,  93,  76, 123,
#         74,  27,  48,  11,  29, 106,  52,  28,  15,   8, 103,  13,  30,
#          7, 112,  12,  92,  18,  19,  55,  38,  71,  68,   3, 109,  32,
#         64,  83,  95,  56,  89,  82,  25,  24,  79,  80, 107,  26,  20,
#         36,  99,   6,   1,  90,  57,  97,   1,  31,  77,  42,   9,  86,
#         16,  65, 104,  50,   1,  70,  45,  34,  72,  67, 111,  62,  98,
#        100,  69, 101,  44,  43,   1,  61,  75,  22,  17,   4])

# %%
selected_features = []
for i, rank in enumerate(fit_model.ranking_):
    feature = fit_model.feature_names_in_[i]
    selected_features.append({'feature': feature, 'rank': rank})
selected_features
# Out:
# [{'feature': 'year_born', 'rank': 87},
#  {'feature': 'pa_race', 'rank': 37},
#  {'feature': 'pa_gender', 'rank': 85},
#  {'feature': 'pa_maritalstatus', 'rank': 59},
#  {'feature': 'epi_AdmitType', 'rank': 1},
#  {'feature': 'epi_height', 'rank': 94},
#  {'feature': 'epi_weight', 'rank': 108},
#  {'feature': 'ceo_HIPPS', 'rank': 88},
#  {'feature': 'ceo_HHRG', 'rank': 66},
#  {'feature': 'icd_code', 'rank': 119},
#  {'feature': 'DiagnosisCategory', 'rank': 53},
#  {'feature': 'RoughAge', 'rank': 14},
#  {'feature': 'M0100_ASSMT_REASON', 'rank': 63},
#  {'feature': 'M0110_EPISODE_TIMING', 'rank': 114},
#  {'feature': 'M0140_ETHNIC_AI_AN', 'rank': 39},
#  {'feature': 'M0140_ETHNIC_ASIAN', 'rank': 41},
#  {'feature': 'M0140_ETHNIC_BLACK', 'rank': 60},
#  {'feature': 'M0140_ETHNIC_HISP', 'rank': 51},
#  {'feature': 'M0140_ETHNIC_NH_PI', 'rank': 49},
#  {'feature': 'M0140_ETHNIC_WHITE', 'rank': 124},
#  {'feature': 'M0906_DC_TRAN_DTH_DT', 'rank': 105},
#  {'feature': 'M1000_DC_IPPS_14_DA', 'rank': 73},
#  {'feature': 'M1000_DC_IRF_14_DA', 'rank': 23},
#  {'feature': 'M1000_DC_LTC_14_DA', 'rank': 40},
#  {'feature': 'M1000_DC_LTCH_14_DA', 'rank': 33},
#  {'feature': 'M1000_DC_NONE_14_DA', 'rank': 2},
#  {'feature': 'M1000_DC_OTH_14_DA', 'rank': 46},
#  {'feature': 'M1000_DC_PSYCH_14_DA', 'rank': 47},
#  {'feature': 'M1000_DC_SNF_14_DA', 'rank': 21},
#  {'feature': 'M1028_ACTV_DIAG_DM', 'rank': 10},
#  {'feature': 'M1028_ACTV_DIAG_NOA', 'rank': 96},
#  {'feature': 'M1028_ACTV_DIAG_PVD_PAD', 'rank': 118},
#  {'feature': 'M1030_THH_ENT_NUTRITION', 'rank': 122},
#  {'feature': 'M1030_THH_IV_INFUSION', 'rank': 115},
#  {'feature': 'M1030_THH_NONE_ABOVE', 'rank': 120},
#  {'feature': 'M1030_THH_PAR_NUTRITION', 'rank': 110},
#  {'feature': 'M1033_HOSP_RISK_5PLUS_MDCTN', 'rank': 102},
#  {'feature': 'M1033_HOSP_RISK_COMPLIANCE', 'rank': 78},
#  {'feature': 'M1033_HOSP_RISK_CRNT_EXHSTN', 'rank': 91},
#  {'feature': 'M1033_HOSP_RISK_HSTRY_FALLS', 'rank': 116},
#  {'feature': 'M1033_HOSP_RISK_MLTPL_ED_VISIT', 'rank': 54},
#  {'feature': 'M1033_HOSP_RISK_MLTPL_HOSPZTN', 'rank': 58},
#  {'feature': 'M1033_HOSP_RISK_MNTL_BHV_DCLN', 'rank': 113},
#  {'feature': 'M1033_HOSP_RISK_NONE_ABOVE', 'rank': 121},
#  {'feature': 'M1033_HOSP_RISK_OTHR_RISK', 'rank': 117},
#  {'feature': 'M1033_HOSP_RISK_WEIGHT_LOSS', 'rank': 5},
#  {'feature': 'M1046_INFLNZ_RECD_CRNT_SEASON', 'rank': 84},
#  {'feature': 'M1051_PVX_RCVD_AGNCY', 'rank': 35},
#  {'feature': 'M1056_PVX_RSN_NOT_RCVD_AGNCY', 'rank': 81},
#  {'feature': 'M1060_HEIGHT_A', 'rank': 93},
#  {'feature': 'M1060_WEIGHT_B', 'rank': 76},
#  {'feature': 'M1200_VISION', 'rank': 123},
#  {'feature': 'M1242_PAIN_FREQ_ACTVTY_MVMT', 'rank': 74},
#  {'feature': 'M1306_UNHLD_STG2_PRSR_ULCR', 'rank': 27},
#  {'feature': 'M1307_OLDST_STG2_AT_DSCHRG', 'rank': 48},
#  {'feature': 'M1307_OLDST_STG2_ONST_DT', 'rank': 11},
#  {'feature': 'M1311_NBR_PRSULC_STG2_A1', 'rank': 29},
#  {'feature': 'M1311_NBR_PRSULC_STG3_B1', 'rank': 106},
#  {'feature': 'M1311_NBR_PRSULC_STG4_C1', 'rank': 52},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG2_A2', 'rank': 28},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG3_B2', 'rank': 15},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG4_C2', 'rank': 8},
#  {'feature': 'M1311_NSTG_CVRG_E1', 'rank': 103},
#  {'feature': 'M1311_NSTG_CVRG_SOCROC_E2', 'rank': 13},
#  {'feature': 'M1311_NSTG_DEEP_TSUE_F1', 'rank': 30},
#  {'feature': 'M1311_NSTG_DEEP_TSUE_SOCROC_F2', 'rank': 7},
#  {'feature': 'M1311_NSTG_DRSG_D1', 'rank': 112},
#  {'feature': 'M1311_NSTG_DRSG_SOCROC_D2', 'rank': 12},
#  {'feature': 'M1324_STG_PRBLM_ULCER', 'rank': 92},
#  {'feature': 'M1330_STAS_ULCR_PRSNT', 'rank': 18},
#  {'feature': 'M1332_NBR_STAS_ULCR', 'rank': 19},
#  {'feature': 'M1334_STUS_PRBLM_STAS_ULCR', 'rank': 55},
#  {'feature': 'M1340_SRGCL_WND_PRSNT', 'rank': 38},
#  {'feature': 'M1342_STUS_PRBLM_SRGCL_WND', 'rank': 71},
#  {'feature': 'M1400_WHEN_DYSPNEIC', 'rank': 68},
#  {'feature': 'M1600_UTI', 'rank': 3},
#  {'feature': 'M1610_UR_INCONT', 'rank': 109},
#  {'feature': 'M1620_BWL_INCONT', 'rank': 32},
#  {'feature': 'M1630_OSTOMY', 'rank': 64},
#  {'feature': 'M1700_COG_FUNCTION', 'rank': 83},
#  {'feature': 'M1710_WHEN_CONFUSED', 'rank': 95},
#  {'feature': 'M1720_WHEN_ANXIOUS', 'rank': 56},
#  {'feature': 'M1730_PHQ2_DPRSN', 'rank': 89},
#  {'feature': 'M1730_PHQ2_LACK_INTRST', 'rank': 82},
#  {'feature': 'M1730_STDZ_DPRSN_SCRNG', 'rank': 25},
#  {'feature': 'M1740_BD_DELUSIONS', 'rank': 24},
#  {'feature': 'M1740_BD_IMP_DECISN', 'rank': 79},
#  {'feature': 'M1740_BD_MEM_DEFICIT', 'rank': 80},
#  {'feature': 'M1740_BD_NONE', 'rank': 107},
#  {'feature': 'M1740_BD_PHYSICAL', 'rank': 26},
#  {'feature': 'M1740_BD_SOC_INAPPRO', 'rank': 20},
#  {'feature': 'M1740_BD_VERBAL', 'rank': 36},
#  {'feature': 'M1745_BEH_PROB_FREQ', 'rank': 99},
#  {'feature': 'M1800_CRNT_GROOMING', 'rank': 6},
#  {'feature': 'M1810_CRNT_DRESS_UPPER', 'rank': 1},
#  {'feature': 'M1820_CRNT_DRESS_LOWER', 'rank': 90},
#  {'feature': 'M1830_CRNT_BATHG', 'rank': 57},
#  {'feature': 'M1840_CRNT_TOILTG', 'rank': 97},
#  {'feature': 'M1845_CRNT_TOILTG_HYGN', 'rank': 1},
#  {'feature': 'M1850_CRNT_TRNSFRNG', 'rank': 31},
#  {'feature': 'M1860_CRNT_AMBLTN', 'rank': 77},
#  {'feature': 'M1870_CRNT_FEEDING', 'rank': 42},
#  {'feature': 'M1910_MLT_FCTR_FALL_RISK_ASMT', 'rank': 9},
#  {'feature': 'M2001_DRUG_RGMN_RVW', 'rank': 86},
#  {'feature': 'M2003_MDCTN_FLWP', 'rank': 16},
#  {'feature': 'M2005_MDCTN_INTRVTN', 'rank': 65},
#  {'feature': 'M2010_HIGH_RISK_DRUG_EDCTN', 'rank': 104},
#  {'feature': 'M2016_DRUG_EDCTN_INTRVTN', 'rank': 50},
#  {'feature': 'M2020_CRNT_MGMT_ORAL_MDCTN', 'rank': 1},
#  {'feature': 'M2030_CRNT_MGMT_INJCTN_MDCTN', 'rank': 70},
#  {'feature': 'M2102_CARE_TYPE_SRC_ADL', 'rank': 45},
#  {'feature': 'M2102_CARE_TYPE_SRC_MDCTN', 'rank': 34},
#  {'feature': 'M2102_CARE_TYPE_SRC_PRCDR', 'rank': 72},
#  {'feature': 'M2102_CARE_TYPE_SRC_SPRVSN', 'rank': 67},
#  {'feature': 'M2200_THER_NEED_NA', 'rank': 111},
#  {'feature': 'M2301_EMER_USE_AFTR_LAST_ASMT', 'rank': 62},
#  {'feature': 'M2310_ECR_HYPOGLYC', 'rank': 98},
#  {'feature': 'M2310_ECR_MEDICATION', 'rank': 100},
#  {'feature': 'M2310_ECR_OTHER', 'rank': 69},
#  {'feature': 'M2310_ECR_UNKNOWN', 'rank': 101},
#  {'feature': 'M2401_INTRVTN_SMRY_DBTS_FT', 'rank': 44},
#  {'feature': 'M2401_INTRVTN_SMRY_DPRSN', 'rank': 43},
#  {'feature': 'M2401_INTRVTN_SMRY_FALL_PRVNT', 'rank': 1},
#  {'feature': 'M2401_INTRVTN_SMRY_PAIN_MNTR', 'rank': 61},
#  {'feature': 'M2401_INTRVTN_SMRY_PRSULC_PRVN', 'rank': 75},
#  {'feature': 'M2401_INTRVTN_SMRY_PRSULC_WET', 'rank': 22},
#  {'feature': 'M2410_INPAT_FACILITY', 'rank': 17},
#  {'feature': 'M2420_DSCHRG_DISP', 'rank': 4}]

# %%
sorted(selected_features, key=lambda i: i['rank'])
# Out:
# [{'feature': 'epi_AdmitType', 'rank': 1},
#  {'feature': 'M1810_CRNT_DRESS_UPPER', 'rank': 1},
#  {'feature': 'M1845_CRNT_TOILTG_HYGN', 'rank': 1},
#  {'feature': 'M2020_CRNT_MGMT_ORAL_MDCTN', 'rank': 1},
#  {'feature': 'M2401_INTRVTN_SMRY_FALL_PRVNT', 'rank': 1},
#  {'feature': 'M1000_DC_NONE_14_DA', 'rank': 2},
#  {'feature': 'M1600_UTI', 'rank': 3},
#  {'feature': 'M2420_DSCHRG_DISP', 'rank': 4},
#  {'feature': 'M1033_HOSP_RISK_WEIGHT_LOSS', 'rank': 5},
#  {'feature': 'M1800_CRNT_GROOMING', 'rank': 6},
#  {'feature': 'M1311_NSTG_DEEP_TSUE_SOCROC_F2', 'rank': 7},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG4_C2', 'rank': 8},
#  {'feature': 'M1910_MLT_FCTR_FALL_RISK_ASMT', 'rank': 9},
#  {'feature': 'M1028_ACTV_DIAG_DM', 'rank': 10},
#  {'feature': 'M1307_OLDST_STG2_ONST_DT', 'rank': 11},
#  {'feature': 'M1311_NSTG_DRSG_SOCROC_D2', 'rank': 12},
#  {'feature': 'M1311_NSTG_CVRG_SOCROC_E2', 'rank': 13},
#  {'feature': 'RoughAge', 'rank': 14},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG3_B2', 'rank': 15},
#  {'feature': 'M2003_MDCTN_FLWP', 'rank': 16},
#  {'feature': 'M2410_INPAT_FACILITY', 'rank': 17},
#  {'feature': 'M1330_STAS_ULCR_PRSNT', 'rank': 18},
#  {'feature': 'M1332_NBR_STAS_ULCR', 'rank': 19},
#  {'feature': 'M1740_BD_SOC_INAPPRO', 'rank': 20},
#  {'feature': 'M1000_DC_SNF_14_DA', 'rank': 21},
#  {'feature': 'M2401_INTRVTN_SMRY_PRSULC_WET', 'rank': 22},
#  {'feature': 'M1000_DC_IRF_14_DA', 'rank': 23},
#  {'feature': 'M1740_BD_DELUSIONS', 'rank': 24},
#  {'feature': 'M1730_STDZ_DPRSN_SCRNG', 'rank': 25},
#  {'feature': 'M1740_BD_PHYSICAL', 'rank': 26},
#  {'feature': 'M1306_UNHLD_STG2_PRSR_ULCR', 'rank': 27},
#  {'feature': 'M1311_NBR_ULC_SOCROC_STG2_A2', 'rank': 28},
#  {'feature': 'M1311_NBR_PRSULC_STG2_A1', 'rank': 29},
#  {'feature': 'M1311_NSTG_DEEP_TSUE_F1', 'rank': 30},
#  {'feature': 'M1850_CRNT_TRNSFRNG', 'rank': 31},
#  {'feature': 'M1620_BWL_INCONT', 'rank': 32},
#  {'feature': 'M1000_DC_LTCH_14_DA', 'rank': 33},
#  {'feature': 'M2102_CARE_TYPE_SRC_MDCTN', 'rank': 34},
#  {'feature': 'M1051_PVX_RCVD_AGNCY', 'rank': 35},
#  {'feature': 'M1740_BD_VERBAL', 'rank': 36},
#  {'feature': 'pa_race', 'rank': 37},
#  {'feature': 'M1340_SRGCL_WND_PRSNT', 'rank': 38},
#  {'feature': 'M0140_ETHNIC_AI_AN', 'rank': 39},
#  {'feature': 'M1000_DC_LTC_14_DA', 'rank': 40},
#  {'feature': 'M0140_ETHNIC_ASIAN', 'rank': 41},
#  {'feature': 'M1870_CRNT_FEEDING', 'rank': 42},
#  {'feature': 'M2401_INTRVTN_SMRY_DPRSN', 'rank': 43},
#  {'feature': 'M2401_INTRVTN_SMRY_DBTS_FT', 'rank': 44},
#  {'feature': 'M2102_CARE_TYPE_SRC_ADL', 'rank': 45},
#  {'feature': 'M1000_DC_OTH_14_DA', 'rank': 46},
#  {'feature': 'M1000_DC_PSYCH_14_DA', 'rank': 47},
#  {'feature': 'M1307_OLDST_STG2_AT_DSCHRG', 'rank': 48},
#  {'feature': 'M0140_ETHNIC_NH_PI', 'rank': 49},
#  {'feature': 'M2016_DRUG_EDCTN_INTRVTN', 'rank': 50},
#  {'feature': 'M0140_ETHNIC_HISP', 'rank': 51},
#  {'feature': 'M1311_NBR_PRSULC_STG4_C1', 'rank': 52},
#  {'feature': 'DiagnosisCategory', 'rank': 53},
#  {'feature': 'M1033_HOSP_RISK_MLTPL_ED_VISIT', 'rank': 54},
#  {'feature': 'M1334_STUS_PRBLM_STAS_ULCR', 'rank': 55},
#  {'feature': 'M1720_WHEN_ANXIOUS', 'rank': 56},
#  {'feature': 'M1830_CRNT_BATHG', 'rank': 57},
#  {'feature': 'M1033_HOSP_RISK_MLTPL_HOSPZTN', 'rank': 58},
#  {'feature': 'pa_maritalstatus', 'rank': 59},
#  {'feature': 'M0140_ETHNIC_BLACK', 'rank': 60},
#  {'feature': 'M2401_INTRVTN_SMRY_PAIN_MNTR', 'rank': 61},
#  {'feature': 'M2301_EMER_USE_AFTR_LAST_ASMT', 'rank': 62},
#  {'feature': 'M0100_ASSMT_REASON', 'rank': 63},
#  {'feature': 'M1630_OSTOMY', 'rank': 64},
#  {'feature': 'M2005_MDCTN_INTRVTN', 'rank': 65},
#  {'feature': 'ceo_HHRG', 'rank': 66},
#  {'feature': 'M2102_CARE_TYPE_SRC_SPRVSN', 'rank': 67},
#  {'feature': 'M1400_WHEN_DYSPNEIC', 'rank': 68},
#  {'feature': 'M2310_ECR_OTHER', 'rank': 69},
#  {'feature': 'M2030_CRNT_MGMT_INJCTN_MDCTN', 'rank': 70},
#  {'feature': 'M1342_STUS_PRBLM_SRGCL_WND', 'rank': 71},
#  {'feature': 'M2102_CARE_TYPE_SRC_PRCDR', 'rank': 72},
#  {'feature': 'M1000_DC_IPPS_14_DA', 'rank': 73},
#  {'feature': 'M1242_PAIN_FREQ_ACTVTY_MVMT', 'rank': 74},
#  {'feature': 'M2401_INTRVTN_SMRY_PRSULC_PRVN', 'rank': 75},
#  {'feature': 'M1060_WEIGHT_B', 'rank': 76},
#  {'feature': 'M1860_CRNT_AMBLTN', 'rank': 77},
#  {'feature': 'M1033_HOSP_RISK_COMPLIANCE', 'rank': 78},
#  {'feature': 'M1740_BD_IMP_DECISN', 'rank': 79},
#  {'feature': 'M1740_BD_MEM_DEFICIT', 'rank': 80},
#  {'feature': 'M1056_PVX_RSN_NOT_RCVD_AGNCY', 'rank': 81},
#  {'feature': 'M1730_PHQ2_LACK_INTRST', 'rank': 82},
#  {'feature': 'M1700_COG_FUNCTION', 'rank': 83},
#  {'feature': 'M1046_INFLNZ_RECD_CRNT_SEASON', 'rank': 84},
#  {'feature': 'pa_gender', 'rank': 85},
#  {'feature': 'M2001_DRUG_RGMN_RVW', 'rank': 86},
#  {'feature': 'year_born', 'rank': 87},
#  {'feature': 'ceo_HIPPS', 'rank': 88},
#  {'feature': 'M1730_PHQ2_DPRSN', 'rank': 89},
#  {'feature': 'M1820_CRNT_DRESS_LOWER', 'rank': 90},
#  {'feature': 'M1033_HOSP_RISK_CRNT_EXHSTN', 'rank': 91},
#  {'feature': 'M1324_STG_PRBLM_ULCER', 'rank': 92},
#  {'feature': 'M1060_HEIGHT_A', 'rank': 93},
#  {'feature': 'epi_height', 'rank': 94},
#  {'feature': 'M1710_WHEN_CONFUSED', 'rank': 95},
#  {'feature': 'M1028_ACTV_DIAG_NOA', 'rank': 96},
#  {'feature': 'M1840_CRNT_TOILTG', 'rank': 97},
#  {'feature': 'M2310_ECR_HYPOGLYC', 'rank': 98},
#  {'feature': 'M1745_BEH_PROB_FREQ', 'rank': 99},
#  {'feature': 'M2310_ECR_MEDICATION', 'rank': 100},
#  {'feature': 'M2310_ECR_UNKNOWN', 'rank': 101},
#  {'feature': 'M1033_HOSP_RISK_5PLUS_MDCTN', 'rank': 102},
#  {'feature': 'M1311_NSTG_CVRG_E1', 'rank': 103},
#  {'feature': 'M2010_HIGH_RISK_DRUG_EDCTN', 'rank': 104},
#  {'feature': 'M0906_DC_TRAN_DTH_DT', 'rank': 105},
#  {'feature': 'M1311_NBR_PRSULC_STG3_B1', 'rank': 106},
#  {'feature': 'M1740_BD_NONE', 'rank': 107},
#  {'feature': 'epi_weight', 'rank': 108},
#  {'feature': 'M1610_UR_INCONT', 'rank': 109},
#  {'feature': 'M1030_THH_PAR_NUTRITION', 'rank': 110},
#  {'feature': 'M2200_THER_NEED_NA', 'rank': 111},
#  {'feature': 'M1311_NSTG_DRSG_D1', 'rank': 112},
#  {'feature': 'M1033_HOSP_RISK_MNTL_BHV_DCLN', 'rank': 113},
#  {'feature': 'M0110_EPISODE_TIMING', 'rank': 114},
#  {'feature': 'M1030_THH_IV_INFUSION', 'rank': 115},
#  {'feature': 'M1033_HOSP_RISK_HSTRY_FALLS', 'rank': 116},
#  {'feature': 'M1033_HOSP_RISK_OTHR_RISK', 'rank': 117},
#  {'feature': 'M1028_ACTV_DIAG_PVD_PAD', 'rank': 118},
#  {'feature': 'icd_code', 'rank': 119},
#  {'feature': 'M1030_THH_NONE_ABOVE', 'rank': 120},
#  {'feature': 'M1033_HOSP_RISK_NONE_ABOVE', 'rank': 121},
#  {'feature': 'M1030_THH_ENT_NUTRITION', 'rank': 122},
#  {'feature': 'M1200_VISION', 'rank': 123},
#  {'feature': 'M0140_ETHNIC_WHITE', 'rank': 124}]

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(X_train, y_train)


model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(X_train)
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
## !pip install statsmodels

# %%
import statsmodels.api as sm
def get_stats():
    #x = df[df.columns[:-1]]
    results = sm.OLS(y_train, X_train).fit()
    print(results.summary())
get_stats()
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       patient_deceased   R-squared (uncentered):                   0.973
# Model:                            OLS   Adj. R-squared (uncentered):              0.972
# Method:                 Least Squares   F-statistic:                              2661.
# Date:                Tue, 19 Apr 2022   Prob (F-statistic):                        0.00
# Time:                        13:07:32   Log-Likelihood:                          3866.7
# No. Observations:                9735   AIC:                                     -7477.
# Df Residuals:                    9607   BIC:                                     -6558.
# Df Model:                         128
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# year_born                         -0.0010      0.000     -6.657      0.000      -0.001      -0.001
# pa_race                            0.0124      0.001     10.083      0.000       0.010       0.015
# pa_gender                         -0.0036      0.004     -1.031      0.303      -0.011       0.003
# pa_maritalstatus                  -0.0058      0.001     -7.962      0.000      -0.007      -0.004
# epi_AdmitType                     -0.0501      0.002    -22.373      0.000      -0.054      -0.046
# epi_height                        -0.0003      0.000     -0.843      0.399      -0.001       0.000
# epi_weight                         0.0003      0.000      2.471      0.014    5.68e-05       0.000
# ceo_HIPPS                         -0.0006    6.5e-05     -8.966      0.000      -0.001      -0.000
# ceo_HHRG                           0.0029      0.000      6.530      0.000       0.002       0.004
# icd_code                        1.022e-05   1.15e-05      0.888      0.375   -1.23e-05    3.28e-05
# DiagnosisCategory                 -0.0042      0.001     -4.993      0.000      -0.006      -0.003
# RoughAge                          -0.0010      0.000     -6.151      0.000      -0.001      -0.001
# M0100_ASSMT_REASON                -0.0168      0.005     -3.118      0.002      -0.027      -0.006
# M0110_EPISODE_TIMING           -2.136e-05      0.003     -0.008      0.994      -0.006       0.005
# M0140_ETHNIC_AI_AN                -0.0420      0.043     -0.986      0.324      -0.126       0.042
# M0140_ETHNIC_ASIAN                 0.0122      0.049      0.248      0.804      -0.084       0.109
# M0140_ETHNIC_BLACK                -0.0042      0.038     -0.111      0.911      -0.078       0.069
# M0140_ETHNIC_HISP                 -0.0111      0.040     -0.280      0.780      -0.089       0.067
# M0140_ETHNIC_NH_PI                -0.0043      0.103     -0.041      0.967      -0.205       0.197
# M0140_ETHNIC_WHITE                -0.0036      0.037     -0.098      0.922      -0.076       0.069
# M0906_DC_TRAN_DTH_DT               0.0002   9.67e-06     21.123      0.000       0.000       0.000
# M1000_DC_IPPS_14_DA                0.0120      0.022      0.546      0.585      -0.031       0.055
# M1000_DC_IRF_14_DA                 0.0202      0.023      0.886      0.376      -0.024       0.065
# M1000_DC_LTC_14_DA                -0.0002      0.049     -0.004      0.997      -0.095       0.095
# M1000_DC_LTCH_14_DA                0.0039      0.037      0.105      0.916      -0.069       0.077
# M1000_DC_NONE_14_DA                0.0159      0.023      0.690      0.490      -0.029       0.061
# M1000_DC_OTH_14_DA                 0.1076      0.069      1.550      0.121      -0.028       0.244
# M1000_DC_PSYCH_14_DA               0.0022      0.064      0.034      0.973      -0.124       0.129
# M1000_DC_SNF_14_DA                 0.0168      0.022      0.759      0.448      -0.027       0.060
# M1028_ACTV_DIAG_DM                 0.0016      0.008      0.203      0.839      -0.014       0.017
# M1028_ACTV_DIAG_NOA               -0.0044      0.008     -0.564      0.573      -0.020       0.011
# M1028_ACTV_DIAG_PVD_PAD            0.0038      0.008      0.506      0.613      -0.011       0.019
# M1030_THH_ENT_NUTRITION            0.0473      0.018      2.603      0.009       0.012       0.083
# M1030_THH_IV_INFUSION             -0.0082      0.018     -0.450      0.653      -0.044       0.027
# M1030_THH_NONE_ABOVE               0.0130      0.017      0.769      0.442      -0.020       0.046
# M1030_THH_PAR_NUTRITION            0.0735      0.024      3.095      0.002       0.027       0.120
# M1033_HOSP_RISK_5PLUS_MDCTN       -0.0280      0.010     -2.702      0.007      -0.048      -0.008
# M1033_HOSP_RISK_COMPLIANCE         0.0094      0.005      1.724      0.085      -0.001       0.020
# M1033_HOSP_RISK_CRNT_EXHSTN        0.0046      0.005      0.912      0.362      -0.005       0.015
# M1033_HOSP_RISK_HSTRY_FALLS       -0.0078      0.005     -1.584      0.113      -0.017       0.002
# M1033_HOSP_RISK_MLTPL_ED_VISIT     0.0162      0.006      2.518      0.012       0.004       0.029
# M1033_HOSP_RISK_MLTPL_HOSPZTN      0.0109      0.007      1.675      0.094      -0.002       0.024
# M1033_HOSP_RISK_MNTL_BHV_DCLN     -0.0096      0.006     -1.631      0.103      -0.021       0.002
# M1033_HOSP_RISK_NONE_ABOVE        -0.0347      0.013     -2.696      0.007      -0.060      -0.009
# M1033_HOSP_RISK_OTHR_RISK         -0.0054      0.005     -1.111      0.267      -0.015       0.004
# M1033_HOSP_RISK_WEIGHT_LOSS        0.0220      0.006      3.440      0.001       0.009       0.035
# M1046_INFLNZ_RECD_CRNT_SEASON      0.0052      0.001      4.851      0.000       0.003       0.007
# M1051_PVX_RCVD_AGNCY               0.0116      0.012      0.946      0.344      -0.012       0.036
# M1056_PVX_RSN_NOT_RCVD_AGNCY      -0.0006      0.004     -0.147      0.883      -0.008       0.007
# M1060_HEIGHT_A                     0.0003      0.000      0.854      0.393      -0.000       0.001
# M1060_WEIGHT_B                  5.472e-05   4.64e-05      1.181      0.238   -3.61e-05       0.000
# M1200_VISION                      -0.0029      0.005     -0.613      0.540      -0.012       0.006
# M1242_PAIN_FREQ_ACTVTY_MVMT       -0.0020      0.002     -1.137      0.255      -0.006       0.001
# M1306_UNHLD_STG2_PRSR_ULCR        -0.0235      0.031     -0.759      0.448      -0.084       0.037
# M1307_OLDST_STG2_AT_DSCHRG        -0.0352      0.021     -1.670      0.095      -0.076       0.006
# M1307_OLDST_STG2_ONST_DT          -0.0119      0.024     -0.488      0.626      -0.060       0.036
# M1311_NBR_PRSULC_STG2_A1           0.0040      0.004      1.056      0.291      -0.003       0.011
# M1311_NBR_PRSULC_STG3_B1           0.0026      0.005      0.497      0.619      -0.008       0.013
# M1311_NBR_PRSULC_STG4_C1          -0.0065      0.005     -1.196      0.232      -0.017       0.004
# M1311_NBR_ULC_SOCROC_STG2_A2       0.0126      0.022      0.573      0.567      -0.030       0.056
# M1311_NBR_ULC_SOCROC_STG3_B2       0.0405      0.020      2.056      0.040       0.002       0.079
# M1311_NBR_ULC_SOCROC_STG4_C2       0.1050      0.030      3.477      0.001       0.046       0.164
# M1311_NSTG_CVRG_E1                 0.0146      0.007      2.162      0.031       0.001       0.028
# M1311_NSTG_CVRG_SOCROC_E2          0.0215      0.051      0.420      0.674      -0.079       0.122
# M1311_NSTG_DEEP_TSUE_F1           -0.0071      0.007     -1.065      0.287      -0.020       0.006
# M1311_NSTG_DEEP_TSUE_SOCROC_F2     0.0502      0.047      1.061      0.289      -0.043       0.143
# M1311_NSTG_DRSG_D1                -0.0100      0.012     -0.856      0.392      -0.033       0.013
# M1311_NSTG_DRSG_SOCROC_D2         -0.0170      0.059     -0.286      0.775      -0.133       0.099
# M1324_STG_PRBLM_ULCER             -0.0059      0.003     -2.091      0.037      -0.012      -0.000
# M1330_STAS_ULCR_PRSNT              0.0175      0.009      2.046      0.041       0.001       0.034
# M1332_NBR_STAS_ULCR                0.0133      0.007      1.953      0.051   -5.14e-05       0.027
# M1334_STUS_PRBLM_STAS_ULCR         0.0146      0.012      1.249      0.212      -0.008       0.038
# M1340_SRGCL_WND_PRSNT              0.0046      0.007      0.692      0.489      -0.008       0.018
# M1342_STUS_PRBLM_SRGCL_WND        -0.0007      0.002     -0.302      0.763      -0.006       0.004
# M1400_WHEN_DYSPNEIC                0.0064      0.002      2.874      0.004       0.002       0.011
# M1600_UTI                         -0.0083      0.006     -1.409      0.159      -0.020       0.003
# M1610_UR_INCONT                   -0.0010      0.004     -0.277      0.782      -0.008       0.006
# M1620_BWL_INCONT                  -0.0040      0.002     -2.107      0.035      -0.008      -0.000
# M1630_OSTOMY                      -0.0392      0.012     -3.165      0.002      -0.064      -0.015
# M1700_COG_FUNCTION                 0.0070      0.005      1.517      0.129      -0.002       0.016
# M1710_WHEN_CONFUSED                0.0033      0.004      0.940      0.347      -0.004       0.010
# M1720_WHEN_ANXIOUS                -0.0009      0.003     -0.270      0.787      -0.007       0.005
# M1730_PHQ2_DPRSN                   0.0059      0.008      0.754      0.451      -0.009       0.021
# M1730_PHQ2_LACK_INTRST            -0.0067      0.008     -0.850      0.395      -0.022       0.009
# M1730_STDZ_DPRSN_SCRNG            -0.0054      0.007     -0.789      0.430      -0.019       0.008
# M1740_BD_DELUSIONS                 0.0025      0.018      0.135      0.893      -0.033       0.038
# M1740_BD_IMP_DECISN                0.0056      0.010      0.543      0.587      -0.015       0.026
# M1740_BD_MEM_DEFICIT               0.0005      0.009      0.053      0.958      -0.018       0.019
# M1740_BD_NONE                      0.0002      0.012      0.018      0.985      -0.023       0.023
# M1740_BD_PHYSICAL                 -0.0116      0.030     -0.386      0.700      -0.071       0.047
# M1740_BD_SOC_INAPPRO              -0.1043      0.035     -2.975      0.003      -0.173      -0.036
# M1740_BD_VERBAL                    0.0242      0.020      1.226      0.220      -0.014       0.063
# M1745_BEH_PROB_FREQ               -0.0023      0.002     -1.080      0.280      -0.006       0.002
# M1800_CRNT_GROOMING               -0.0055      0.006     -0.860      0.390      -0.018       0.007
# M1810_CRNT_DRESS_UPPER             0.0189      0.007      2.619      0.009       0.005       0.033
# M1820_CRNT_DRESS_LOWER            -0.0021      0.006     -0.359      0.720      -0.014       0.010
# M1830_CRNT_BATHG                   0.0010      0.002      0.447      0.655      -0.004       0.006
# M1840_CRNT_TOILTG                 -0.0003      0.003     -0.094      0.925      -0.007       0.006
# M1845_CRNT_TOILTG_HYGN            -0.0132      0.005     -2.774      0.006      -0.023      -0.004
# M1850_CRNT_TRNSFRNG                0.0154      0.004      3.758      0.000       0.007       0.023
# M1860_CRNT_AMBLTN                 -0.0048      0.003     -1.376      0.169      -0.012       0.002
# M1870_CRNT_FEEDING                -0.0114      0.004     -2.849      0.004      -0.019      -0.004
# M1910_MLT_FCTR_FALL_RISK_ASMT     -0.0099      0.012     -0.826      0.409      -0.033       0.014
# M2001_DRUG_RGMN_RVW                0.0174      0.017      0.995      0.320      -0.017       0.052
# M2003_MDCTN_FLWP                   0.0131      0.014      0.946      0.344      -0.014       0.040
# M2005_MDCTN_INTRVTN                0.0015      0.004      0.331      0.740      -0.007       0.010
# M2010_HIGH_RISK_DRUG_EDCTN        -0.0023      0.007     -0.352      0.725      -0.015       0.011
# M2016_DRUG_EDCTN_INTRVTN          -0.0044      0.019     -0.233      0.816      -0.042       0.033
# M2020_CRNT_MGMT_ORAL_MDCTN         0.0029      0.004      0.796      0.426      -0.004       0.010
# M2030_CRNT_MGMT_INJCTN_MDCTN       0.0054      0.003      1.599      0.110      -0.001       0.012
# M2102_CARE_TYPE_SRC_ADL           -0.0062      0.011     -0.556      0.578      -0.028       0.016
# M2102_CARE_TYPE_SRC_MDCTN          0.0220      0.013      1.758      0.079      -0.003       0.047
# M2102_CARE_TYPE_SRC_PRCDR         -0.0382      0.010     -3.694      0.000      -0.059      -0.018
# M2102_CARE_TYPE_SRC_SPRVSN         0.0006      0.003      0.199      0.842      -0.006       0.007
# M2200_THER_NEED_NA                -0.0373      0.021     -1.782      0.075      -0.078       0.004
# M2301_EMER_USE_AFTR_LAST_ASMT      0.0027      0.005      0.493      0.622      -0.008       0.013
# M2310_ECR_HYPOGLYC                 0.1113      0.030      3.655      0.000       0.052       0.171
# M2310_ECR_MEDICATION              -0.2060      0.045     -4.545      0.000      -0.295      -0.117
# M2310_ECR_OTHER                    0.0502      0.022      2.239      0.025       0.006       0.094
# M2310_ECR_UNKNOWN                  0.0676      0.025      2.698      0.007       0.018       0.117
# M2401_INTRVTN_SMRY_DBTS_FT        -0.0088      0.005     -1.736      0.083      -0.019       0.001
# M2401_INTRVTN_SMRY_DPRSN           0.0111      0.005      2.097      0.036       0.001       0.021
# M2401_INTRVTN_SMRY_FALL_PRVNT      0.0793      0.016      5.085      0.000       0.049       0.110
# M2401_INTRVTN_SMRY_PAIN_MNTR      -0.0160      0.009     -1.682      0.093      -0.035       0.003
# M2401_INTRVTN_SMRY_PRSULC_PRVN    -0.0039      0.005     -0.722      0.470      -0.015       0.007
# M2401_INTRVTN_SMRY_PRSULC_WET      0.0368      0.007      5.014      0.000       0.022       0.051
# M2410_INPAT_FACILITY              -0.0245      0.010     -2.536      0.011      -0.043      -0.006
# M2420_DSCHRG_DISP                  0.0244      0.006      4.157      0.000       0.013       0.036
# ==============================================================================
# Omnibus:                     6902.677   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            97248.929
# Skew:                          -3.354   Prob(JB):                         0.00
# Kurtosis:                      16.956   Cond. No.                     4.86e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 4.86e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
def get_models():
    models = dict()
    for i in range(2, 10):
        rfe = RFE(estimator=LogisticRegression(), n_features_to_select=i)
        model = LogisticRegression()
        models[str(i)] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# %%
models = get_models()

# %%
def evaluate_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
    return scores

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from matplotlib import pyplot

## UNCOMMENT AND RUN if you have a lot of time. Will take a long time.

results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X_train, y_train)
    results.append(scores)
    names.append(name)    
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

def get_different_models():
    models = dict()
    # lr
    rfe = RFE(estimator=LogisticRegression(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['lr'] = Pipeline(steps=[('s',rfe),('m',model)])
    # lin
    rfe = RFE(estimator=LinearRegression(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['lin'] = Pipeline(steps=[('s',rfe),('m',model)])
    # cart
    rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['cart'] = Pipeline(steps=[('s',rfe),('m',model)])
    # rf
    rfe = RFE(estimator=RandomForestClassifier(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['rf'] = Pipeline(steps=[('s',rfe),('m',model)])
    # gbm
    rfe = RFE(estimator=GradientBoostingClassifier(), n_features_to_select=5)
    model = DecisionTreeClassifier()
    models['gbm'] = Pipeline(steps=[('s',rfe),('m',model)])
    return models
diff_models = get_different_models()

# %%
def evaluate_different_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
    return scores

## UNCOMMENT AND RUN if you have a lot of time. Will take a long time.

# results, names = list(), list()
# for name, model in diff_models.items():
#     scores = evaluate_different_model(model, X, y)
#     results.append(scores)
#     names.append(name)

# pyplot.boxplot(results, labels=names, showmeans=True)
# pyplot.show()

# %% [markdown]
# ### Feature Elimination and Variance Check: GBR

# %%
from sklearn.ensemble import GradientBoostingRegressor
def fe_gbr(n_):

    # Select 10 features with RFE on a GradientBoostingRegressor, drop 3 features on each step
    rfe_gb = RFE(estimator=GradientBoostingRegressor(),
                n_features_to_select=n_, step=3)
    rfe_gb.fit(X_train, y_train)

    # Calculate the R squared on the test set
    r_squared = rfe_gb.score(X_test, y_test)
    print('The model can explain {0:.1%} of the variance in the test set'.format(r_squared))

    # Assign the support array to gb_mask
    gb_mask = rfe_gb.support_
    return gb_mask, r_squared

# %% [markdown]
# ### Feature Elimination and Variance Check: RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
def fe_rf(n_):

    rfe_rf = RFE(estimator=RandomForestRegressor(),
                n_features_to_select=n_, step=3)
    rfe_rf.fit(X_train, y_train)

    # Calculate the R squared on the test set
    r_squared = rfe_rf.score(X_test, y_test)
    print('The model can explain {0:.1%} of the variance in the test set'.format(r_squared))

    # Assign the support array to rf_mask
    rf_mask = rfe_rf.support_
    return rf_mask, r_squared

# %% [markdown]
# ### Feature Elimination and Variance Check: Logistic

# %%
from sklearn.linear_model import LogisticRegression

def fe_logistic(n_):
    
    rfe = RFE(estimator=LogisticRegression(), n_features_to_select=n_, step=3)
    rfe.fit(X_train, y_train)

    # Calculate the R squared on the test set
    r_squared = rfe.score(X_test, y_test)
    print('The model can explain {0:.1%} of the variance in the test set'.format(r_squared))

    # Assign the support array to rf_mask
    logi_mask = rfe.support_
    return logi_mask, r_squared

# %% [markdown]
# ### Run All Feature Elimination code and compare

# %%
# RUN ALL MODELS

result = {}
for n in range(5, 130, 5):
    g, gr = fe_gbr(n)
    r, rr = fe_rf(n)
    lo, lor = fe_logistic(n)
    print(f'Number of Features: {n}')
    print(f'Gradient Boosing R-squared value: {gr}')
    print(f'Random Forest R-squared value: {rr}')
    print(f'Logistic Regression R-squared value: {lor}')
    result[n] = {'GB': gr, 'RF': rr, 'LR': lor}
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 69.1% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X[:, features], y, **fit_params)
# The model can explain 86.4% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X[:, features], y, **fit_params)
# The model can explain 89.0% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 97.5% of the variance in the test set
# Number of Features: 115
# Gradient Boosing R-squared value: 0.7013394086453686
# Random Forest R-squared value: 0.8898334758376794
# Logistic Regression R-squared value: 0.9753542821934689
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 70.1% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X[:, features], y, **fit_params)
# The model can explain 88.6% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 97.5% of the variance in the test set
# Number of Features: 120
# Gradient Boosing R-squared value: 0.7012700030917911
# Random Forest R-squared value: 0.885598506315703
# Logistic Regression R-squared value: 0.9747381392483057
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 70.2% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:283: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X[:, features], y, **fit_params)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_rfe.py:310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator_.fit(X[:, features], y, **fit_params)
# The model can explain 88.5% of the variance in the test set
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The model can explain 97.3% of the variance in the test set
# Number of Features: 125
# Gradient Boosing R-squared value: 0.7017218550253345
# Random Forest R-squared value: 0.8847815430758555
# Logistic Regression R-squared value: 0.9728897104128158
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
result
# Out:
# {5: {'GB': 0.6909940480345207,
#   'RF': 0.8637826816184315,
#   'LR': 0.9602587800369686},
#  10: {'GB': 0.699700641381056,
#   'RF': 0.9172590609635085,
#   'LR': 0.9611829944547134},
#  15: {'GB': 0.7159322215004965,
#   'RF': 0.9028394983250143,
#   'LR': 0.9614910659272952},
#  20: {'GB': 0.7063373259283081,
#   'RF': 0.8803964202311405,
#   'LR': 0.9617991373998768},
#  25: {'GB': 0.7036534460000536,
#   'RF': 0.8864800516298468,
#   'LR': 0.9707332101047443},
#  30: {'GB': 0.704720608543873,
#   'RF': 0.8950492856130299,
#   'LR': 0.9704251386321626},
#  35: {'GB': 0.6908549644322919,
#   'RF': 0.8892708045153733,
#   'LR': 0.9707332101047443},
#  40: {'GB': 0.6939460028574502,
#   'RF': 0.8908070506076953,
#   'LR': 0.9688847812692545},
#  45: {'GB': 0.6948053996293624,
#   'RF': 0.8871888398952481,
#   'LR': 0.9707332101047443},
#  50: {'GB': 0.6918313369325197,
#   'RF': 0.8820949287851318,
#   'LR': 0.9691928527418361},
#  55: {'GB': 0.6996759843211933,
#   'RF': 0.8771988002775477,
#   'LR': 0.9704251386321626},
#  60: {'GB': 0.7012101533172279,
#   'RF': 0.8864178913833367,
#   'LR': 0.9698089956869994},
#  65: {'GB': 0.7017748993593265,
#   'RF': 0.8895162163976991,
#   'LR': 0.9691928527418361},
#  70: {'GB': 0.7013336646219883,
#   'RF': 0.8832509479150346,
#   'LR': 0.9698089956869994},
#  75: {'GB': 0.7018874368116403,
#   'RF': 0.8854717639948967,
#   'LR': 0.9685767097966729},
#  80: {'GB': 0.7013603632086635,
#   'RF': 0.8843811342152189,
#   'LR': 0.9691928527418361},
#  85: {'GB': 0.7011037686925397,
#   'RF': 0.8864098186240497,
#   'LR': 0.9713493530499075},
#  90: {'GB': 0.701250979477561,
#   'RF': 0.8901168296886541,
#   'LR': 0.9670363524337646},
#  95: {'GB': 0.7014788297511148,
#   'RF': 0.8905309622400788,
#   'LR': 0.9670363524337646},
#  100: {'GB': 0.7019027518229699,
#   'RF': 0.885870558303676,
#   'LR': 0.9698089956869994},
#  105: {'GB': 0.7014805406998615,
#   'RF': 0.8897454827614507,
#   'LR': 0.9682686383240912},
#  110: {'GB': 0.7018931808350204,
#   'RF': 0.8831960531518828,
#   'LR': 0.9682686383240912},
#  115: {'GB': 0.7013394086453686,
#   'RF': 0.8898334758376794,
#   'LR': 0.9753542821934689},
#  120: {'GB': 0.7012700030917911,
#   'RF': 0.885598506315703,
#   'LR': 0.9747381392483057},
#  125: {'GB': 0.7017218550253345,
#   'RF': 0.8847815430758555,
#   'LR': 0.9728897104128158}}

# %%
import matplotlib.pyplot as plt

gb = []
rf = []
lr = []
n = []
for k, v in result.items():
    gb.append(v['GB'])
    rf.append(v['RF'])
    lr.append(v['LR'])
    n.append(k)

plt.plot(n, gb, linestyle='-', marker='o', label='Gradient Boosting')
plt.plot(n, rf, linestyle='-', marker='o', label='Random Forest')
plt.plot(n, lr, linestyle='-', marker='o', label='Logistic Regression')

# x axis label
plt.xlabel('Number of features to be selected (RFE)')

# y axis label
plt.ylabel('R-squared value')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression

# Create the RFE object and compute a cross-validated score.
# The "accuracy" scoring shows the proportion of correct classifications

min_features_to_select = 1  # Minimum number of features to consider

rfecv = RFECV(
    estimator=LogisticRegression(),
    step=1,
    cv=StratifiedKFold(2),
    scoring="accuracy",
    min_features_to_select=min_features_to_select,
)
rfecv.fit(X_train, y_train)

print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (accuracy)")
plt.plot(
    range(min_features_to_select, len(rfecv.grid_scores_) + min_features_to_select),
    rfecv.grid_scores_,
)
plt.legend()
plt.show()
# Out:
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but RFECV was fitted with feature names
#   warnings.warn(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjyhl\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: The `grid_scores_` attribute is deprecated in version 1.0 in favor of `cv_results_` and will be removed in version 1.2.
#   warnings.warn(msg, category=FutureWarning)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Optimal number of features : 108

# %%
selected_features = []
for i, rank in enumerate(rfecv.ranking_):
    feature = rfecv.feature_names_in_[i]
    selected_features.append({'feature': feature, 'rank': rank})
features_selected = [f['feature'] for f in selected_features if f['rank'] == 1]

# %%
df[(features_selected + ['patient_deceased'])].to_csv('chosen.csv')

# %%
features_selected
# Out:
# ['year_born',
#  'pa_race',
#  'pa_gender',
#  'pa_maritalstatus',
#  'epi_AdmitType',
#  'epi_height',
#  'ceo_HIPPS',
#  'ceo_HHRG',
#  'DiagnosisCategory',
#  'RoughAge',
#  'M0100_ASSMT_REASON',
#  'M0140_ETHNIC_AI_AN',
#  'M0140_ETHNIC_ASIAN',
#  'M0140_ETHNIC_BLACK',
#  'M0140_ETHNIC_HISP',
#  'M0140_ETHNIC_NH_PI',
#  'M1000_DC_IPPS_14_DA',
#  'M1000_DC_IRF_14_DA',
#  'M1000_DC_LTC_14_DA',
#  'M1000_DC_LTCH_14_DA',
#  'M1000_DC_NONE_14_DA',
#  'M1000_DC_OTH_14_DA',
#  'M1000_DC_PSYCH_14_DA',
#  'M1000_DC_SNF_14_DA',
#  'M1028_ACTV_DIAG_DM',
#  'M1028_ACTV_DIAG_NOA',
#  'M1033_HOSP_RISK_5PLUS_MDCTN',
#  'M1033_HOSP_RISK_COMPLIANCE',
#  'M1033_HOSP_RISK_CRNT_EXHSTN',
#  'M1033_HOSP_RISK_MLTPL_ED_VISIT',
#  'M1033_HOSP_RISK_MLTPL_HOSPZTN',
#  'M1033_HOSP_RISK_WEIGHT_LOSS',
#  'M1046_INFLNZ_RECD_CRNT_SEASON',
#  'M1051_PVX_RCVD_AGNCY',
#  'M1056_PVX_RSN_NOT_RCVD_AGNCY',
#  'M1060_HEIGHT_A',
#  'M1060_WEIGHT_B',
#  'M1242_PAIN_FREQ_ACTVTY_MVMT',
#  'M1306_UNHLD_STG2_PRSR_ULCR',
#  'M1307_OLDST_STG2_AT_DSCHRG',
#  'M1307_OLDST_STG2_ONST_DT',
#  'M1311_NBR_PRSULC_STG2_A1',
#  'M1311_NBR_PRSULC_STG4_C1',
#  'M1311_NBR_ULC_SOCROC_STG2_A2',
#  'M1311_NBR_ULC_SOCROC_STG3_B2',
#  'M1311_NBR_ULC_SOCROC_STG4_C2',
#  'M1311_NSTG_CVRG_E1',
#  'M1311_NSTG_CVRG_SOCROC_E2',
#  'M1311_NSTG_DEEP_TSUE_F1',
#  'M1311_NSTG_DEEP_TSUE_SOCROC_F2',
#  'M1311_NSTG_DRSG_SOCROC_D2',
#  'M1324_STG_PRBLM_ULCER',
#  'M1330_STAS_ULCR_PRSNT',
#  'M1332_NBR_STAS_ULCR',
#  'M1334_STUS_PRBLM_STAS_ULCR',
#  'M1340_SRGCL_WND_PRSNT',
#  'M1342_STUS_PRBLM_SRGCL_WND',
#  'M1400_WHEN_DYSPNEIC',
#  'M1600_UTI',
#  'M1620_BWL_INCONT',
#  'M1630_OSTOMY',
#  'M1700_COG_FUNCTION',
#  'M1710_WHEN_CONFUSED',
#  'M1720_WHEN_ANXIOUS',
#  'M1730_PHQ2_DPRSN',
#  'M1730_PHQ2_LACK_INTRST',
#  'M1730_STDZ_DPRSN_SCRNG',
#  'M1740_BD_DELUSIONS',
#  'M1740_BD_IMP_DECISN',
#  'M1740_BD_MEM_DEFICIT',
#  'M1740_BD_PHYSICAL',
#  'M1740_BD_SOC_INAPPRO',
#  'M1740_BD_VERBAL',
#  'M1745_BEH_PROB_FREQ',
#  'M1800_CRNT_GROOMING',
#  'M1810_CRNT_DRESS_UPPER',
#  'M1820_CRNT_DRESS_LOWER',
#  'M1830_CRNT_BATHG',
#  'M1840_CRNT_TOILTG',
#  'M1845_CRNT_TOILTG_HYGN',
#  'M1850_CRNT_TRNSFRNG',
#  'M1860_CRNT_AMBLTN',
#  'M1870_CRNT_FEEDING',
#  'M1910_MLT_FCTR_FALL_RISK_ASMT',
#  'M2001_DRUG_RGMN_RVW',
#  'M2003_MDCTN_FLWP',
#  'M2005_MDCTN_INTRVTN',
#  'M2010_HIGH_RISK_DRUG_EDCTN',
#  'M2016_DRUG_EDCTN_INTRVTN',
#  'M2020_CRNT_MGMT_ORAL_MDCTN',
#  'M2030_CRNT_MGMT_INJCTN_MDCTN',
#  'M2102_CARE_TYPE_SRC_ADL',
#  'M2102_CARE_TYPE_SRC_MDCTN',
#  'M2102_CARE_TYPE_SRC_PRCDR',
#  'M2102_CARE_TYPE_SRC_SPRVSN',
#  'M2301_EMER_USE_AFTR_LAST_ASMT',
#  'M2310_ECR_HYPOGLYC',
#  'M2310_ECR_MEDICATION',
#  'M2310_ECR_OTHER',
#  'M2310_ECR_UNKNOWN',
#  'M2401_INTRVTN_SMRY_DBTS_FT',
#  'M2401_INTRVTN_SMRY_DPRSN',
#  'M2401_INTRVTN_SMRY_FALL_PRVNT',
#  'M2401_INTRVTN_SMRY_PAIN_MNTR',
#  'M2401_INTRVTN_SMRY_PRSULC_PRVN',
#  'M2401_INTRVTN_SMRY_PRSULC_WET',
#  'M2410_INPAT_FACILITY',
#  'M2420_DSCHRG_DISP']

# %%
len(features_selected)
# Out:
# 108
